# %%
import pandas as pd
import numpy as np

import rows

pd.set_option('display.max_rows', 500)
import warnings
warnings.filterwarnings('ignore')

# %%
from tabula import read_pdf

# %% [markdown]
# ### LDO 1

# %%
dd = read_pdf('files/ldo_full.pdf', pages='42-98' ,multiple_tables=True, encoding='utf-8', lattice=True)

# %%
len(dd)
# Out:
# 111

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i]], axis=0)
    
df = df.reset_index(drop=True)

# %%
mask = df[0].str.contains('PROGRAMA:').replace(np.nan,False)

df_programas = df[mask]


mask = df[4].str.contains('VALOR').replace(np.nan,False)

df_valor = df[mask]

# %%
display(df_programas.shape)
# display(df_valor.shape)
# Out:
# (114, 6)

# %%
indexes_programas = list(df_programas.index)

# %%
df_final = pd.DataFrame()

for i in range(len(indexes)):
#     print(indexes[i])
    
    if i == len(indexes)-1:
        df_f = df.loc[indexes[i]+4:]
        df_f[5] = df_programas.loc[indexes[i]][0]
    else:
#         print(i,'-',indexes[i], '- ', df_programas.loc[indexes[i]][0])
        df_f = df.loc[indexes[i]+4:indexes[i+1]-4]
        df_f[5] = df_programas.loc[indexes[i]][0]

    
    df_final = pd.concat([df_final,df_f], axis=0)


mask = (df_final[4].notnull()) & (df_final[4] != 'VALOR')


df_final = df_final[mask]
df_final[4] = df_final[4].str.replace('.','').astype(float)

rename = {
    0:'acao',
    1:'indicador de produto (unidade de medida)',
    2:'meta',
    3:'orgao',
    4:'valor',
    5:'programa'
}
df_final = df_final.rename(columns=rename)
# Out:
# /home/m/python/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/m/python/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cols = ['programa', 'acao', 'indicador de produto (unidade de medida)' ,'meta','orgao','valor']
df_final = df_final[cols]
df_final.head(2)
# Out:
#                               programa  \
# 9   PROGRAMA: 0000  -  ENCARGOS GERAIS
# 10  PROGRAMA: 0000  -  ENCARGOS GERAIS
#
#                                                  acao  \
# 9   4812 - PAGAMENTO DE AÇÕES INDENIZATÓRIAS DE PE...
# 10       5027 - PAGAMENTO DE BENEFÍCIOS ASSISTENCIAIS
#
#    indicador de produto (unidade de medida) meta  \
# 9                                       NaN  NaN
# 10                                      NaN  NaN
#
#                             orgao        valor
# 9     40000 - PROCURADORIA\rGERAL  800000000.0
# 10  21000 - ADM. GERAL DO\rESTADO   40587539.0

# %%
# df_final.groupby(by='orgao').sum().sort_values(by='valor', ascending=False)/df_final['valor'].sum()

# %%
# df_final.to_excel('ldo_1.xlsx', encoding='utf-8', index=False)

# %% [markdown]
# ### LDO 2

# %%
dd = read_pdf('files/ldo_full.pdf', pages='129-167' ,multiple_tables=True, encoding='utf-8', lattice=True)

# %%
len(dd)
# Out:
# 63

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i]], axis=0)
    
df = df.reset_index(drop=True)

# %%
mask = df[0].str.contains('PROGRAMA:').replace(np.nan,False)

df_programas = df[mask]


mask = df[4].str.contains('VALOR').replace(np.nan,False)

df_valor = df[mask]

indexes = list(df_programas.index)

# %%
df_final = pd.DataFrame()

for i in range(len(indexes)):
#     print(indexes[i])
    
    if i == len(indexes)-1:
        df_f = df.loc[indexes[i]+2:]
        df_f[7] = df_programas.loc[indexes[i]][0]
    else:
#         print(i,'-',indexes[i], '- ', df_programas.loc[indexes[i]][0])
        df_f = df.loc[indexes[i]+2:indexes[i+1]-3]
        df_f[7] = df_programas.loc[indexes[i]][0]

    
    df_final = pd.concat([df_final,df_f], axis=0)
# Out:
# /home/m/python/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/m/python/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_f = df_final.copy()

mask =(df_f[4] != 'DESPESA') & (df_f[5].notnull()) 

df_f = df_f[mask]
df_f[4] = df_f[4].fillna('1111111111')

mask =df_f[4].str.contains('-')
df_f[5] = np.where(mask,df_f[4],df_f[5])
df_f[4] = np.where(mask,np.nan,df_f[4])

df_f[4] = df_f[4].fillna('1111111111')




# df_f = df_f[mask]

df_f[4] = df_f[4].str.replace('.','')

df_f[0] = df_f[7]
df_f = df_f.drop(columns=7)

rename = {
    0:'programa',
    1:'produto',
    2:'indicador de produto (unidade de medida)',
    3:'meta',
    4:'despesa',
    5:'acao',
    6:'orgao'
}
df_f = df_f.rename(columns=rename)

for col in df_f.columns:
    
    if col!='despesa':
        df_f[col] = df_f[col].str.replace('\r','')

# %%
count=1
while count!=0:
    
    df_f['despesa_shift'] = df_f['despesa'].shift(1)
    df_f['produto_shift'] = df_f['produto'].shift(1)
    df_f['indicador de produto (unidade de medida)_shift'] = df_f['indicador de produto (unidade de medida)'].shift(1)
    df_f['meta_shift'] = df_f['meta'].shift(1)
    df_f['orgao_shift'] = df_f['orgao'].shift(1)

    
    
    
    mask = df_f['despesa']=='1111111111'
    count = len(df_f[mask])
    df_f['despesa'] = np.where(mask,df_f['despesa_shift'],df_f['despesa'])
    df_f['produto'] = np.where(mask,df_f['produto_shift'],df_f['produto'])
    df_f['indicador de produto (unidade de medida)'] = np.where(mask,df_f['indicador de produto (unidade de medida)_shift'],df_f['indicador de produto (unidade de medida)'])
    df_f['meta'] = np.where(mask,df_f['meta_shift'],df_f['meta'])
    df_f['orgao'] = np.where(mask,df_f['orgao_shift'],df_f['orgao'])


    
df_f = df_f[df_f.columns[:7]]

df_f['despesa_cat'] = df_f['despesa']
df_f['despesa'] = df_f['despesa'].astype(float)

# %%
df_ff = df_f.copy()

cols = ['programa','produto','indicador de produto (unidade de medida)', 'meta','despesa_cat']

df_ff['key']=df_ff['programa']+'_'+df_ff['produto'].fillna('1111111111')+'_'+df_ff['indicador de produto (unidade de medida)'].fillna('1111111111') + '_' + df_ff['meta'].fillna('1111111111')+'_'+df_ff['despesa_cat'].fillna('1111111111')

df_ff['count'] = df_ff.groupby(by='key').cumcount()+1

df_ff = pd.merge(df_ff, df_ff[['key','count']].groupby(by='key', as_index=False).last().rename(columns={'count':'factor'}), on='key', how='outer' )
df_ff = df_ff.drop(columns=['despesa_cat','key','count'])
df_ff['despesa'] = df_ff['despesa']/df_ff['factor']

df_ff['meta'] =  df_ff['meta'].str.replace('.','').str.replace(',','.').astype(float)

# %%
#157.465.738.257


df_ff['despesa'].sum()
# Out:
# 157465738257.0

# %%
# df_ff.to_excel('ldo_2.xlsx', index=False, encoding='utf-8')

# %% [markdown]
# ### LDO 3

# %%
dd = read_pdf('files/ldo_full.pdf', pages='169-178' ,multiple_tables=True, encoding='utf-8', lattice=True)

# %%
len(dd)
# Out:
# 11

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i]], axis=0)
    
df = df.reset_index(drop=True)

# %%
mask = df[0].str.contains('PROGRAMA:').replace(np.nan,False)

df_programas = df[mask]

indexes = list(df_programas.index)

# %%
mask = (df[0]!='CÓDIGO') & (df[0]!='QUADRO XXIII') & (df[0]!='ESPECIFICAÇÃO DA RECEITA E RESPECTIVA LEGISLAÇÃO') 
df = df[mask].rename(columns={0:'codigo',1:'discriminacao',2:'legeislacao especifica',3:'data'})

# %%
df['data'] = np.where(df['data']=='Dat Promul', np.nan, df['data'])

# %%
for col in df.columns:
    df[col] = df[col].str.replace('\r','')

# %%
# df.to_excel('ldo_3.xlsx', encoding='utf-8', index=False)

# %% [markdown]
# ### LDO 4

# %%
### test - '339-396'
### full - '339-844'

dd = read_pdf('files/ldo_full.pdf', pages='339-844' ,multiple_tables=True, encoding='utf-8', lattice=True)

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i]], axis=0)
    
df = df.reset_index(drop=True)

# %%
mask = df[0].str.contains('ÓRGÃO:').replace(np.nan,False)

df_orgao = df[mask]
df_orgao[2] = "org"

mask = df[0].str.contains('UNIDADE:').replace(np.nan,False)

df_unidade = df[mask]
df_unidade[2]='uni'

mask = df[0].str.contains('PROGRAMAÇÃO DA UNIDADE ORÇAMENTÁRIA').replace(np.nan,False)

df_programacao = df[mask]
df_programacao[2]='prog'

# indexes = list(df_programas.index)

# %%
df_include = pd.concat([df_orgao, df_unidade,df_programacao], axis=0).sort_index()

includes = df_include[2].tolist()

l3=[]
for i in range(len(includes)-2):
    if (includes[i]=='org') & (includes[i+1]=='uni') & (includes[i+2]=='prog'):
        l3.append(1)
    else:
        l3.append(0)
l3.append(1)
l3.append(1)

l4=[]        
for i in range(len(includes)-2):       
    if (includes[i-1]=='org') & (includes[i]=='uni') & (includes[i+1]=='prog'):
        l4.append(1)
    else:
        l4.append(0)
l4.append(1)
l4.append(1)

l5=[]
for i in range(len(includes)-2):       
    if (includes[i-2]=='org') & (includes[i-1]=='uni') & (includes[i]=='prog'):
        l5.append(1)
    else:
        l5.append(0)    
l5.append(1)
l5.append(1) 

df_include[3]=l3
df_include[4]=l4
df_include[5]=l5

df_include[6] = df_include[[3,4,5]].any(axis=1)
df_include[1]=df_include[2]
df_include[2]=df_include[6]
df_include = df_include.drop(columns=[3,4,5,6,7,8])

# %%
indexes = df_include.index.tolist()
ranges = df_include[2].tolist()

exclude_ranges=[]
for i in range(len(ranges)-1):
    if (ranges[i]==False) & (ranges[i+1]==True):
        exclude_ranges.append([indexes[i],indexes[i+1]])
    elif (ranges[i]==False) & (ranges[i+1]==False):
        exclude_ranges.append([indexes[i],indexes[i+1]])

# %%
df2 = df.copy()

for exclude in exclude_ranges:
    print(exclude[0],exclude[1])
    df2.drop(df.index[exclude[0]:exclude[1]], inplace=True)
# Out:
# 3 96
# 197 256
# 321 410
# 515 552
# 599 678
# 781 857
# 962 1193
# 1193 1425
# 2376 2810
# 2810 3180
# 4546 5002
# 5002 5202
# 6635 6806
# 6806 6928
# 7214 7438
# 7438 7624
# 7918 8205
# 8205 8311
# 8856 9167
# 9167 9291
# 9952 10264
# 10264 10531
# 11139 11487
# 11487 11812
# 12688 12802
# 12802 12922
# 13155 13306
# 13306 13450
# 13649 14275
# 14275 14750
# 16043 16087
# 16087 16131
# 16182 16336
# 16336 16462
# 16868 17049
# 17049 17217
# 17683 18010
# 18010 18234
# 18740 18919
# 18919 19092
# 19885 20018
# 20018 20116
# 20252 20371
# 20371 20478
# 20631 20711
# 20711 20779
# 20874 20977
# 20977 21074
# 21229 21745
# 21745 22025
# 23089 23127
# 23127 23161
# 23198 23227
# 23227 23257

# %%
mask = df2[0].str.contains('ÓRGÃO:').replace(np.nan,False)
df_orgao = df2[mask]
df_orgao=df_orgao[[0]]
# df_orgao[1] = "org"

mask = df2[0].str.contains('UNIDADE:').replace(np.nan,False)
df_unidade = df2[mask]
df_unidade=df_unidade[[0]]
df_unidade[1]='uni'

mask = df2[0].str.contains('PROGRAMAÇÃO DA UNIDADE ORÇAMENTÁRIA').replace(np.nan,False)
df_programacao = df2[mask]
df_programacao=df_programacao[[0]]
df_programacao[1]='prog'

# indexes = list(df_programas.index)

# %%
indexes = df_orgao.index.tolist()
orgs = df_orgao[0].tolist()
unidades = df_unidade[0].tolist()

df_aux = pd.DataFrame([1])
df_final = pd.DataFrame()

for i in range(len(indexes)):   
    
#     print(unidades[i])

    if i == len(indexes)-1:
        df_f = df2.loc[indexes[i]:]
        mask = df_f[0].str.contains('PROGRAMA:').replace(np.nan,False)
        programas = df_f[mask][0].tolist()
        prog_index = df_f[mask][0].index.tolist()
        
        
        for j in range(len(programas)):
#             print(programas[j])
            
            if j == len(programas)-1:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:]    
                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))
                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                
            else:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:prog_index[j+1]-1]
                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                mask = df_ff[0]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))
                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)
                        
                        
                        
                        
                        
    else:
        
        df_f = df2.loc[indexes[i]:indexes[i+1]]
        mask = df_f[0].str.contains('PROGRAMA:').replace(np.nan,False)
        programas = df_f[mask][0].tolist()
        prog_index = df_f[mask][0].index.tolist()
    
        
        for j in range(len(programas)):
#             print(programas[j])
            if j == len(programas)-1:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:]    
                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))
                
                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                
            else:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:prog_index[j+1]-1]
                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                mask = df_ff[0]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))
                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j] 
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)
            
#             df_final = pd.concat([df_final,df_aux],axis=0)
            
        
#         print(indexes[i], orgs[i], unidades[i])

# %%
df_final.head()

# %%
df2.head(50)
# Out:
#                                                      0  \
# 0                            roposta Orçamentária 2020
# 1                                                  NaN
# 2                   #101000 - ASSEMBLEIA LEGISLATIVA#1
# 96             ÓRGÃO:   01000 - ASSEMBLEIA LEGISLATIVA
# 97                                       1.271.893.723
# 98           UNIDADE:   01001 - ASSEMBLEIA LEGISLATIVA
# 99                          ESFERA:   ORÇAMENTO FISCAL
# 100                      RESUMO DA UNIDADE ORÇAMENTÁRA
# 101                                           PROGRAMA
# 102                        0150 - PROCESSO LEGISLATIVO
# 103                                             FUNÇÃO
# 104                                   01 - LEGISLATIVA
# 105                                          SUBFUNÇÃO
# 106                             031 - AÇÃO LEGISLATIVA
# 107                     126 - TECNOLOGIA DA INFORMAÇÃO
# 108                 128 - FORMAÇÃO DE RECURSOS HUMANOS
# 109                            MODALIDADE DE APLICAÇÃO
# 110                           090 - APLICAÇÕES DIRETAS
# 111  091 - OPERAÇÃO INTRAÓRGÃOS ORÇ.FISCAL E SEGURI...
# 112                                   FONTE DE RECURSO
# 113                                  TESOURO DO ESTADO
# 114                          FUNDO ESPECIAL DE DESPESA
# 115                                              TOTAL
# 116  Inclui valores referentes a transferência intr...
# 117                PROGRAMAÇÃO DA UNIDADE ORÇAMENTÁRIA
# 118                                                NaN
# 119                                                NaN
# 120         PROGRAMA:     0150    PROCESSO LEGISLATIVO
# 121                                               AÇÃO
# 122                                   01.031.0150.1215
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                           PRODUTO:
# 127                             INDICADOR DE\rPRODUTO:
# 128                                                NaN
# 129                                               AÇÃO
# 130                                   01.031.0150.4508
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                           PRODUTO:
# 135                             INDICADOR DE\rPRODUTO:
# 136                                              META:
# 137                                               AÇÃO
# 138                                   01.031.0150.4817
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
#
#                                                      1  \
# 0                       Governo do Estado de São Paulo
# 1                                                  NaN
# 2                                   Valores em R$ 1,00
# 96                                  Valores em R$ 1,00
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                      1.271.893.723
# 103                                                NaN
# 104                                      1.271.893.723
# 105                                                NaN
# 106                                      1.254.939.126
# 107                                         16.226.802
# 108                                            727.795
# 109                                                NaN
# 110                                        992.365.585
# 111                                        279.528.138
# 112                       PESSOAL E\rENCARGOS\rSOCIAIS
# 113                                      1.052.362.217
# 114                                                NaN
# 115                                      1.052.362.217
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                      1.271.893.723
# 121                                      GRUPO DESPESA
# 122  EXPANSÃO E ADEQUAÇÃO DAS INSTALAÇÕES DO PALÁCI...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126  OBRAS, ADAPTAÇÕES E/OU REFORMAS NO PALÁCIO 9 D...
# 127         OBRAS E/OU ADAPTAÇÕES REALIZADAS (unidade)
# 128                                                NaN
# 129                                      GRUPO DESPESA
# 130              DIVULGAÇÃO DOS TRABALHOS LEGISLATIVOS
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134      HORAS PRODUZIDAS E TRANSMITIDAS PELA TV ALESP
# 135  HORAS DE PRODUÇÃO E TRANSMISSÃO DA TV ALESP (u...
# 136                                              2.880
# 137                                      GRUPO DESPESA
# 138              FUNCIONAMENTO DO PROCESSO LEGISLATIVO
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
#
#                                 2                            3              4  \
# 0                             NaN                          NaN            NaN
# 1                             NaN                          NaN            NaN
# 2                             NaN                          NaN            NaN
# 96                            NaN                          NaN            NaN
# 97                            NaN                          NaN            NaN
# 98                            NaN                          NaN            NaN
# 99                            NaN                          NaN            NaN
# 100                           NaN                          NaN            NaN
# 101                           NaN                          NaN            NaN
# 102                           NaN                          NaN            NaN
# 103                           NaN                          NaN            NaN
# 104                           NaN                          NaN            NaN
# 105                           NaN                          NaN            NaN
# 106                           NaN                          NaN            NaN
# 107                           NaN                          NaN            NaN
# 108                           NaN                          NaN            NaN
# 109                           NaN                          NaN            NaN
# 110                           NaN                          NaN            NaN
# 111                           NaN                          NaN            NaN
# 112  JUROS E\rENCARGOS DA\rDÍVIDA  OUTRAS\rDESPESAS\rCORRENTES  INVESTIMENTOS
# 113                           NaN                  213.803.711            NaN
# 114                           NaN                    3.727.795      2.000.000
# 115                           NaN                  217.531.506      2.000.000
# 116                           NaN                          NaN            NaN
# 117                           NaN                          NaN            NaN
# 118                           NaN                          NaN            NaN
# 119                           NaN                          NaN            NaN
# 120                           NaN                          NaN            NaN
# 121              FONTE DE RECURSO                          NaN            NaN
# 122                           NaN                          NaN             10
# 123      UTRAS DESPESAS\rORRENTES                          NaN             10
# 124                           NaN             ESOURO DO ESTADO             10
# 125                           NaN                          NaN            NaN
# 126                           NaN                          NaN            NaN
# 127                           NaN                          NaN            NaN
# 128                           NaN                          NaN            NaN
# 129              FONTE DE RECURSO                          NaN            NaN
# 130                           NaN                          NaN     17.636.431
# 131      UTRAS DESPESAS\rORRENTES                          NaN     17.636.431
# 132                           NaN             ESOURO DO ESTADO     17.636.431
# 133                           NaN                          NaN            NaN
# 134                           NaN                          NaN            NaN
# 135                           NaN                          NaN            NaN
# 136                           NaN                          NaN            NaN
# 137              FONTE DE RECURSO                          NaN            NaN
# 138                           NaN                          NaN  1.237.302.665
# 139     ESSOAL E ENCARGOS\rOCIAIS                          NaN  1.052.362.217
# 140                           NaN             ESOURO DO ESTADO  1.052.362.217
# 141      UTRAS DESPESAS\rORRENTES                          NaN    184.940.448
# 142                           NaN             ESOURO DO ESTADO    184.940.448
#
#                           5                       6              7   8
# 0                       NaN                     NaN            NaN NaN
# 1                       NaN                     NaN            NaN NaN
# 2                       NaN                     NaN            NaN NaN
# 96                      NaN                     NaN            NaN NaN
# 97                      NaN                     NaN            NaN NaN
# 98                      NaN                     NaN            NaN NaN
# 99                      NaN                     NaN            NaN NaN
# 100                     NaN                     NaN            NaN NaN
# 101                     NaN                     NaN            NaN NaN
# 102                     NaN                     NaN            NaN NaN
# 103                     NaN                     NaN            NaN NaN
# 104                     NaN                     NaN            NaN NaN
# 105                     NaN                     NaN            NaN NaN
# 106                     NaN                     NaN            NaN NaN
# 107                     NaN                     NaN            NaN NaN
# 108                     NaN                     NaN            NaN NaN
# 109                     NaN                     NaN            NaN NaN
# 110                     NaN                     NaN            NaN NaN
# 111                     NaN                     NaN            NaN NaN
# 112  INVERSÕES\rFINANCEIRAS  AMORTIZAÇÃO\rDA DÍVIDA          TOTAL NaN
# 113                     NaN                     NaN  1.266.165.928 NaN
# 114                     NaN                     NaN      5.727.795 NaN
# 115                     NaN                     NaN  1.271.893.723 NaN
# 116                     NaN                     NaN            NaN NaN
# 117                     NaN                     NaN            NaN NaN
# 118                     NaN                     NaN            NaN NaN
# 119                     NaN                     NaN            NaN NaN
# 120                     NaN                     NaN            NaN NaN
# 121                     NaN                     NaN            NaN NaN
# 122                     NaN                     NaN            NaN NaN
# 123                     NaN                     NaN            NaN NaN
# 124                     NaN                     NaN            NaN NaN
# 125                     NaN                     NaN            NaN NaN
# 126                     NaN                     NaN            NaN NaN
# 127                     NaN                     NaN            NaN NaN
# 128                     NaN                     NaN            NaN NaN
# 129                     NaN                     NaN            NaN NaN
# 130                     NaN                     NaN            NaN NaN
# 131                     NaN                     NaN            NaN NaN
# 132                     NaN                     NaN            NaN NaN
# 133                     NaN                     NaN            NaN NaN
# 134                     NaN                     NaN            NaN NaN
# 135                     NaN                     NaN            NaN NaN
# 136                     NaN                     NaN            NaN NaN
# 137                     NaN                     NaN            NaN NaN
# 138                     NaN                     NaN            NaN NaN
# 139                     NaN                     NaN            NaN NaN
# 140                     NaN                     NaN            NaN NaN
# 141                     NaN                     NaN            NaN NaN
# 142                     NaN                     NaN            NaN NaN

# %%
df2.head(50)
# Out:
#                                                      0  \
# 0                            roposta Orçamentária 2020
# 1                                                  NaN
# 2                   #101000 - ASSEMBLEIA LEGISLATIVA#1
# 96             ÓRGÃO:   01000 - ASSEMBLEIA LEGISLATIVA
# 97                                       1.271.893.723
# 98           UNIDADE:   01001 - ASSEMBLEIA LEGISLATIVA
# 99                          ESFERA:   ORÇAMENTO FISCAL
# 100                      RESUMO DA UNIDADE ORÇAMENTÁRA
# 101                                           PROGRAMA
# 102                        0150 - PROCESSO LEGISLATIVO
# 103                                             FUNÇÃO
# 104                                   01 - LEGISLATIVA
# 105                                          SUBFUNÇÃO
# 106                             031 - AÇÃO LEGISLATIVA
# 107                     126 - TECNOLOGIA DA INFORMAÇÃO
# 108                 128 - FORMAÇÃO DE RECURSOS HUMANOS
# 109                            MODALIDADE DE APLICAÇÃO
# 110                           090 - APLICAÇÕES DIRETAS
# 111  091 - OPERAÇÃO INTRAÓRGÃOS ORÇ.FISCAL E SEGURI...
# 112                                   FONTE DE RECURSO
# 113                                  TESOURO DO ESTADO
# 114                          FUNDO ESPECIAL DE DESPESA
# 115                                              TOTAL
# 116  Inclui valores referentes a transferência intr...
# 117                PROGRAMAÇÃO DA UNIDADE ORÇAMENTÁRIA
# 118                                                NaN
# 119                                                NaN
# 120         PROGRAMA:     0150    PROCESSO LEGISLATIVO
# 121                                               AÇÃO
# 122                                   01.031.0150.1215
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                           PRODUTO:
# 127                             INDICADOR DE\rPRODUTO:
# 128                                                NaN
# 129                                               AÇÃO
# 130                                   01.031.0150.4508
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                           PRODUTO:
# 135                             INDICADOR DE\rPRODUTO:
# 136                                              META:
# 137                                               AÇÃO
# 138                                   01.031.0150.4817
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
#
#                                                      1  \
# 0                       Governo do Estado de São Paulo
# 1                                                  NaN
# 2                                   Valores em R$ 1,00
# 96                                  Valores em R$ 1,00
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                      1.271.893.723
# 103                                                NaN
# 104                                      1.271.893.723
# 105                                                NaN
# 106                                      1.254.939.126
# 107                                         16.226.802
# 108                                            727.795
# 109                                                NaN
# 110                                        992.365.585
# 111                                        279.528.138
# 112                       PESSOAL E\rENCARGOS\rSOCIAIS
# 113                                      1.052.362.217
# 114                                                NaN
# 115                                      1.052.362.217
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                      1.271.893.723
# 121                                      GRUPO DESPESA
# 122  EXPANSÃO E ADEQUAÇÃO DAS INSTALAÇÕES DO PALÁCI...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126  OBRAS, ADAPTAÇÕES E/OU REFORMAS NO PALÁCIO 9 D...
# 127         OBRAS E/OU ADAPTAÇÕES REALIZADAS (unidade)
# 128                                                NaN
# 129                                      GRUPO DESPESA
# 130              DIVULGAÇÃO DOS TRABALHOS LEGISLATIVOS
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134      HORAS PRODUZIDAS E TRANSMITIDAS PELA TV ALESP
# 135  HORAS DE PRODUÇÃO E TRANSMISSÃO DA TV ALESP (u...
# 136                                              2.880
# 137                                      GRUPO DESPESA
# 138              FUNCIONAMENTO DO PROCESSO LEGISLATIVO
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
#
#                                 2                            3              4  \
# 0                             NaN                          NaN            NaN
# 1                             NaN                          NaN            NaN
# 2                             NaN                          NaN            NaN
# 96                            NaN                          NaN            NaN
# 97                            NaN                          NaN            NaN
# 98                            NaN                          NaN            NaN
# 99                            NaN                          NaN            NaN
# 100                           NaN                          NaN            NaN
# 101                           NaN                          NaN            NaN
# 102                           NaN                          NaN            NaN
# 103                           NaN                          NaN            NaN
# 104                           NaN                          NaN            NaN
# 105                           NaN                          NaN            NaN
# 106                           NaN                          NaN            NaN
# 107                           NaN                          NaN            NaN
# 108                           NaN                          NaN            NaN
# 109                           NaN                          NaN            NaN
# 110                           NaN                          NaN            NaN
# 111                           NaN                          NaN            NaN
# 112  JUROS E\rENCARGOS DA\rDÍVIDA  OUTRAS\rDESPESAS\rCORRENTES  INVESTIMENTOS
# 113                           NaN                  213.803.711            NaN
# 114                           NaN                    3.727.795      2.000.000
# 115                           NaN                  217.531.506      2.000.000
# 116                           NaN                          NaN            NaN
# 117                           NaN                          NaN            NaN
# 118                           NaN                          NaN            NaN
# 119                           NaN                          NaN            NaN
# 120                           NaN                          NaN            NaN
# 121              FONTE DE RECURSO                          NaN            NaN
# 122                           NaN                          NaN             10
# 123      UTRAS DESPESAS\rORRENTES                          NaN             10
# 124                           NaN             ESOURO DO ESTADO             10
# 125                           NaN                          NaN            NaN
# 126                           NaN                          NaN            NaN
# 127                           NaN                          NaN            NaN
# 128                           NaN                          NaN            NaN
# 129              FONTE DE RECURSO                          NaN            NaN
# 130                           NaN                          NaN     17.636.431
# 131      UTRAS DESPESAS\rORRENTES                          NaN     17.636.431
# 132                           NaN             ESOURO DO ESTADO     17.636.431
# 133                           NaN                          NaN            NaN
# 134                           NaN                          NaN            NaN
# 135                           NaN                          NaN            NaN
# 136                           NaN                          NaN            NaN
# 137              FONTE DE RECURSO                          NaN            NaN
# 138                           NaN                          NaN  1.237.302.665
# 139     ESSOAL E ENCARGOS\rOCIAIS                          NaN  1.052.362.217
# 140                           NaN             ESOURO DO ESTADO  1.052.362.217
# 141      UTRAS DESPESAS\rORRENTES                          NaN    184.940.448
# 142                           NaN             ESOURO DO ESTADO    184.940.448
#
#                           5                       6              7   8
# 0                       NaN                     NaN            NaN NaN
# 1                       NaN                     NaN            NaN NaN
# 2                       NaN                     NaN            NaN NaN
# 96                      NaN                     NaN            NaN NaN
# 97                      NaN                     NaN            NaN NaN
# 98                      NaN                     NaN            NaN NaN
# 99                      NaN                     NaN            NaN NaN
# 100                     NaN                     NaN            NaN NaN
# 101                     NaN                     NaN            NaN NaN
# 102                     NaN                     NaN            NaN NaN
# 103                     NaN                     NaN            NaN NaN
# 104                     NaN                     NaN            NaN NaN
# 105                     NaN                     NaN            NaN NaN
# 106                     NaN                     NaN            NaN NaN
# 107                     NaN                     NaN            NaN NaN
# 108                     NaN                     NaN            NaN NaN
# 109                     NaN                     NaN            NaN NaN
# 110                     NaN                     NaN            NaN NaN
# 111                     NaN                     NaN            NaN NaN
# 112  INVERSÕES\rFINANCEIRAS  AMORTIZAÇÃO\rDA DÍVIDA          TOTAL NaN
# 113                     NaN                     NaN  1.266.165.928 NaN
# 114                     NaN                     NaN      5.727.795 NaN
# 115                     NaN                     NaN  1.271.893.723 NaN
# 116                     NaN                     NaN            NaN NaN
# 117                     NaN                     NaN            NaN NaN
# 118                     NaN                     NaN            NaN NaN
# 119                     NaN                     NaN            NaN NaN
# 120                     NaN                     NaN            NaN NaN
# 121                     NaN                     NaN            NaN NaN
# 122                     NaN                     NaN            NaN NaN
# 123                     NaN                     NaN            NaN NaN
# 124                     NaN                     NaN            NaN NaN
# 125                     NaN                     NaN            NaN NaN
# 126                     NaN                     NaN            NaN NaN
# 127                     NaN                     NaN            NaN NaN
# 128                     NaN                     NaN            NaN NaN
# 129                     NaN                     NaN            NaN NaN
# 130                     NaN                     NaN            NaN NaN
# 131                     NaN                     NaN            NaN NaN
# 132                     NaN                     NaN            NaN NaN
# 133                     NaN                     NaN            NaN NaN
# 134                     NaN                     NaN            NaN NaN
# 135                     NaN                     NaN            NaN NaN
# 136                     NaN                     NaN            NaN NaN
# 137                     NaN                     NaN            NaN NaN
# 138                     NaN                     NaN            NaN NaN
# 139                     NaN                     NaN            NaN NaN
# 140                     NaN                     NaN            NaN NaN
# 141                     NaN                     NaN            NaN NaN
# 142                     NaN                     NaN            NaN NaN

# %%
df_final = pd.DataFrame()
indexes = df_orgao.index.tolist()

for i in range(len(indexes)):
#     print(indexes[i])
    
    if i == len(indexes)-1:
        df_f = df2.loc[indexes[i]:]
        df_f[7] = df_orgao.loc[indexes[i]][0]
    else:
#         print(i,'-',indexes[i], '- ', df_programas.loc[indexes[i]][0])
        df_f = df.loc[indexes[i]+2:indexes[i+1]-3]
        df_f[7] = df_programas.loc[indexes[i]][0]

    
    df_final = pd.concat([df_final,df_f], axis=0)
