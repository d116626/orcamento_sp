# %% [markdown]
# IBRA - INSTITUTO BRASILEIRO DE RASTREAMENTO DE ATIVOS

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 200)
import warnings
warnings.filterwarnings('ignore')

from tabula import read_pdf
import camelot

import sys
sys.path.insert(0, "../")
from scripts import emendas

# %%
def check_total(df):
    return df.groupby(by=['ano','parlamentar'], as_index=False).sum().sort_values(by='valor')

# %% [markdown]
# ### LOA 2021 EMENDAS

# %%
ano = 2021
# dd_saude_2021 = camelot.read_pdf(f'../files/loa_{ano}_final.pdf', pages='22-98',kind='grid')

# %%
# dd_outros_2021 = camelot.read_pdf(f'../files/loa_{ano}_final.pdf', pages='99-188',kind='grid')

# %%
### saude
df = emendas.tables_to_df(dd_saude_2021)

columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','objeto','valor']

df_saude = emendas.manipulate_padronize_df(df, columns_df,ano)
df_saude['parlamentar'] = df_saude['parlamentar'].str.replace(
    'MARINA HELOU MARINA HELOU',
    'MARINA HELOU'
)

### outros
df = emendas.tables_to_df(dd_outros_2021)
columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','orgao','objeto','valor']

df_outras = emendas.manipulate_padronize_df(df, columns_df,ano)

# %%
# display(check_total(df_saude))
# display(check_total(df_outras))

# %%
### merge saude and outras
df_saude['orgao'] = 'SAÚDE'

df_saude = df_saude[df_outras.columns]
df_final = pd.concat([df_saude,df_outras], axis=0)

df_final.to_csv(f'../data/emendas/emendas_parlamentares_{ano}.csv',index=False)

display(check_total(df_final))
# Out:
#      ano                        parlamentar    valor
# 52  2021                       LECI BRANDAO  4907940
# 36  2021                        EDNA MACEDO  5208000
# 57  2021                         MARCIA LIA  5360000
# 32  2021                 DR. JORGE DO CARMO  5400000
# 82  2021                   ROGERIO NOGUEIRA  5404000
# 0   2021                  ADALBERTO FREITAS  5416000
# 66  2021                      MAURO BRAGATO  5416000
# 65  2021                            MAURICI  5416000
# 64  2021                        MARTA COSTA  5416000
# 63  2021                       MARINA HELOU  5416000
# 62  2021                  MARIA LUCIA AMARY  5416000
# 61  2021                     MARCOS ZERBINI  5416000
# 60  2021                     MARCOS DAMASIO  5416000
# 58  2021                 MARCIO DA FARMACIA  5416000
# 67  2021                 MILTON LEITE FILHO  5416000
# 56  2021                        MAJOR MECCA  5416000
# 55  2021             LUIZ FERNANDO TEIXEIRA  5416000
# ...

# %% [markdown]
# ### LOA 2020 EMENDAS

# %%
ano = 2020
dd_saude_2020 = camelot.read_pdf(f'../files/loa_{ano}_final.pdf', pages='22-63',kind='grid')

# %%
dd_outros_2020 = camelot.read_pdf(f'../files/loa_{ano}_final.pdf', pages='65-118',kind='grid')

# %%
### saude
df = emendas.tables_to_df(dd_saude_2020)

columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','objeto','valor']

df_saude = emendas.manipulate_padronize_df(df, columns_df,ano)
df_saude['parlamentar'] = df_saude['parlamentar'].str.replace(
    'MARINA HELOU MARINA HELOU',
    'MARINA HELOU'
)

### outros
df = emendas.tables_to_df(dd_outros_2020)
columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','orgao','objeto','valor']

df_outras = emendas.manipulate_padronize_df(df, columns_df,ano)

# %%
# display(check_total(df_saude))
# display(check_total(df_outras))

# %%
### merge saude and outras
df_saude['orgao'] = 'SAÚDE'

df_saude = df_saude[df_outras.columns]
df_final = pd.concat([df_saude,df_outras], axis=0)

df_final.to_csv(f'../data/emendas/emendas_parlamentares_{ano}.csv',index=False)

display(check_total(df_final))
# Out:
#      ano                        parlamentar    valor
# 3   2020                  ALEX DE MADUREIRA  5154852
# 77  2020                     RICARDO MELLAO  5159520
# 0   2020                  ADALBERTO FREITAS  5160000
# 67  2020                 MILTON LEITE FILHO  5160000
# 66  2020                      MAURO BRAGATO  5160000
# 65  2020                        MARTA COSTA  5160000
# 64  2020                       MARINA HELOU  5160000
# 63  2020                  MARIA LUCIA AMARY  5160000
# 62  2020                     MARCOS ZERBINI  5160000
# 61  2020                     MARCOS DAMASIO  5160000
# 60  2020                   MARCIO NAKASHIMA  5160000
# 59  2020                 MARCIO DA FARMACIA  5160000
# 58  2020                         MARCIA LIA  5160000
# 57  2020                        MAJOR MECCA  5160000
# 56  2020             LUIZ FERNANDO TEIXEIRA  5160000
# 55  2020                     LETICIA AGUIAR  5160000
# 54  2020                       LEO OLIVEIRA  5160000
# ...

# %% [markdown]
# ### LOA 2019 EMENDAS

# %%
ano = 2019
dd_saude_2019 = camelot.read_pdf(f'../files/loa_{ano}_final.pdf', pages='22-52',kind='grid')

# %%
dd_outros_2019 = camelot.read_pdf(f'../files/loa_{ano}_final.pdf', pages='53-95',kind='grid')

# %%
## saude
df = emendas.tables_to_df(dd_saude_2019)

columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','objeto','valor']

df_saude = emendas.manipulate_padronize_df(df, columns_df,ano)
df_saude['parlamentar'] = df_saude['parlamentar'].str.replace(
    'LUIZ FERNANDO TEIXEIRA LUIZ FERNANDO TEIXEIRA',
    'LUIZ FERNANDO TEIXEIRA'
)

## outros

df = emendas.tables_to_df(dd_outros_2019)
columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','orgao','objeto','valor']

df_outras = emendas.manipulate_padronize_df(df, columns_df,ano)
df_outras['parlamentar'] = df_outras['parlamentar'].str.replace('CASSIONAVARRO','CASSIO NAVARRO')

# %%
### merge saude and outras
df_saude['orgao'] = 'SAÚDE'

df_saude = df_saude[df_outras.columns]
df_final = pd.concat([df_saude,df_outras], axis=0)

df_final.to_csv(f'../data/emendas/emendas_parlamentares_{ano}.csv',index=False)

display(check_total(df_final))
# Out:
#      ano                        parlamentar    valor
# 3   2019                      ALDO DEMARCHI  4800000
# 9   2019              ANTONIO SALIM CURIATI  4890000
# 68  2019                 MILTON LEITE FILHO  4900000
# 1   2019                      ADILSON ROSSI  4900000
# 34  2019                     EDSON GIRIBONI  4900000
# 53  2019                       JOSE AMERICO  4900000
# 86  2019                   ROGERIO NOGUEIRA  4900000
# 85  2019                     RODRIGO MORAES  4900000
# 81  2019                     ROBERTO ENGLER  4900000
# 82  2019                  ROBERTO MASSAFERA  4900000
# 60  2019                         MARCIA LIA  4906000
# 59  2019                         LUIZ TURCO  4906000
# 58  2019             LUIZ FERNANDO TEIXEIRA  4906000
# 24  2019               CEZINHA DE MADUREIRA  4906000
# 12  2019                        CAIO FRANCA  4906000
# 45  2019                      GUSTAVO PETTA  4906970
# 56  2019                       LEO OLIVEIRA  4907940
# ...

# %% [markdown]
# ### LOA 2018 EMENDAS

# %%
ano=2018
dd_saude_2018 = camelot.read_pdf(f'../files/loa_{ano}_final.pdf', pages='22-76',kind='grid')

# %%
dd_outros_2018 = camelot.read_pdf(f'../files/loa_{ano}_final.pdf', pages='77-135',kind='grid')

# %%
## saude
df = emendas.tables_to_df(dd_saude_2018)

columns_df = ['parlamentar','entidade_beneficiada',
              'cnpj','municipio','objeto','valor']

df_saude = emendas.manipulate_padronize_df(df, columns_df,ano)


## outros

df = emendas.tables_to_df(dd_outros_2018)
columns_df = ['parlamentar','entidade_beneficiada',
              'cnpj','municipio','orgao','objeto','valor']

df_outras = emendas.manipulate_padronize_df(df, columns_df,ano)
df_outras['parlamentar'] = df_outras['parlamentar'].str.replace(
    'MARIA LUCIAAMARY',
    'MARIA LUCIA AMARY'
)

# %%
### merge saude and outras
df_saude['orgao'] = 'SAÚDE'

df_saude = df_saude[df_outras.columns]
df_final = pd.concat([df_saude,df_outras], axis=0)

df_final.to_csv(f'../data/emendas/emendas_parlamentares_{ano}.csv',index=False)

display(check_total(df_final))
# Out:
#       ano                          parlamentar      valor
# 38   2018                           ENIO TATTO  2145000.0
# 54   2018  JORGE WILSON - XERIFE DO CONSUMIDOR  2445000.0
# 18   2018                      CARLOS GIANNAZI  2445000.0
# 17   2018                      CARLOS GIANAZZI  2445000.0
# 35   2018                         EDMIR CHEDID  2445000.0
# 34   2018                        EDIMIR CHEDID  2445000.0
# 65   2018                        LUIZ FERNANDO  2445000.0
# 64   2018                   LUIZ CARLOS GONDIM  2445000.0
# 62   2018                   LUIS CARLOS GONDIM  2445000.0
# 63   2018                        LUIS FERNANDO  2445000.0
# 78   2018                  PAULO CORREA JUNIOR  2445000.0
# 95   2018                       ROQUE BARBIERE  2445000.0
# 96   2018                       ROQUE BARBIERI  2445000.0
# 59   2018                    JUNIOR APRILLANTI  2445000.0
# 58   2018                    JUNIOR APRILANTTI  2445000.0
# ...

# %% [markdown]
# ### UPLOAD TO BQ

# %%
import basedosdados as bd

# %%
tb = bd.Table('emendas_parlamentares','br_sp_alesp')

# %%
tb.create(
    '../data/emendas/',
    if_table_exists='replace',
    if_storage_data_exists='replace',
    if_table_config_exists='pass',)
# Out:
# Uploading files: 100%|██████████| 4/4 [00:03<00:00,  1.17it/s]

# %%
tb.publish(if_exists='replace')
