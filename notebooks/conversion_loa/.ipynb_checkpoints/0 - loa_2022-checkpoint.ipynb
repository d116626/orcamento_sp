# %%
import pandas as pd
import numpy as np


pd.options.display.max_columns = 999
pd.options.display.max_rows = 1999
pd.options.display.max_colwidth = 100

import warnings
warnings.filterwarnings('ignore')

from tabula import read_pdf
import camelot

# %% [markdown]
# ### LDO 1

# %%
dd = read_pdf('../files/loa_2021_teste', pages='1-8' ,multiple_tables=True, encoding='utf-8', lattice=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-46cc7cd0ac19> in <module>
# ----> 1 dd = read_pdf('../files/loa_2021_teste', pages='1-8' ,multiple_tables=True, encoding='utf-8', lattice=False)
#
# ~/anaconda3/lib/python3.7/site-packages/tabula/io.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
#     312
#     313     if not os.path.exists(path):
# --> 314         raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), path)
#     315
#     316     if os.path.getsize(path) == 0:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../files/loa_2021_teste'

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i]], axis=0)
    
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (271, 22)

# %%
# df

# %%
cols = [col for col in df.columns.tolist() if 'Unnamed' in col]

# %%
mask = df[0].str.contains('PROGRAMA:').replace(np.nan,False)

df_programas = df[mask]


mask = df[4].str.contains('VALOR').replace(np.nan,False)

df_valor = df[mask]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-8887518751dd> in <module>
# ----> 1 mask = df[0].str.contains('PROGRAMA:').replace(np.nan,False)
#       2
#       3 df_programas = df[mask]
#       4
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %%
display(df_programas.shape)
# display(df_valor.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-095550468d23> in <module>
# ----> 1 display(df_programas.shape)
#       2 # display(df_valor.shape)
#
# NameError: name 'df_programas' is not defined

# %%
indexes = list(df_programas.index)
df_final = pd.DataFrame()

for i in range(len(indexes)):
#     print(indexes[i])
    
    if i == len(indexes)-1:
        df_f = df.loc[indexes[i]+4:]
        df_f[5] = df_programas.loc[indexes[i]][0]
    else:
#         print(i,'-',indexes[i], '- ', df_programas.loc[indexes[i]][0])
        df_f = df.loc[indexes[i]+4:indexes[i+1]-4]
        df_f[5] = df_programas.loc[indexes[i]][0]

    
    df_final = pd.concat([df_final,df_f], axis=0)


mask = (df_final[4].notnull()) & (df_final[4] != 'VALOR')


df_final = df_final[mask]
df_final[4] = df_final[4].str.replace('.','').astype(float)

rename = {
    0:'acao',
    1:'indicador de produto (unidade de medida)',
    2:'meta',
    3:'orgao',
    4:'valor',
    5:'programa'
}
df_final = df_final.rename(columns=rename)

# %%
cols = ['programa', 'acao', 'indicador de produto (unidade de medida)' ,'meta','orgao','valor']
df_final = df_final[cols]
df_final.head(2)
# Out:
#                               programa  \
# 9   PROGRAMA: 0000  -  ENCARGOS GERAIS
# 10  PROGRAMA: 0000  -  ENCARGOS GERAIS
#
#                                                  acao  \
# 9   4812 - PAGAMENTO DE AÇÕES INDENIZATÓRIAS DE PE...
# 10       5027 - PAGAMENTO DE BENEFÍCIOS ASSISTENCIAIS
#
#    indicador de produto (unidade de medida) meta  \
# 9                                       NaN  NaN
# 10                                      NaN  NaN
#
#                             orgao        valor
# 9     40000 - PROCURADORIA\rGERAL  800000000.0
# 10  21000 - ADM. GERAL DO\rESTADO   40587539.0

# %%
for col in df_final.columns:
    
    if col!='valor':
        df_final[col] = df_final[col].str.replace('\r',' ')

# %%
df_final.groupby(by='orgao').sum().sort_values(by='valor', ascending=False)/df_final['valor'].sum()
# Out:
#                                                  valor
# orgao
# 21000 - ADM. GERAL DO ESTADO                  0.278294
# 20000 -  FAZENDA E PLANEJAMENTO               0.161122
# 08000 - EDUCAÇÃO                              0.121151
# 18000 - SEGURANÇA PÚBLICA                     0.091140
# 09000 - SAÚDE                                 0.090835
# 10000 - DESENVOLVIMENTO ECONÔMICO             0.065030
# 03000 - TRIBUNAL  DE JUSTIÇA                  0.045747
# 37000 - TRANSPORTES METROPOLITANOS            0.030352
# 16000 - TRANSPORTES                           0.019674
# 38000 - ADM. PENITENCIÁRIA                    0.016759
# 51000 - GOVERNO                               0.015152
# 26000 - INFRAEST. E MEIO AMBIENTE             0.010874
# 27000 - MINISTÉRIO PÚBLICO                    0.009959
# 17000 - JUSTIÇA E CIDADANIA                   0.008676
# 40000 - PROCURADORIA GERAL                    0.005809
# 01000 - ASSEMBLEIA LEGISLATIVA                0.004727
# 02000 - TRIBUNAL DE CONTAS                    0.003899
# 42000 - DEFENSORIA PÚBLICA                    0.003455
# 35000 - DESENVOLVIMENTO SOCIAL                0.003251
# 12000 - CULTURA E ECONOMIA CRIATIVA           0.002975
# 25000 - HABITAÇÃO                             0.002719
# 13000 - AGRICULTURA                           0.002627
# 29000 - DESENVOLVIMENTO REGIONAL              0.002463
# 50000 - TURISMO                               0.001952
# 41000 - ESPORTES                              0.000580
# 06000 - TRIB. JUSTIÇA MILITAR                 0.000277
# 99000 - RECON                                 0.000186
# 47000 - DIREITOS PESSOA COM DEFICIÊNCIA       0.000160
# 28000 - CASA CIVIL                            0.000144
# 52000 - SEC. ESP. DE RELAÇÕES INTERNACIONAIS  0.000009

# %%
# df_final.to_excel('ldo_1.xlsx', encoding='utf-8', index=False)

# %% [markdown]
# ### LDO 2

# %%
dd = read_pdf('files/ldo_full.pdf', pages='129-167' ,multiple_tables=True, encoding='utf-8', lattice=True)

# %%
len(dd)
# Out:
# 63

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i]], axis=0)
    
df = df.reset_index(drop=True)

# %%
mask = df[0].str.contains('PROGRAMA:').replace(np.nan,False)

df_programas = df[mask]


mask = df[4].str.contains('VALOR').replace(np.nan,False)

df_valor = df[mask]

indexes = list(df_programas.index)

# %%
df_final = pd.DataFrame()

for i in range(len(indexes)):
#     print(indexes[i])
    
    if i == len(indexes)-1:
        df_f = df.loc[indexes[i]+2:]
        df_f[7] = df_programas.loc[indexes[i]][0]
    else:
#         print(i,'-',indexes[i], '- ', df_programas.loc[indexes[i]][0])
        df_f = df.loc[indexes[i]+2:indexes[i+1]-3]
        df_f[7] = df_programas.loc[indexes[i]][0]

    
    df_final = pd.concat([df_final,df_f], axis=0)

# %%
df_f = df_final.copy()

mask =(df_f[4] != 'DESPESA') & (df_f[5].notnull()) 

df_f = df_f[mask]
df_f[4] = df_f[4].fillna('1111111111')

mask =df_f[4].str.contains('-')
df_f[5] = np.where(mask,df_f[4],df_f[5])
df_f[4] = np.where(mask,np.nan,df_f[4])

df_f[4] = df_f[4].fillna('1111111111')




# df_f = df_f[mask]

df_f[4] = df_f[4].str.replace('.','')

df_f[0] = df_f[7]
df_f = df_f.drop(columns=7)

rename = {
    0:'programa',
    1:'produto',
    2:'indicador de produto (unidade de medida)',
    3:'meta',
    4:'despesa',
    5:'acao',
    6:'orgao'
}
df_f = df_f.rename(columns=rename)

for col in df_f.columns:
    
    if col!='despesa':
        df_f[col] = df_f[col].str.replace('\r',' ')

# %%
count=1
while count!=0:
    
    df_f['despesa_shift'] = df_f['despesa'].shift(1)
    df_f['produto_shift'] = df_f['produto'].shift(1)
    df_f['indicador de produto (unidade de medida)_shift'] = df_f['indicador de produto (unidade de medida)'].shift(1)
    df_f['meta_shift'] = df_f['meta'].shift(1)
    df_f['orgao_shift'] = df_f['orgao'].shift(1)

    
    
    
    mask = df_f['despesa']=='1111111111'
    count = len(df_f[mask])
    df_f['despesa'] = np.where(mask,df_f['despesa_shift'],df_f['despesa'])
    df_f['produto'] = np.where(mask,df_f['produto_shift'],df_f['produto'])
    df_f['indicador de produto (unidade de medida)'] = np.where(mask,df_f['indicador de produto (unidade de medida)_shift'],df_f['indicador de produto (unidade de medida)'])
    df_f['meta'] = np.where(mask,df_f['meta_shift'],df_f['meta'])
    df_f['orgao'] = np.where(mask,df_f['orgao_shift'],df_f['orgao'])


    
df_f = df_f[df_f.columns[:7]]

df_f['despesa_cat'] = df_f['despesa']
df_f['despesa'] = df_f['despesa'].astype(float)

# %%
df_ff = df_f.copy()

cols = ['programa','produto','indicador de produto (unidade de medida)', 'meta','despesa_cat']

df_ff['key']=df_ff['programa']+'_'+df_ff['produto'].fillna('1111111111')+'_'+df_ff['indicador de produto (unidade de medida)'].fillna('1111111111') + '_' + df_ff['meta'].fillna('1111111111')+'_'+df_ff['despesa_cat'].fillna('1111111111')

df_ff['count'] = df_ff.groupby(by='key').cumcount()+1

df_ff = pd.merge(df_ff, df_ff[['key','count']].groupby(by='key', as_index=False).last().rename(columns={'count':'factor'}), on='key', how='outer' )
df_ff = df_ff.drop(columns=['despesa_cat','key','count'])
df_ff['despesa'] = df_ff['despesa']/df_ff['factor']

df_ff['meta'] =  df_ff['meta'].str.replace('.','').str.replace(',','.').astype(float)

# %%
#157.465.738.257


df_ff['despesa'].sum()
# Out:
# 157465738257.0

# %%
# df_ff.to_excel('ldo_2.xlsx', index=False, encoding='utf-8')

# %% [markdown]
# ### LDO 3

# %%
dd = read_pdf('files/ldo_full.pdf', pages='169-178' ,multiple_tables=True, encoding='utf-8', lattice=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-99-2e3f3e3d8c4c> in <module>
# ----> 1 dd = read_pdf('files/ldo_full.pdf', pages='169-178' ,multiple_tables=True, encoding='utf-8', lattice=False)
#
# ~/anaconda3/lib/python3.7/site-packages/tabula/io.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
#     312
#     313     if not os.path.exists(path):
# --> 314         raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), path)
#     315
#     316     if os.path.getsize(path) == 0:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'files/ldo_full.pdf'

# %%
len(dd)
# Out:
# 11

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i]], axis=0)
    
df = df.reset_index(drop=True)

# %%
mask = df[0].str.contains('PROGRAMA:').replace(np.nan,False)

df_programas = df[mask]

indexes = list(df_programas.index)

# %%
mask = (df[0]!='CÓDIGO') & (df[0]!='QUADRO XXIII') & (df[0]!='ESPECIFICAÇÃO DA RECEITA E RESPECTIVA LEGISLAÇÃO') 
df = df[mask].rename(columns={0:'codigo',1:'discriminacao',2:'legeislacao especifica',3:'data'})

# %%
df['data'] = np.where(df['data']=='Dat Promul', np.nan, df['data'])

# %%
for col in df.columns:
    df[col] = df[col].str.replace('\r',' ')

# %%
# df.to_excel('ldo_3.xlsx', encoding='utf-8', index=False)

# %% [markdown]
# ### LDO 4

# %%
### test - '339-396'
### full - '339-844'

dd = read_pdf('../files/loa_2021.pdf', pages='480-1010' ,multiple_tables=True, lattice=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/tabula/io.py in _run(java_options, options, path, encoding)
#      79     try:
# ---> 80         result = subprocess.run(
#      81             args,
#
# ~/anaconda3/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     488
# --> 489     with Popen(*popenargs, **kwargs) as process:
#     490         try:
#
# ~/anaconda3/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# ~/anaconda3/lib/python3.8/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1701                         err_msg = os.strerror(errno_num)
# -> 1702                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1703                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'java'
#
# During handling of the above exception, another exception occurred:
#
# JavaNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-19e687e3409d> in <module>
#       2 ### full - '339-844'
#       3
# ----> 4 dd = read_pdf('../files/loa_2021.pdf', pages='480-1010' ,multiple_tables=True, lattice=True)
#
# ~/anaconda3/lib/python3.8/site-packages/tabula/io.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
#     320
#     321     try:
# --> 322         output = _run(java_options, kwargs, path, encoding)
#     323     finally:
#     324         if temporary:
#
# ~/anaconda3/lib/python3.8/site-packages/tabula/io.py in _run(java_options, options, path, encoding)
#      89         return result.stdout
#      90     except FileNotFoundError:
# ---> 91         raise JavaNotFoundError(JAVA_NOT_FOUND_ERROR)
#      92     except subprocess.CalledProcessError as e:
#      93         logger.error("Error from tabula-java:\n{}\n".format(e.stderr.decode(encoding)))
#
# JavaNotFoundError: `java` command is not found from this Python process.Please ensure Java is installed and PATH is set for `java`

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    ddf = dd[i]
    first_row = pd.DataFrame(ddf.columns.tolist()).T
    first_row.columns = [i for i in range(len(first_row.columns))]
    ddf.columns = [i for i in range(len(ddf.columns))]
    ddf = pd.concat([first_row,ddf],0)
    
    df = pd.concat([df,ddf], axis=0)
df = df.reset_index(drop=True)
df['aux']=np.nan

# %%
mask = df[0].str.contains('ÓRGÃO:').replace(np.nan,False)

df_orgao = df[mask]
df_orgao['aux'] = "org"

mask = df[0].str.contains('UNIDADE:').replace(np.nan,False)

df_unidade = df[mask]
df_unidade['aux']='uni'

mask = df[0].str.contains('PROGRAMAÇÃO DA UNIDADE ORÇAMENTÁRIA').replace(np.nan,False)

df_programacao = df[mask]
df_programacao['aux']='prog'

# indexes = list(df_programas.index)

# %%
df_include = pd.concat([df_orgao, df_unidade,df_programacao], axis=0).sort_index()

includes = df_include['aux'].tolist()

l3=[]
for i in range(len(includes)-2):
    if (includes[i]=='org') & (includes[i+1]=='uni') & (includes[i+2]=='prog'):
        l3.append(1)
    else:
        l3.append(0)
l3.append(1)
l3.append(1)

l4=[]        
for i in range(len(includes)-2):       
    if (includes[i-1]=='org') & (includes[i]=='uni') & (includes[i+1]=='prog'):
        l4.append(1)
    else:
        l4.append(0)
l4.append(1)
l4.append(1)

l5=[]
for i in range(len(includes)-2):       
    if (includes[i-2]=='org') & (includes[i-1]=='uni') & (includes[i]=='prog'):
        l5.append(1)
    else:
        l5.append(0)    
l5.append(1)
l5.append(1) 

df_include[3]=l3
df_include[4]=l4
df_include[5]=l5

df_include[6] = df_include[[3,4,5]].any(axis=1)
df_include[1]=df_include[2]
df_include[2]=df_include[6]
df_include = df_include.drop(columns=[3,4,5,6,7])

# %%
indexes = df_include.index.tolist()
ranges = df_include[2].tolist()

exclude_ranges=[]
for i in range(len(ranges)-1):
    if (ranges[i]==False) & (ranges[i+1]==True):
        exclude_ranges.append([indexes[i],indexes[i+1]])
    elif (ranges[i]==False) & (ranges[i+1]==False):
        exclude_ranges.append([indexes[i],indexes[i+1]])

# %%
df2 = df.copy()

for exclude in exclude_ranges:
    print(exclude[0],exclude[1])
    df2.drop(df.index[exclude[0]:exclude[1]], inplace=True)
# Out:
# 3 124
# 228 299
# 366 475
# 584 628
# 677 772
# 884 977
# 1093 1385
# 1385 1648
# 2701 3245
# 3245 3638
# 5096 5643
# 5643 5847
# 7368 7617
# 7617 7780
# 8140 8405
# 8405 8618
# 8935 9291
# 9291 9405
# 10016 10392
# 10392 10519
# 11203 11626
# 11626 11970
# 12687 12960
# 12960 13196
# 13732 13885
# 13885 14018
# 14270 14473
# 14473 14634
# 14856 15607
# 15607 16085
# 17407 17461
# 17461 17505
# 17556 17781
# 17781 17926
# 18382 18626
# 18626 18814
# 19317 19702
# 19702 19922
# 20424 20642
# 20642 20800
# 21562 21731
# 21731 21829
# 21965 22109
# 22109 22222
# 22385 22483
# 22483 22552
# 22648 22779
# 22779 22885
# 23053 23511
# 23511 23731
# 24501 24546
# 24546 24580
# 24617 25047
# 25047 25303
# 25851 25884
# 25884 25914

# %%
mask = df2[0].str.contains('ÓRGÃO:').replace(np.nan,False)
df_orgao = df2[mask]
df_orgao=df_orgao[[0]]
# df_orgao[1] = "org"

mask = df2[0].str.contains('UNIDADE:').replace(np.nan,False)
df_unidade = df2[mask]
df_unidade=df_unidade[[0]]
df_unidade[1]='uni'

mask = df2[0].str.contains('PROGRAMAÇÃO DA UNIDADE ORÇAMENTÁRIA').replace(np.nan,False)
df_programacao = df2[mask]
df_programacao=df_programacao[[0]]
df_programacao[1]='prog'

# indexes = list(df_programas.index)

# %%
indexes = df_orgao.index.tolist()
orgs = df_orgao[0].tolist()
unidades = df_unidade[0].tolist()

df_aux = pd.DataFrame([1])
df_final = pd.DataFrame()

for i in range(len(unidades)):   
    
#     print(unidades[i])

    if i == len(indexes)-1:
        df_f = df2.loc[indexes[i]:]
        mask = df_f[0].str.contains('PROGRAMA:').replace(np.nan,False)
        programas = df_f[mask][0].tolist()
        prog_index = df_f[mask][0].index.tolist()
        
        
        for j in range(len(programas)):
#             print(programas[j])
            
            if j == len(programas)-1:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:]    
                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))
                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                
            else:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:prog_index[j+1]-1]
                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                mask = df_ff[0]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))
                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)
                        
                        
                        
                        
                        
    else:
        
        df_f = df2.loc[indexes[i]:indexes[i+1]]
        mask = df_f[0].str.contains('PROGRAMA:').replace(np.nan,False)
        programas = df_f[mask][0].tolist()
        prog_index = df_f[mask][0].index.tolist()

        for j in range(len(programas)):
#             print(programas[j])
            if j == len(programas)-1:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:]   
#                 display(df_ff)
#                 display(df_ff)

                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))
                
                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                
            else:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:prog_index[j+1]-1]
                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                mask = df_ff[0]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))

                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j] 
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)
            
#             df_final = pd.concat([df_final,df_aux],axis=0)
            
        
#         print(indexes[i], orgs[i], unidades[i])

# %%
df_final.to_excel('pre_ldo_4.xlsx', index=False, encoding='utf-8')

# %% [markdown]
# ### LDO_4 Revival

# %%
df = pd.read_excel('pre_ldo_4.xlsx', encoding='utf-8')

# %%
df[3] = np.where(df[2]=='FONTE DE RECURSO', 'FONTE DE RECURSO',df[3])
df[2] = np.where(df[1]=='GRUPO DESPESA','GRUPO DESPESA',df[2])
df[1] = np.where(df[0]=='AÇÃO', 'AÇÃO',df[1])
df[0] = np.where(df[0]=='AÇÃO', 'NUMERO DA AÇÃO',df[0])

df[5] = np.where(df[0]=='PRODUTO:', df[1],np.nan)
df[6] = np.where(df[0]=='INDICADOR DE\rPRODUTO:', df[1], np.nan)
df[7] = np.where(df[0]=='META:', df[1], np.nan)


df[1] = np.where((df[0]=='PRODUTO:') | (df[0]=='INDICADOR DE\rPRODUTO:') | (df[0]=='META:'), np.nan,df[1])
df[0] = np.where((df[0]=='PRODUTO:') | (df[0]=='INDICADOR DE\rPRODUTO:') | (df[0]=='META:'), np.nan,df[0])


df[5] = np.where(df[0]=='NUMERO DA AÇÃO', 'PRODUTO',df[5])
df[6] = np.where(df[0]=='NUMERO DA AÇÃO', 'INDICADOR DE PRODUTO',df[6])
df[7] = np.where(df[0]=='NUMERO DA AÇÃO', 'META',df[7])

# %%
df[0].fillna(method='ffill', inplace=True)
df[1].fillna(method='ffill', inplace=True)
df[2].fillna(method='ffill', inplace=True)
df[5].fillna(method='bfill', inplace=True)
df[6].fillna(method='bfill', inplace=True)
df[7].fillna(method='bfill', inplace=True)

#remove os nulls das fontes de recurso
mask = df[3].notnull()
df = df[mask]

#remove os nulls dos valores
mask = df[4].notnull()
df = df[mask]

# coloca nan nas linhas que nao possuem meta
df[7] = np.where(df[7]=='META', np.nan, df[7])

df = df.drop(columns=[8])

# %%
rename = {
    0:'codigo da acao',
    1:'acao',
    2:'grupo despesa',
    3:'fonte de recurso',
    4:'valor',
    5:'produto',
    6:'indicador de produto',
    7:'meta'
}

df = df.rename(columns=rename)

# %%
df.columns
# Out:
# Index(['codigo da acao', 'acao', 'grupo despesa', 'fonte de recurso', 'valor',
#        'produto', 'indicador de produto', 'meta', 'aux', 'orgaos', 'unidade',
#        'programas', 'numero de acoes'],
#       dtype='object')

# %%
cols = [
    'orgaos', 'unidade',
    'programas', 
    'codigo da acao', 'acao','numero de acoes',
    'produto','indicador de produto', 
    'grupo despesa', 'fonte de recurso', 
    'meta','valor'
]

df = df[cols]

# %%
mask = (df['acao']=='AÇÃO') | (df['valor'].str.contains('Unnamed'))
df = df[np.logical_not(mask)]

# %%
for col in df.columns:
    if (col!='numero de acoes'):
        df[col] = df[col].str.replace('\r',' ')
    
    
df['valor'] =  df['valor'].str.replace('.','').str.replace(',','.').astype(float)
df['meta']  =  df['meta'].str.replace('.','').str.replace(',','.').astype(float)

# %%
df['contador'] = 1

# %%
replace_values = {
    'UTRAS DESPESAS ORRENTES':'OUTRAS DESPESAS CORRENTES',
    'NVESTIMENTOS':'INVESTIMENTOS ',
    'ESSOAL E ENCARGOS OCIAI':'PESSOAL E ENCARGOS SOCIAIS',
    'NVERSÕES FINANCEIRAS':'INVERSÕES FINANCEIRAS',
    'ESERVA DE ONTINGÊNCIA':'RESERVA DE CONTINGÊNCIA',
    'UROS E ENCARGOS DA ÍVIDA':'JUROS E ENCARGOS DA DÍVIDA',
    'MORTIZAÇÃO DA DÍVIDA':'AMORTIZAÇÃO DA DÍVIDA'
}


df = df.replace({"grupo despesa": replace_values})

# %%
replace_values = {
    'ESOURO DO ESTADO':'TESOURO DO ESTADO',
    'INCULADOS FEDERAIS':'VINCULADOS FEDERAIS',
    'UNDO ESPECIAL DE ESPESA':'FUNDO ESPECIAL DE DESPESA',
    'RÓPRIOS':'PRÓPRIOS',
    'INCULADOS ESTADUAIS':'VINCULADOS ESTADUAIS',
    'UTRAS FONTES - UNDOS':'OUTRAS FONTES - FUNDOS',
    'ESOURO-DOT.INICIAL E RED.SUPLEMENTAR- NTRA':'TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR- INTRA',
    'PERAÇÕES DE RÉDITO':'OPERAÇÕES DE CRÉDITO',
    'UTRAS FONTES - DREM':'OUTRAS FONTES - DREM',
    'ECURSOS INCULADOS-FUNDO SP. DESPESA-INTRA':'RECURSOS VINCULADOS-FUNDO ESP. DESPESA-INTRA',
    'ECURSOS VINCULADOS EDERAIS-INTRA':'RECURSOS VINCULADOS FEDERAIS-INTRA',
    'EC.PROPRIO-ADM.IND.- OT.INIC.CR.SUPL.- NTRA':'REC.PROPRIO-ADM.IND.- DOT.INIC.CR.SUPL.- INTRA',
    'P.CRED.CONTR.EXTERI R-DOT.INIC.CR.SUP- NTRA':'OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-INTRA',
    'UTRAS FONTES DE ECURSOS-INTRA':'OUTRAS FONTES DE RECURSOS-INTRA '
    
}


df = df.replace({"fonte de recurso": replace_values})

# %%
# df['indicador de produto'] = df['indicador de produto'].str.replace('ERCENTUAL','PERCENTUAL').str.replace('ÚMERO','NÚMERO').str.replace('XTENSÃO','EXTENSÃO').str.replace('ENEFICIÁRIOS','BENEFICIÁRIOS')

# df['indicador de produto'] = df['indicador de produto'].str.replace('ERCENTUAL','PERCENTUAL').str.replace('ÚMERO','NÚMERO')

# %%
# mask = (df['valor']==32265100)&(df['codigo da acao']=='roposta Orçamentária 2020')

# df = df.set_value(df[mask].index,'codigo da acao' ,'10.844.0000.9019')
# df = df.set_value(df[mask].index,'acao' ,'PAGAMENTO DA DÍVIDA PÚBLICA EXTERNA')

# mask = (df['valor']==51720442)&(df['codigo da acao']=='roposta Orçamentária 2020')

# df = df.set_value(df[mask].index,'codigo da acao' ,'10.844.0000.9019')
# df = df.set_value(df[mask].index,'acao' ,'PAGAMENTO DA DÍVIDA PÚBLICA EXTERNA')



# mask = (df['valor']==28623000)&(df['codigo da acao']=='roposta Orçamentária 2020')

# df = df.set_value(df[mask].index,'codigo da acao' ,'10.303.0935.4192')
# df = df.set_value(df[mask].index,'acao' ,'ATENDIMENTO HEMOTERÁPICO')




# mask = (df['programas']=='PROGRAMA:     0930    ATENDIMENTO INTEGRAL E DESCENTRALIZADO NO SUS NO ESTADO DE SÃO PAULO') & (df['codigo da acao']=='roposta Orçamentária 2020')

# df = df.set_value(df[mask].index,'codigo da acao' ,'10.302.0930.5274')
# df = df.set_value(df[mask].index,'acao' ,'ASSISTÊNCIA MÉDICA, HOSPITALAR E AMBULATORIAL')



# mask = (df['valor']==2202907)&(df['codigo da acao']=='roposta Orçamentária 2020')

# df = df.set_value(df[mask].index,'codigo da acao' ,'18.542.2604.2622')
# df = df.set_value(df[mask].index,'acao' ,'CONTRAPARTIDAS AMBIENTAIS E CONVÊNIOS')

# %%
# df.groupby(by='acao').sum().sort_values(by='valor',ascending=False)

# %%
# df.head()

# %%
df.groupby(by='unidade').sum()
# Out:
#                                                                   numero de acoes  \
# unidade
# UNIDADE:   01001 - ASSEMBLEIA LEGISLATIVA                                     104
# UNIDADE:   02001 - TRIBUNAL DE CONTAS DO ESTADO                                24
# UNIDADE:   03001 - TRIBUNAL DE JUSTIÇA                                        140
# UNIDADE:   06001 - TRIBUNAL DE JUSTIÇA MILITAR                                  6
# UNIDADE:   08001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE                526
# UNIDADE:   08002 - CONSELHO ESTADUAL DE EDUCAÇÃO-CEE                            4
# UNIDADE:   08009 - COORDENADORIA GESTÃO DE RECURSOS HUMANOS                    22
# UNIDADE:   08010 - ESCOLA FORMAÇÃO PROF.ED.EST.PAULO R.C.SOUZA                 10
# UNIDADE:   08011 - COORDENADORIA PEDAGÓGICA                                   146
# UNIDADE:   08012 - COORD.INFORMAÇÃO,TECNOLOGIA  EVID.E MATRÍCULA               54
# UNIDADE:   08013 - COORD.INFRAESTRUTURA E SERVIÇOS ESCOLARES                  158
# UNIDADE:   08014 - COORDENADORIA DE ORÇAMENTO E FINANÇAS                       12
# UNIDADE:   08046 - FUNDAÇÃO PARA DESENVOLVIMENTO DA EDUCAÇÃO-FDE              171
# UNIDADE:   09012 - FUNDO ESTADUAL DE SAÚDE - FUNDES                           888
# UNIDADE:   09014 - COORDENADORIA DE DEFESA  E SAÚDE ANIMAL                      3
# UNIDADE:   09045 - FUNDAÇÃO REMÉDIO POPULAR CHOPIN LIMA-FURP                   22
# UNIDADE:   09046 - FUNDAÇÃO ONCOCENTRO DE SÃO PAULO                            11
# UNIDADE:   09047 - FUNDAÇÃO PRÓ-SANGUE HEMOCENTRO DE S.PAULO                   13
# UNIDADE:   09055 - SUPERINT. DE CONTROLE DE ENDEMIAS - SUCEN                   17
# UNIDADE:   09056 - HOSP.CLÍNICAS FAC.MEDICINA RIB. PRETO-USP                   34
# UNIDADE:   09057 - HOSP.DAS CLÍNICAS FAC. DE MEDICINA DA USP                   41
# UNIDADE:   09059 - HOSP.CLÍNICAS FAC.MEDICINA BOTUCATU-HCFMB                   16
# UNIDADE:   09060 - HOSP.CLÍNICAS MEDICINA MARÍLIA - HCFAMEMA                   15
# UNIDADE:   10001 - SECRETARIA DE DESENVOLVIMENTO ECONÔMICO                    555
# UNIDADE:   10046 - FUND. UNIVERSIDADE VIRTUAL ESTADO SP-UNIVESP                 4
# UNIDADE:   10047 - FUNDAÇÃO AMPARO PESQUISA ESTADO SP-FAPESP                  189
# UNIDADE:   10058 - UNIVERSIDADE DE SÃO PAULO - USP                            351
# UNIDADE:   10059 - UNIVERSIDADE ESTADUAL DE CAMPINAS-UNICAMP                  247
# UNIDADE:   10061 - UNIV.EST. JÚLIO DE MESQUITA FILHO - UNESP                  193
# UNIDADE:   10063 - CENTRO EDUCAÇÃO TECNOL.PAULA SOUZA- CEETEPS                140
# UNIDADE:   10065 - FACULDADE DE MEDICINA DE MARÍLIA-FAMEMA                    105
# UNIDADE:   10066 - FAC.DE MEDICINA DE SÃO JOSÉ DO RIO PRETO                   102
# UNIDADE:   10067 - JUNTA COMERCIAL DO ESTADO DE SP - JUCESP                     5
# UNIDADE:   10091 - INSTITUTO DE PESQUISAS TECNOLÓGICAS - IPT                   20
# UNIDADE:   12001 - SECRETARIA DA CULTURA E ECONOMIA CRIATIVA                  295
# UNIDADE:   12045 - FUNDAÇÃO PADRE ANCHIETA-RÁDIO E TV EDUCATIVAS                4
# UNIDADE:   12046 - FUNDAÇÃO MEMORIAL DA AMÉRICA LATINA                         50
# UNIDADE:   13001 - SECRETARIA DE AGRICULTURA E ABASTECIMENTO                 1017
# UNIDADE:   16001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE                 28
# UNIDADE:   16002 - DEPARTAMENTO HIDROVIÁRIO                                    44
# UNIDADE:   16055 - DEPARTAMENTO DE ESTRADAS DE RODAGEM - DER                  343
# UNIDADE:   16056 - DEPARTAMENTO AEROVIÁRIO DO ESTADO-DAESP                     40
# UNIDADE:   16091 - DESENVOLVIMENTO RODOVIÁRIO S.A. - DERSA                      4
# UNIDADE:   16093 - COMPANHIA DOCAS DE SÃO SEBASTIÃO                            10
# UNIDADE:   17001 - SECRETARIA DA JUSTIÇA E CIDADANIA                          302
# UNIDADE:   17046 - FUND.DE PROTEÇÃO DEFESA DO CONSUMIDOR-PROCON               138
# UNIDADE:   17047 - FUND. INSTITUTO DE TERRAS JOSÉ G.SILVA- ITESP               27
# UNIDADE:   17048 - FUND.AT.SOCIOEDUC.ADOLESCENTE-FUNDAÇÃO CASA                136
# UNIDADE:   17055 - INST.MEDICINA SOCIAL E DE CRIMINOLOGIA-IMESC                60
# UNIDADE:   17056 - INSTITUTO PESOS E MEDIDAS EST.SP- IPEM/SP                   16
# UNIDADE:   18001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE                 40
# UNIDADE:   18002 - POLÍCIA CIVIL DO ESTADO DE SÃO PAULO                       252
# UNIDADE:   18004 - POLÍCIA MILITAR DO ESTADO DE SÃO PAULO                     290
# UNIDADE:   18005 - CORPO DE BOMBEIROS                                         159
# UNIDADE:   18007 - SUPERINT.DA POLÍCIA TÉCNICO-CIENTÍFICA                      48
# UNIDADE:   18058 - CAIXA BENEFICENTE DA POLÍCIA MILITAR                        24
# UNIDADE:   20001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE                207
# UNIDADE:   20003 - COORD. DA ADMINISTRAÇÃO FINANCEIRA - CAF                     5
# UNIDADE:   20007 - COORDENADORIA DE ADMINISTRAÇÃO                              31
# UNIDADE:   20009 - CONTROLADORIA                                                2
# UNIDADE:   20010 - SUBCOORD.FISCALIZAÇÃO.,COBRANÇA E ARRECADAÇÃO                7
# UNIDADE:   20011 - SUBC.CONSULTORIA TRIBUTÁRIA/CONTENCIOSO TRIB.                2
# UNIDADE:   21001 - SERVIÇO DA DÍVIDA PÚBLICA                                   32
# UNIDADE:   21002 - ENCARGOS GERAIS DO ESTADO                                   32
# UNIDADE:   21003 - ENCARGOS GERAIS DE PESSOAL                                  10
# UNIDADE:   21004 - REGIME ESPECIAL DE PRECATÓRIOS                               3
# UNIDADE:   25001 - SECRETARIA DA HABITAÇÃO                                    109
# UNIDADE:   26001 - SECRETARIA DE INFRAESTRUTURA E MEIO AMBIENTE              1527
# UNIDADE:   26045 - FUND. P/ CONSERVAÇÃO E PRODUÇÃO FLORESTAL                   28
# UNIDADE:   26046 - FUNDAÇÃO PARQUE ZOOLÓGICO DE SÃO PAULO                       7
# UNIDADE:   26050 - DEPARTAMENTO DE ÁGUAS E ENERGIA ELÉTRICA-DAEE              251
# UNIDADE:   26097 - CETESB - COMPANHIA AMBIENTAL DO ESTADO                     226
# UNIDADE:   27001 - MINISTÉRIO PÚBLICO                                         112
# UNIDADE:   28001 - CASA CIVIL                                                  12
# UNIDADE:   29001 - SECRETARIA DE DESENVOLVIMENTO REGIONAL                     158
# UNIDADE:   29059 - AGÊNCIA METROPOLITANA BAIXADA SANTISTA - AGEM                5
# UNIDADE:   29060 - AGÊNCIA METROPOLITANA DE CAMPINAS- AGEMCAMP                 16
# UNIDADE:   29061 - AG.METR.VALE DO PARAIBA E LIT.NORTE-AGEMVALE                24
# UNIDADE:   29062 - AGÊNCIA METROPOLITANA  SOROCABA-AGEMSOROCABA                14
# UNIDADE:   35001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE                 31
# UNIDADE:   35003 - COORDENADORIA DE AÇÃO SOCIAL                                 3
# UNIDADE:   35004 - COORDENADORIA DE GESTÃO ESTRATÉGICA                          3
# UNIDADE:   35006 - COORD.ADMINISTRAÇÃO DE FUNDOS E CONVÊNIOS                    5
# UNIDADE:   35007 - FUNDO EST. DE ASSISTÊNCIA SOCIAL - FEAS                    199
# UNIDADE:   35009 - COORD. SEGURANÇA ALIMENTAR E NUTRICIONAL                    12
# UNIDADE:   35010 - COORD.DE POLÍTICAS SOBRE DROGAS DO EST.- COED               12
# UNIDADE:   37001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE                213
# UNIDADE:   37002 - ESTRADA DE FERRO CAMPOS DO JORDÃO                           12
# UNIDADE:   37092 - CIA.PAULISTA DE TRENS METROPOLITANOS-CPTM                  220
# UNIDADE:   38001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE                133
# UNIDADE:   38003 - COORD.UNIDADES PRISIONAIS RG METROPOLITANA SP               60
# UNIDADE:   38004 - COORD.UNID.PRISIONAIS RG VALE PARAÍBA LITORAL               60
# UNIDADE:   38005 - COORD.UNIDADES PRISIONAIS REGIÃO CENTRAL                    55
# UNIDADE:   38006 - COORD.UNIDADES PRISIONAIS REGIÃO NOROESTE                   60
# UNIDADE:   38007 - COORD.UNIDADES PRISIONAIS DA REGIÃO OESTE                   55
# UNIDADE:   38008 - COORD. DE SAÚDE DO SISTEMA PENITENCIÁRIO                    78
# UNIDADE:   38009 - COORD. DE REINTEGRAÇÃO SOCIAL E CIDADANIA                   54
# UNIDADE:   38045 - FUND.PROF.DR.MANOEL PEDRO PIMENTEL-FUNAP                    60
# UNIDADE:   40001 - PROCURADORIA GERAL DO ESTADO                               120
# UNIDADE:   41001 - SECRETARIA DE ESPORTES                                     197
# UNIDADE:   42001 - DEFENSORIA PÚBLICA DO ESTADO                               128
# UNIDADE:   47001 - SEC.DOS DIREITOS DA PESSOA COM DEFICIÊNCIA                  77
# UNIDADE:   50001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE                 40
# UNIDADE:   50002 - COORDENADORIA DE TURISMO                                    24
# UNIDADE:   51001 - SECRETARIA DE GOVERNO                                       67
# UNIDADE:   51003 - CASA MILITAR                                                31
# UNIDADE:   51004 - FUNDO SOCIAL DE SÃO PAULO - FUSSP                           60
# UNIDADE:   51005 - UNIDADE DE COMUNICAÇÃO                                       2
# UNIDADE:   51045 - FUNDAÇÃO SIST.ESTADUAL  ANÁLISE  DADOS-SEADE                35
# UNIDADE:   51055 - AGÊNCIA REG.SERV.DELEGADOS TRANSPORTES-ARTESP               70
# UNIDADE:   51056 - AGÊNCIA REG.SANEAMENTO E ENERGIA DE SP-ARSESP               50
# UNIDADE:   51057 - DEPARTAMENTO ESTADUAL DE TRÂNSITO-DETRAN-SP                 57
# UNIDADE:   52001 - SECRETARIA  ESP. DE  RELAÇÕES  INTERNACIONAIS                3
# UNIDADE:   53001 - SECRETARIA DE PROJETOS, ORÇAMENTO E GESTÃO                 219
# UNIDADE:   53055 - INSTITUTO ASSIST.MÉDICA SERVIDOR PÚB.-IAMSPE                84
# UNIDADE:   53057 - SÃO PAULO PREVIDÊNCIA - SPPREV                              22
# UNIDADE:   99099 - RESERVA DE CONTINGÊNCIA                                      1
#
#                                                                           meta  \
# unidade
# UNIDADE:   01001 - ASSEMBLEIA LEGISLATIVA                         1.743000e+04
# UNIDADE:   02001 - TRIBUNAL DE CONTAS DO ESTADO                   1.644900e+04
# UNIDADE:   03001 - TRIBUNAL DE JUSTIÇA                            4.911638e+06
# UNIDADE:   06001 - TRIBUNAL DE JUSTIÇA MILITAR                    3.177600e+04
# UNIDADE:   08001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    2.372414e+07
# UNIDADE:   08002 - CONSELHO ESTADUAL DE EDUCAÇÃO-CEE              0.000000e+00
# UNIDADE:   08009 - COORDENADORIA GESTÃO DE RECURSOS HUMANOS       8.000000e+00
# UNIDADE:   08010 - ESCOLA FORMAÇÃO PROF.ED.EST.PAULO R.C.SOUZA    3.200000e+01
# UNIDADE:   08011 - COORDENADORIA PEDAGÓGICA                       2.134555e+07
# UNIDADE:   08012 - COORD.INFORMAÇÃO,TECNOLOGIA  EVID.E MATRÍCULA  3.323844e+06
# UNIDADE:   08013 - COORD.INFRAESTRUTURA E SERVIÇOS ESCOLARES      8.388120e+05
# UNIDADE:   08014 - COORDENADORIA DE ORÇAMENTO E FINANÇAS          0.000000e+00
# UNIDADE:   08046 - FUNDAÇÃO PARA DESENVOLVIMENTO DA EDUCAÇÃO-FDE  7.293897e+06
# UNIDADE:   09012 - FUNDO ESTADUAL DE SAÚDE - FUNDES               2.432384e+08
# UNIDADE:   09014 - COORDENADORIA DE DEFESA  E SAÚDE ANIMAL        0.000000e+00
# UNIDADE:   09045 - FUNDAÇÃO REMÉDIO POPULAR CHOPIN LIMA-FURP      1.000002e+08
# UNIDADE:   09046 - FUNDAÇÃO ONCOCENTRO DE SÃO PAULO               1.545070e+05
# UNIDADE:   09047 - FUNDAÇÃO PRÓ-SANGUE HEMOCENTRO DE S.PAULO      5.161400e+04
# UNIDADE:   09055 - SUPERINT. DE CONTROLE DE ENDEMIAS - SUCEN      6.710200e+04
# UNIDADE:   09056 - HOSP.CLÍNICAS FAC.MEDICINA RIB. PRETO-USP      4.034540e+05
# UNIDADE:   09057 - HOSP.DAS CLÍNICAS FAC. DE MEDICINA DA USP      1.463177e+07
# UNIDADE:   09059 - HOSP.CLÍNICAS FAC.MEDICINA BOTUCATU-HCFMB      1.161400e+05
# UNIDADE:   09060 - HOSP.CLÍNICAS MEDICINA MARÍLIA - HCFAMEMA      2.032275e+05
# UNIDADE:   10001 - SECRETARIA DE DESENVOLVIMENTO ECONÔMICO        5.654830e+05
# UNIDADE:   10046 - FUND. UNIVERSIDADE VIRTUAL ESTADO SP-UNIVESP   3.200000e+02
# UNIDADE:   10047 - FUNDAÇÃO AMPARO PESQUISA ESTADO SP-FAPESP      8.350616e+06
# UNIDADE:   10058 - UNIVERSIDADE DE SÃO PAULO - USP                5.567882e+06
# UNIDADE:   10059 - UNIVERSIDADE ESTADUAL DE CAMPINAS-UNICAMP      1.048210e+07
# UNIDADE:   10061 - UNIV.EST. JÚLIO DE MESQUITA FILHO - UNESP      4.046400e+05
# UNIDADE:   10063 - CENTRO EDUCAÇÃO TECNOL.PAULA SOUZA- CEETEPS    1.682863e+06
# UNIDADE:   10065 - FACULDADE DE MEDICINA DE MARÍLIA-FAMEMA        4.479000e+03
# UNIDADE:   10066 - FAC.DE MEDICINA DE SÃO JOSÉ DO RIO PRETO       3.939160e+05
# UNIDADE:   10067 - JUNTA COMERCIAL DO ESTADO DE SP - JUCESP       1.600000e+06
# UNIDADE:   10091 - INSTITUTO DE PESQUISAS TECNOLÓGICAS - IPT      1.675200e+04
# UNIDADE:   12001 - SECRETARIA DA CULTURA E ECONOMIA CRIATIVA      2.335889e+07
# UNIDADE:   12045 - FUNDAÇÃO PADRE ANCHIETA-RÁDIO E TV EDUCATIVAS  2.016000e+04
# UNIDADE:   12046 - FUNDAÇÃO MEMORIAL DA AMÉRICA LATINA            4.000000e+04
# UNIDADE:   13001 - SECRETARIA DE AGRICULTURA E ABASTECIMENTO      1.435081e+07
# UNIDADE:   16001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    0.000000e+00
# UNIDADE:   16002 - DEPARTAMENTO HIDROVIÁRIO                       2.395000e+01
# UNIDADE:   16055 - DEPARTAMENTO DE ESTRADAS DE RODAGEM - DER      5.567870e+06
# UNIDADE:   16056 - DEPARTAMENTO AEROVIÁRIO DO ESTADO-DAESP        6.000000e+00
# UNIDADE:   16091 - DESENVOLVIMENTO RODOVIÁRIO S.A. - DERSA        0.000000e+00
# UNIDADE:   16093 - COMPANHIA DOCAS DE SÃO SEBASTIÃO               3.900000e+05
# UNIDADE:   17001 - SECRETARIA DA JUSTIÇA E CIDADANIA              1.510300e+05
# UNIDADE:   17046 - FUND.DE PROTEÇÃO DEFESA DO CONSUMIDOR-PROCON   1.529202e+06
# UNIDADE:   17047 - FUND. INSTITUTO DE TERRAS JOSÉ G.SILVA- ITESP  1.279800e+04
# UNIDADE:   17048 - FUND.AT.SOCIOEDUC.ADOLESCENTE-FUNDAÇÃO CASA    2.234775e+06
# UNIDADE:   17055 - INST.MEDICINA SOCIAL E DE CRIMINOLOGIA-IMESC   2.808400e+04
# UNIDADE:   17056 - INSTITUTO PESOS E MEDIDAS EST.SP- IPEM/SP      6.960000e+05
# UNIDADE:   18001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    1.501600e+05
# UNIDADE:   18002 - POLÍCIA CIVIL DO ESTADO DE SÃO PAULO           5.818630e+07
# UNIDADE:   18004 - POLÍCIA MILITAR DO ESTADO DE SÃO PAULO         4.373072e+07
# UNIDADE:   18005 - CORPO DE BOMBEIROS                             1.125000e+03
# UNIDADE:   18007 - SUPERINT.DA POLÍCIA TÉCNICO-CIENTÍFICA         1.200920e+05
# UNIDADE:   18058 - CAIXA BENEFICENTE DA POLÍCIA MILITAR           5.000000e+03
# UNIDADE:   20001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    8.500000e+01
# UNIDADE:   20003 - COORD. DA ADMINISTRAÇÃO FINANCEIRA - CAF       2.720000e+02
# UNIDADE:   20007 - COORDENADORIA DE ADMINISTRAÇÃO                 0.000000e+00
# UNIDADE:   20009 - CONTROLADORIA                                  1.200000e+01
# UNIDADE:   20010 - SUBCOORD.FISCALIZAÇÃO.,COBRANÇA E ARRECADAÇÃO  3.382800e+02
# UNIDADE:   20011 - SUBC.CONSULTORIA TRIBUTÁRIA/CONTENCIOSO TRIB.  0.000000e+00
# UNIDADE:   21001 - SERVIÇO DA DÍVIDA PÚBLICA                      0.000000e+00
# UNIDADE:   21002 - ENCARGOS GERAIS DO ESTADO                      0.000000e+00
# UNIDADE:   21003 - ENCARGOS GERAIS DE PESSOAL                     0.000000e+00
# UNIDADE:   21004 - REGIME ESPECIAL DE PRECATÓRIOS                 0.000000e+00
# UNIDADE:   25001 - SECRETARIA DA HABITAÇÃO                        1.844830e+05
# UNIDADE:   26001 - SECRETARIA DE INFRAESTRUTURA E MEIO AMBIENTE   6.845165e+07
# UNIDADE:   26045 - FUND. P/ CONSERVAÇÃO E PRODUÇÃO FLORESTAL      1.682288e+07
# UNIDADE:   26046 - FUNDAÇÃO PARQUE ZOOLÓGICO DE SÃO PAULO         5.460000e+02
# UNIDADE:   26050 - DEPARTAMENTO DE ÁGUAS E ENERGIA ELÉTRICA-DAEE  2.619526e+06
# UNIDADE:   26097 - CETESB - COMPANHIA AMBIENTAL DO ESTADO         4.858120e+05
# UNIDADE:   27001 - MINISTÉRIO PÚBLICO                             1.530000e+02
# UNIDADE:   28001 - CASA CIVIL                                     0.000000e+00
# UNIDADE:   29001 - SECRETARIA DE DESENVOLVIMENTO REGIONAL         8.726600e+02
# UNIDADE:   29059 - AGÊNCIA METROPOLITANA BAIXADA SANTISTA - AGEM  0.000000e+00
# UNIDADE:   29060 - AGÊNCIA METROPOLITANA DE CAMPINAS- AGEMCAMP    0.000000e+00
# UNIDADE:   29061 - AG.METR.VALE DO PARAIBA E LIT.NORTE-AGEMVALE   1.200000e+01
# UNIDADE:   29062 - AGÊNCIA METROPOLITANA  SOROCABA-AGEMSOROCABA   3.200000e+01
# UNIDADE:   35001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    1.992800e+04
# UNIDADE:   35003 - COORDENADORIA DE AÇÃO SOCIAL                   0.000000e+00
# UNIDADE:   35004 - COORDENADORIA DE GESTÃO ESTRATÉGICA            0.000000e+00
# UNIDADE:   35006 - COORD.ADMINISTRAÇÃO DE FUNDOS E CONVÊNIOS      0.000000e+00
# UNIDADE:   35007 - FUNDO EST. DE ASSISTÊNCIA SOCIAL - FEAS        6.650590e+05
# UNIDADE:   35009 - COORD. SEGURANÇA ALIMENTAR E NUTRICIONAL       5.366850e+06
# UNIDADE:   35010 - COORD.DE POLÍTICAS SOBRE DROGAS DO EST.- COED  1.100000e+02
# UNIDADE:   37001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    1.672133e+08
# UNIDADE:   37002 - ESTRADA DE FERRO CAMPOS DO JORDÃO              5.156400e+04
# UNIDADE:   37092 - CIA.PAULISTA DE TRENS METROPOLITANOS-CPTM      3.019134e+05
# UNIDADE:   38001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    2.918800e+02
# UNIDADE:   38003 - COORD.UNIDADES PRISIONAIS RG METROPOLITANA SP  1.802202e+04
# UNIDADE:   38004 - COORD.UNID.PRISIONAIS RG VALE PARAÍBA LITORAL  1.096610e+04
# UNIDADE:   38005 - COORD.UNIDADES PRISIONAIS REGIÃO CENTRAL       5.716130e+03
# UNIDADE:   38006 - COORD.UNIDADES PRISIONAIS REGIÃO NOROESTE      3.936770e+03
# UNIDADE:   38007 - COORD.UNIDADES PRISIONAIS DA REGIÃO OESTE      9.790990e+03
# UNIDADE:   38008 - COORD. DE SAÚDE DO SISTEMA PENITENCIÁRIO       2.058400e+02
# UNIDADE:   38009 - COORD. DE REINTEGRAÇÃO SOCIAL E CIDADANIA      9.000000e+02
# UNIDADE:   38045 - FUND.PROF.DR.MANOEL PEDRO PIMENTEL-FUNAP       1.860400e+05
# UNIDADE:   40001 - PROCURADORIA GERAL DO ESTADO                   1.089600e+04
# UNIDADE:   41001 - SECRETARIA DE ESPORTES                         5.635690e+05
# UNIDADE:   42001 - DEFENSORIA PÚBLICA DO ESTADO                   1.616231e+06
# UNIDADE:   47001 - SEC.DOS DIREITOS DA PESSOA COM DEFICIÊNCIA     1.068300e+04
# UNIDADE:   50001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    8.230000e+02
# UNIDADE:   50002 - COORDENADORIA DE TURISMO                       0.000000e+00
# UNIDADE:   51001 - SECRETARIA DE GOVERNO                          1.017000e+03
# UNIDADE:   51003 - CASA MILITAR                                   8.051000e+03
# UNIDADE:   51004 - FUNDO SOCIAL DE SÃO PAULO - FUSSP              6.754000e+03
# UNIDADE:   51005 - UNIDADE DE COMUNICAÇÃO                         0.000000e+00
# UNIDADE:   51045 - FUNDAÇÃO SIST.ESTADUAL  ANÁLISE  DADOS-SEADE   0.000000e+00
# UNIDADE:   51055 - AGÊNCIA REG.SERV.DELEGADOS TRANSPORTES-ARTESP  1.768230e+05
# UNIDADE:   51056 - AGÊNCIA REG.SANEAMENTO E ENERGIA DE SP-ARSESP  4.660000e+02
# UNIDADE:   51057 - DEPARTAMENTO ESTADUAL DE TRÂNSITO-DETRAN-SP    3.600127e+07
# UNIDADE:   52001 - SECRETARIA  ESP. DE  RELAÇÕES  INTERNACIONAIS  9.000000e+00
# UNIDADE:   53001 - SECRETARIA DE PROJETOS, ORÇAMENTO E GESTÃO     3.136233e+07
# UNIDADE:   53055 - INSTITUTO ASSIST.MÉDICA SERVIDOR PÚB.-IAMSPE   2.800450e+07
# UNIDADE:   53057 - SÃO PAULO PREVIDÊNCIA - SPPREV                 2.958720e+05
# UNIDADE:   99099 - RESERVA DE CONTINGÊNCIA                        0.000000e+00
#
#                                                                          valor  \
# unidade
# UNIDADE:   01001 - ASSEMBLEIA LEGISLATIVA                         1.276109e+09
# UNIDADE:   02001 - TRIBUNAL DE CONTAS DO ESTADO                   1.037336e+09
# UNIDADE:   03001 - TRIBUNAL DE JUSTIÇA                            1.205885e+10
# UNIDADE:   06001 - TRIBUNAL DE JUSTIÇA MILITAR                    7.360856e+07
# UNIDADE:   08001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    2.382467e+10
# UNIDADE:   08002 - CONSELHO ESTADUAL DE EDUCAÇÃO-CEE              2.080722e+06
# UNIDADE:   08009 - COORDENADORIA GESTÃO DE RECURSOS HUMANOS       3.086518e+08
# UNIDADE:   08010 - ESCOLA FORMAÇÃO PROF.ED.EST.PAULO R.C.SOUZA    5.127173e+07
# UNIDADE:   08011 - COORDENADORIA PEDAGÓGICA                       2.652255e+08
# UNIDADE:   08012 - COORD.INFORMAÇÃO,TECNOLOGIA  EVID.E MATRÍCULA  7.860118e+08
# UNIDADE:   08013 - COORD.INFRAESTRUTURA E SERVIÇOS ESCOLARES      8.777901e+08
# UNIDADE:   08014 - COORDENADORIA DE ORÇAMENTO E FINANÇAS          8.809637e+09
# UNIDADE:   08046 - FUNDAÇÃO PARA DESENVOLVIMENTO DA EDUCAÇÃO-FDE  4.777081e+08
# UNIDADE:   09012 - FUNDO ESTADUAL DE SAÚDE - FUNDES               2.042574e+10
# UNIDADE:   09014 - COORDENADORIA DE DEFESA  E SAÚDE ANIMAL        7.351195e+06
# UNIDADE:   09045 - FUNDAÇÃO REMÉDIO POPULAR CHOPIN LIMA-FURP      2.894267e+08
# UNIDADE:   09046 - FUNDAÇÃO ONCOCENTRO DE SÃO PAULO               8.741183e+06
# UNIDADE:   09047 - FUNDAÇÃO PRÓ-SANGUE HEMOCENTRO DE S.PAULO      7.959563e+07
# UNIDADE:   09055 - SUPERINT. DE CONTROLE DE ENDEMIAS - SUCEN      8.658274e+07
# UNIDADE:   09056 - HOSP.CLÍNICAS FAC.MEDICINA RIB. PRETO-USP      5.549119e+08
# UNIDADE:   09057 - HOSP.DAS CLÍNICAS FAC. DE MEDICINA DA USP      1.950118e+09
# UNIDADE:   09059 - HOSP.CLÍNICAS FAC.MEDICINA BOTUCATU-HCFMB      2.862958e+08
# UNIDADE:   09060 - HOSP.CLÍNICAS MEDICINA MARÍLIA - HCFAMEMA      5.097859e+07
# UNIDADE:   10001 - SECRETARIA DE DESENVOLVIMENTO ECONÔMICO        4.049518e+08
# UNIDADE:   10046 - FUND. UNIVERSIDADE VIRTUAL ESTADO SP-UNIVESP   8.902534e+07
# UNIDADE:   10047 - FUNDAÇÃO AMPARO PESQUISA ESTADO SP-FAPESP      1.175642e+09
# UNIDADE:   10058 - UNIVERSIDADE DE SÃO PAULO - USP                5.515396e+09
# UNIDADE:   10059 - UNIVERSIDADE ESTADUAL DE CAMPINAS-UNICAMP      3.165591e+09
# UNIDADE:   10061 - UNIV.EST. JÚLIO DE MESQUITA FILHO - UNESP      3.086785e+09
# UNIDADE:   10063 - CENTRO EDUCAÇÃO TECNOL.PAULA SOUZA- CEETEPS    2.467971e+09
# UNIDADE:   10065 - FACULDADE DE MEDICINA DE MARÍLIA-FAMEMA        5.903325e+07
# UNIDADE:   10066 - FAC.DE MEDICINA DE SÃO JOSÉ DO RIO PRETO       8.691559e+07
# UNIDADE:   10067 - JUNTA COMERCIAL DO ESTADO DE SP - JUCESP       7.564247e+07
# UNIDADE:   10091 - INSTITUTO DE PESQUISAS TECNOLÓGICAS - IPT      1.847329e+08
# UNIDADE:   12001 - SECRETARIA DA CULTURA E ECONOMIA CRIATIVA      7.908663e+08
# UNIDADE:   12045 - FUNDAÇÃO PADRE ANCHIETA-RÁDIO E TV EDUCATIVAS  1.618645e+08
# UNIDADE:   12046 - FUNDAÇÃO MEMORIAL DA AMÉRICA LATINA            1.511115e+07
# UNIDADE:   13001 - SECRETARIA DE AGRICULTURA E ABASTECIMENTO      7.619704e+08
# UNIDADE:   16001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    3.879168e+07
# UNIDADE:   16002 - DEPARTAMENTO HIDROVIÁRIO                       3.341476e+08
# UNIDADE:   16055 - DEPARTAMENTO DE ESTRADAS DE RODAGEM - DER      5.820984e+09
# UNIDADE:   16056 - DEPARTAMENTO AEROVIÁRIO DO ESTADO-DAESP        6.382298e+07
# UNIDADE:   16091 - DESENVOLVIMENTO RODOVIÁRIO S.A. - DERSA        1.670094e+08
# UNIDADE:   16093 - COMPANHIA DOCAS DE SÃO SEBASTIÃO               3.547351e+07
# UNIDADE:   17001 - SECRETARIA DA JUSTIÇA E CIDADANIA              1.737102e+08
# UNIDADE:   17046 - FUND.DE PROTEÇÃO DEFESA DO CONSUMIDOR-PROCON   1.201146e+08
# UNIDADE:   17047 - FUND. INSTITUTO DE TERRAS JOSÉ G.SILVA- ITESP  6.441928e+07
# UNIDADE:   17048 - FUND.AT.SOCIOEDUC.ADOLESCENTE-FUNDAÇÃO CASA    1.506352e+09
# UNIDADE:   17055 - INST.MEDICINA SOCIAL E DE CRIMINOLOGIA-IMESC   2.600059e+07
# UNIDADE:   17056 - INSTITUTO PESOS E MEDIDAS EST.SP- IPEM/SP      8.866233e+07
# UNIDADE:   18001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    7.202091e+08
# UNIDADE:   18002 - POLÍCIA CIVIL DO ESTADO DE SÃO PAULO           4.378623e+09
# UNIDADE:   18004 - POLÍCIA MILITAR DO ESTADO DE SÃO PAULO         1.578405e+10
# UNIDADE:   18005 - CORPO DE BOMBEIROS                             1.171595e+08
# UNIDADE:   18007 - SUPERINT.DA POLÍCIA TÉCNICO-CIENTÍFICA         7.239657e+08
# UNIDADE:   18058 - CAIXA BENEFICENTE DA POLÍCIA MILITAR           2.563643e+08
# UNIDADE:   20001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    1.520406e+09
# UNIDADE:   20003 - COORD. DA ADMINISTRAÇÃO FINANCEIRA - CAF       7.163652e+07
# UNIDADE:   20007 - COORDENADORIA DE ADMINISTRAÇÃO                 6.623553e+08
# UNIDADE:   20009 - CONTROLADORIA                                  2.482355e+07
# UNIDADE:   20010 - SUBCOORD.FISCALIZAÇÃO.,COBRANÇA E ARRECADAÇÃO  1.055956e+09
# UNIDADE:   20011 - SUBC.CONSULTORIA TRIBUTÁRIA/CONTENCIOSO TRIB.  1.227898e+08
# UNIDADE:   21001 - SERVIÇO DA DÍVIDA PÚBLICA                      2.351205e+10
# UNIDADE:   21002 - ENCARGOS GERAIS DO ESTADO                      5.372274e+10
# UNIDADE:   21003 - ENCARGOS GERAIS DE PESSOAL                     3.566139e+09
# UNIDADE:   21004 - REGIME ESPECIAL DE PRECATÓRIOS                 2.545970e+09
# UNIDADE:   25001 - SECRETARIA DA HABITAÇÃO                        9.618719e+08
# UNIDADE:   26001 - SECRETARIA DE INFRAESTRUTURA E MEIO AMBIENTE   7.654128e+08
# UNIDADE:   26045 - FUND. P/ CONSERVAÇÃO E PRODUÇÃO FLORESTAL      1.029337e+08
# UNIDADE:   26046 - FUNDAÇÃO PARQUE ZOOLÓGICO DE SÃO PAULO         3.734147e+07
# UNIDADE:   26050 - DEPARTAMENTO DE ÁGUAS E ENERGIA ELÉTRICA-DAEE  1.152020e+09
# UNIDADE:   26097 - CETESB - COMPANHIA AMBIENTAL DO ESTADO         4.931824e+08
# UNIDADE:   27001 - MINISTÉRIO PÚBLICO                             2.625870e+09
# UNIDADE:   28001 - CASA CIVIL                                     3.651748e+07
# UNIDADE:   29001 - SECRETARIA DE DESENVOLVIMENTO REGIONAL         8.420198e+08
# UNIDADE:   29059 - AGÊNCIA METROPOLITANA BAIXADA SANTISTA - AGEM  4.075442e+06
# UNIDADE:   29060 - AGÊNCIA METROPOLITANA DE CAMPINAS- AGEMCAMP    1.942929e+06
# UNIDADE:   29061 - AG.METR.VALE DO PARAIBA E LIT.NORTE-AGEMVALE   1.943874e+06
# UNIDADE:   29062 - AGÊNCIA METROPOLITANA  SOROCABA-AGEMSOROCABA   1.761946e+06
# UNIDADE:   35001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    1.195741e+08
# UNIDADE:   35003 - COORDENADORIA DE AÇÃO SOCIAL                   1.751922e+07
# UNIDADE:   35004 - COORDENADORIA DE GESTÃO ESTRATÉGICA            1.343547e+06
# UNIDADE:   35006 - COORD.ADMINISTRAÇÃO DE FUNDOS E CONVÊNIOS      9.406300e+06
# UNIDADE:   35007 - FUNDO EST. DE ASSISTÊNCIA SOCIAL - FEAS        4.644835e+08
# UNIDADE:   35009 - COORD. SEGURANÇA ALIMENTAR E NUTRICIONAL       2.503734e+08
# UNIDADE:   35010 - COORD.DE POLÍTICAS SOBRE DROGAS DO EST.- COED  2.688731e+07
# UNIDADE:   37001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    4.610569e+09
# UNIDADE:   37002 - ESTRADA DE FERRO CAMPOS DO JORDÃO              1.498180e+07
# UNIDADE:   37092 - CIA.PAULISTA DE TRENS METROPOLITANOS-CPTM      3.355464e+09
# UNIDADE:   38001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    2.784650e+08
# UNIDADE:   38003 - COORD.UNIDADES PRISIONAIS RG METROPOLITANA SP  9.316224e+08
# UNIDADE:   38004 - COORD.UNID.PRISIONAIS RG VALE PARAÍBA LITORAL  4.224379e+08
# UNIDADE:   38005 - COORD.UNIDADES PRISIONAIS REGIÃO CENTRAL       7.136406e+08
# UNIDADE:   38006 - COORD.UNIDADES PRISIONAIS REGIÃO NOROESTE      8.514761e+08
# UNIDADE:   38007 - COORD.UNIDADES PRISIONAIS DA REGIÃO OESTE      1.069745e+09
# UNIDADE:   38008 - COORD. DE SAÚDE DO SISTEMA PENITENCIÁRIO       8.736505e+07
# UNIDADE:   38009 - COORD. DE REINTEGRAÇÃO SOCIAL E CIDADANIA      1.985721e+07
# UNIDADE:   38045 - FUND.PROF.DR.MANOEL PEDRO PIMENTEL-FUNAP       6.869686e+07
# UNIDADE:   40001 - PROCURADORIA GERAL DO ESTADO                   1.536624e+09
# UNIDADE:   41001 - SECRETARIA DE ESPORTES                         2.148357e+08
# UNIDADE:   42001 - DEFENSORIA PÚBLICA DO ESTADO                   8.552809e+08
# UNIDADE:   47001 - SEC.DOS DIREITOS DA PESSOA COM DEFICIÊNCIA     4.620951e+07
# UNIDADE:   50001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE    5.376709e+08
# UNIDADE:   50002 - COORDENADORIA DE TURISMO                       2.235280e+07
# UNIDADE:   51001 - SECRETARIA DE GOVERNO                          8.395375e+08
# UNIDADE:   51003 - CASA MILITAR                                   2.538208e+07
# UNIDADE:   51004 - FUNDO SOCIAL DE SÃO PAULO - FUSSP              4.360297e+07
# UNIDADE:   51005 - UNIDADE DE COMUNICAÇÃO                         1.807611e+08
# UNIDADE:   51045 - FUNDAÇÃO SIST.ESTADUAL  ANÁLISE  DADOS-SEADE   5.073655e+07
# UNIDADE:   51055 - AGÊNCIA REG.SERV.DELEGADOS TRANSPORTES-ARTESP  1.594233e+08
# UNIDADE:   51056 - AGÊNCIA REG.SANEAMENTO E ENERGIA DE SP-ARSESP  1.243079e+08
# UNIDADE:   51057 - DEPARTAMENTO ESTADUAL DE TRÂNSITO-DETRAN-SP    9.682948e+08
# UNIDADE:   52001 - SECRETARIA  ESP. DE  RELAÇÕES  INTERNACIONAIS  2.369894e+06
# UNIDADE:   53001 - SECRETARIA DE PROJETOS, ORÇAMENTO E GESTÃO     4.987835e+08
# UNIDADE:   53055 - INSTITUTO ASSIST.MÉDICA SERVIDOR PÚB.-IAMSPE   1.618058e+09
# UNIDADE:   53057 - SÃO PAULO PREVIDÊNCIA - SPPREV                 4.023088e+10
# UNIDADE:   99099 - RESERVA DE CONTINGÊNCIA                        5.100000e+07
#
#                                                                   contador
# unidade
# UNIDADE:   01001 - ASSEMBLEIA LEGISLATIVA                               13
# UNIDADE:   02001 - TRIBUNAL DE CONTAS DO ESTADO                          8
# UNIDADE:   03001 - TRIBUNAL DE JUSTIÇA                                  20
# UNIDADE:   06001 - TRIBUNAL DE JUSTIÇA MILITAR                           6
# UNIDADE:   08001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE          58
# UNIDADE:   08002 - CONSELHO ESTADUAL DE EDUCAÇÃO-CEE                     4
# UNIDADE:   08009 - COORDENADORIA GESTÃO DE RECURSOS HUMANOS              8
# UNIDADE:   08010 - ESCOLA FORMAÇÃO PROF.ED.EST.PAULO R.C.SOUZA          10
# UNIDADE:   08011 - COORDENADORIA PEDAGÓGICA                             21
# UNIDADE:   08012 - COORD.INFORMAÇÃO,TECNOLOGIA  EVID.E MATRÍCULA        18
# UNIDADE:   08013 - COORD.INFRAESTRUTURA E SERVIÇOS ESCOLARES            26
# UNIDADE:   08014 - COORDENADORIA DE ORÇAMENTO E FINANÇAS                 6
# UNIDADE:   08046 - FUNDAÇÃO PARA DESENVOLVIMENTO DA EDUCAÇÃO-FDE        27
# UNIDADE:   09012 - FUNDO ESTADUAL DE SAÚDE - FUNDES                    103
# UNIDADE:   09014 - COORDENADORIA DE DEFESA  E SAÚDE ANIMAL               3
# UNIDADE:   09045 - FUNDAÇÃO REMÉDIO POPULAR CHOPIN LIMA-FURP            11
# UNIDADE:   09046 - FUNDAÇÃO ONCOCENTRO DE SÃO PAULO                     11
# UNIDADE:   09047 - FUNDAÇÃO PRÓ-SANGUE HEMOCENTRO DE S.PAULO             8
# UNIDADE:   09055 - SUPERINT. DE CONTROLE DE ENDEMIAS - SUCEN            12
# UNIDADE:   09056 - HOSP.CLÍNICAS FAC.MEDICINA RIB. PRETO-USP            14
# UNIDADE:   09057 - HOSP.DAS CLÍNICAS FAC. DE MEDICINA DA USP            12
# UNIDADE:   09059 - HOSP.CLÍNICAS FAC.MEDICINA BOTUCATU-HCFMB             9
# UNIDADE:   09060 - HOSP.CLÍNICAS MEDICINA MARÍLIA - HCFAMEMA             8
# UNIDADE:   10001 - SECRETARIA DE DESENVOLVIMENTO ECONÔMICO              45
# UNIDADE:   10046 - FUND. UNIVERSIDADE VIRTUAL ESTADO SP-UNIVESP          4
# UNIDADE:   10047 - FUNDAÇÃO AMPARO PESQUISA ESTADO SP-FAPESP            27
# UNIDADE:   10058 - UNIVERSIDADE DE SÃO PAULO - USP                      45
# UNIDADE:   10059 - UNIVERSIDADE ESTADUAL DE CAMPINAS-UNICAMP            39
# UNIDADE:   10061 - UNIV.EST. JÚLIO DE MESQUITA FILHO - UNESP            31
# UNIDADE:   10063 - CENTRO EDUCAÇÃO TECNOL.PAULA SOUZA- CEETEPS          20
# UNIDADE:   10065 - FACULDADE DE MEDICINA DE MARÍLIA-FAMEMA              15
# UNIDADE:   10066 - FAC.DE MEDICINA DE SÃO JOSÉ DO RIO PRETO             18
# UNIDADE:   10067 - JUNTA COMERCIAL DO ESTADO DE SP - JUCESP              5
# UNIDADE:   10091 - INSTITUTO DE PESQUISAS TECNOLÓGICAS - IPT            10
# UNIDADE:   12001 - SECRETARIA DA CULTURA E ECONOMIA CRIATIVA            42
# UNIDADE:   12045 - FUNDAÇÃO PADRE ANCHIETA-RÁDIO E TV EDUCATIVAS         4
# UNIDADE:   12046 - FUNDAÇÃO MEMORIAL DA AMÉRICA LATINA                  10
# UNIDADE:   13001 - SECRETARIA DE AGRICULTURA E ABASTECIMENTO            63
# UNIDADE:   16001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE          10
# UNIDADE:   16002 - DEPARTAMENTO HIDROVIÁRIO                             11
# UNIDADE:   16055 - DEPARTAMENTO DE ESTRADAS DE RODAGEM - DER            39
# UNIDADE:   16056 - DEPARTAMENTO AEROVIÁRIO DO ESTADO-DAESP              10
# UNIDADE:   16091 - DESENVOLVIMENTO RODOVIÁRIO S.A. - DERSA               4
# UNIDADE:   16093 - COMPANHIA DOCAS DE SÃO SEBASTIÃO                      5
# UNIDADE:   17001 - SECRETARIA DA JUSTIÇA E CIDADANIA                    26
# UNIDADE:   17046 - FUND.DE PROTEÇÃO DEFESA DO CONSUMIDOR-PROCON         23
# UNIDADE:   17047 - FUND. INSTITUTO DE TERRAS JOSÉ G.SILVA- ITESP         9
# UNIDADE:   17048 - FUND.AT.SOCIOEDUC.ADOLESCENTE-FUNDAÇÃO CASA          17
# UNIDADE:   17055 - INST.MEDICINA SOCIAL E DE CRIMINOLOGIA-IMESC         12
# UNIDADE:   17056 - INSTITUTO PESOS E MEDIDAS EST.SP- IPEM/SP             8
# UNIDADE:   18001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE          14
# UNIDADE:   18002 - POLÍCIA CIVIL DO ESTADO DE SÃO PAULO                 35
# UNIDADE:   18004 - POLÍCIA MILITAR DO ESTADO DE SÃO PAULO               35
# UNIDADE:   18005 - CORPO DE BOMBEIROS                                   27
# UNIDADE:   18007 - SUPERINT.DA POLÍCIA TÉCNICO-CIENTÍFICA               15
# UNIDADE:   18058 - CAIXA BENEFICENTE DA POLÍCIA MILITAR                  6
# UNIDADE:   20001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE          47
# UNIDADE:   20003 - COORD. DA ADMINISTRAÇÃO FINANCEIRA - CAF              5
# UNIDADE:   20007 - COORDENADORIA DE ADMINISTRAÇÃO                       13
# UNIDADE:   20009 - CONTROLADORIA                                         2
# UNIDADE:   20010 - SUBCOORD.FISCALIZAÇÃO.,COBRANÇA E ARRECADAÇÃO         7
# UNIDADE:   20011 - SUBC.CONSULTORIA TRIBUTÁRIA/CONTENCIOSO TRIB.         2
# UNIDADE:   21001 - SERVIÇO DA DÍVIDA PÚBLICA                             8
# UNIDADE:   21002 - ENCARGOS GERAIS DO ESTADO                            12
# UNIDADE:   21003 - ENCARGOS GERAIS DE PESSOAL                            7
# UNIDADE:   21004 - REGIME ESPECIAL DE PRECATÓRIOS                        3
# UNIDADE:   25001 - SECRETARIA DA HABITAÇÃO                              30
# UNIDADE:   26001 - SECRETARIA DE INFRAESTRUTURA E MEIO AMBIENTE        124
# UNIDADE:   26045 - FUND. P/ CONSERVAÇÃO E PRODUÇÃO FLORESTAL            12
# UNIDADE:   26046 - FUNDAÇÃO PARQUE ZOOLÓGICO DE SÃO PAULO                7
# UNIDADE:   26050 - DEPARTAMENTO DE ÁGUAS E ENERGIA ELÉTRICA-DAEE        30
# UNIDADE:   26097 - CETESB - COMPANHIA AMBIENTAL DO ESTADO               52
# UNIDADE:   27001 - MINISTÉRIO PÚBLICO                                   16
# UNIDADE:   28001 - CASA CIVIL                                            6
# UNIDADE:   29001 - SECRETARIA DE DESENVOLVIMENTO REGIONAL               30
# UNIDADE:   29059 - AGÊNCIA METROPOLITANA BAIXADA SANTISTA - AGEM         5
# UNIDADE:   29060 - AGÊNCIA METROPOLITANA DE CAMPINAS- AGEMCAMP           8
# UNIDADE:   29061 - AG.METR.VALE DO PARAIBA E LIT.NORTE-AGEMVALE          8
# UNIDADE:   29062 - AGÊNCIA METROPOLITANA  SOROCABA-AGEMSOROCABA          7
# UNIDADE:   35001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE          14
# UNIDADE:   35003 - COORDENADORIA DE AÇÃO SOCIAL                          3
# UNIDADE:   35004 - COORDENADORIA DE GESTÃO ESTRATÉGICA                   3
# UNIDADE:   35006 - COORD.ADMINISTRAÇÃO DE FUNDOS E CONVÊNIOS             5
# UNIDADE:   35007 - FUNDO EST. DE ASSISTÊNCIA SOCIAL - FEAS              25
# UNIDADE:   35009 - COORD. SEGURANÇA ALIMENTAR E NUTRICIONAL              4
# UNIDADE:   35010 - COORD.DE POLÍTICAS SOBRE DROGAS DO EST.- COED         4
# UNIDADE:   37001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE          37
# UNIDADE:   37002 - ESTRADA DE FERRO CAMPOS DO JORDÃO                     6
# UNIDADE:   37092 - CIA.PAULISTA DE TRENS METROPOLITANOS-CPTM            20
# UNIDADE:   38001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE          19
# UNIDADE:   38003 - COORD.UNIDADES PRISIONAIS RG METROPOLITANA SP        12
# UNIDADE:   38004 - COORD.UNID.PRISIONAIS RG VALE PARAÍBA LITORAL        12
# UNIDADE:   38005 - COORD.UNIDADES PRISIONAIS REGIÃO CENTRAL             11
# UNIDADE:   38006 - COORD.UNIDADES PRISIONAIS REGIÃO NOROESTE            12
# UNIDADE:   38007 - COORD.UNIDADES PRISIONAIS DA REGIÃO OESTE            11
# UNIDADE:   38008 - COORD. DE SAÚDE DO SISTEMA PENITENCIÁRIO             13
# UNIDADE:   38009 - COORD. DE REINTEGRAÇÃO SOCIAL E CIDADANIA             9
# UNIDADE:   38045 - FUND.PROF.DR.MANOEL PEDRO PIMENTEL-FUNAP             15
# UNIDADE:   40001 - PROCURADORIA GERAL DO ESTADO                         21
# UNIDADE:   41001 - SECRETARIA DE ESPORTES                               28
# UNIDADE:   42001 - DEFENSORIA PÚBLICA DO ESTADO                         16
# UNIDADE:   47001 - SEC.DOS DIREITOS DA PESSOA COM DEFICIÊNCIA           11
# UNIDADE:   50001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE          14
# UNIDADE:   50002 - COORDENADORIA DE TURISMO                              8
# UNIDADE:   51001 - SECRETARIA DE GOVERNO                                25
# UNIDADE:   51003 - CASA MILITAR                                         10
# UNIDADE:   51004 - FUNDO SOCIAL DE SÃO PAULO - FUSSP                    10
# UNIDADE:   51005 - UNIDADE DE COMUNICAÇÃO                                2
# UNIDADE:   51045 - FUNDAÇÃO SIST.ESTADUAL  ANÁLISE  DADOS-SEADE          7
# UNIDADE:   51055 - AGÊNCIA REG.SERV.DELEGADOS TRANSPORTES-ARTESP        10
# UNIDADE:   51056 - AGÊNCIA REG.SANEAMENTO E ENERGIA DE SP-ARSESP        10
# UNIDADE:   51057 - DEPARTAMENTO ESTADUAL DE TRÂNSITO-DETRAN-SP          13
# UNIDADE:   52001 - SECRETARIA  ESP. DE  RELAÇÕES  INTERNACIONAIS         3
# UNIDADE:   53001 - SECRETARIA DE PROJETOS, ORÇAMENTO E GESTÃO           56
# UNIDADE:   53055 - INSTITUTO ASSIST.MÉDICA SERVIDOR PÚB.-IAMSPE         14
# UNIDADE:   53057 - SÃO PAULO PREVIDÊNCIA - SPPREV                       11
# UNIDADE:   99099 - RESERVA DE CONTINGÊNCIA                               1

# %%
df.to_excel('../data/loa_2021/loa_2021_part4.xlsx', index=False, encoding='utf-8')

# %% [markdown]
# ### LDO 5

# %%
### test - '339-396'
### full - '846-869'

dd = read_pdf('files/ldo_full.pdf', pages='846-869' ,multiple_tables=True, encoding='utf-8', lattice=True)

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i]], axis=0)
    
df = df.reset_index(drop=True)

# %%
mask = df[0].str.contains('ÓRGÃO:').replace(np.nan,False)

df_orgao = df[mask]
df_orgao[2] = "org"

mask = df[0].str.contains('EMPRESA:').replace(np.nan,False)

df_empresa = df[mask]
df_empresa[2]='uni'

mask = df[0].str.contains('DEMONSTRATIVO DOS INVESTIMENTOS').replace(np.nan,False)

df_demonstrativo = df[mask]
df_demonstrativo[2]='dem'

# indexes = list(df_programas.index)

# %%
df_exclude = pd.concat([df_empresa,df_demonstrativo],axis=0).sort_index()
exclude_list=[df_exclude.index.tolist()[i:i+2] for i in range(0,len(df_exclude.index.tolist()),2)]

# %%
df2 = df.copy()

for exclude in exclude_list:
    print(exclude[0],exclude[1])
    df2.drop(df.index[exclude[0]+1:exclude[1]+1], inplace=True)
# Out:
# 6 38
# 75 107
# 148 178
# 198 229
# 249 280
# 301 338
# 449 483
# 527 560
# 583 617
# 731 762
# 877 910
# 942 974
# 1006 1037

# %%
df_f = df2.copy()

df_f['orgao'] = np.where(df_f[0]=='ÓRGÃO:',df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where(df_f[0]=='ÓRGÃO:',np.nan,df_f[1])
df_f[0] = np.where(df_f[0]=='ÓRGÃO:',np.nan,df_f[0])

df_f['empresa'] = np.where(df_f[0]=='EMPRESA:',df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where(df_f[0]=='EMPRESA:',np.nan,df_f[1])
df_f[0] = np.where(df_f[0]=='EMPRESA:',np.nan,df_f[0])

df_f['programa'] = np.where(df_f[0].str.contains('PROGRAMA:'),df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where((df_f[0].str.contains('PROGRAMA:') & df_f[0].notnull()),np.nan,df_f[1])
df_f[0] = np.where((df_f[0].str.contains('PROGRAMA:') & df_f[0].notnull()),np.nan,df_f[0])

df_f['produto'] = np.where(df_f[0]=='PRODUTO:',df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where(df_f[0]=='PRODUTO:',np.nan,df_f[1])
df_f[0] = np.where(df_f[0]=='PRODUTO:',np.nan,df_f[0])


df_f['indicador de produto'] = np.where(df_f[0]=='INDICADOR\rDE PRODUTO:',df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where(df_f[0]=='INDICADOR\rDE PRODUTO:',np.nan,df_f[1])
df_f[0] = np.where(df_f[0]=='INDICADOR\rDE PRODUTO:',np.nan,df_f[0])


df_f['descricao'] = np.where(df_f[0]=='DESCRIÇÃO:',df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where(df_f[0]=='DESCRIÇÃO:',np.nan,df_f[1])
df_f[0] = np.where(df_f[0]=='DESCRIÇÃO:',np.nan,df_f[0])


df_f[2] = df_f[2].str.replace('.','')
df_f[2] = df_f[2].fillna('aaaaaaaaaa')

mask = df_f[2].str.isdigit()
df_f['valor'] = np.where(mask, df_f[2],np.nan)
df_f[2] = np.where(mask, np.nan, df_f[2])

df_f[2] = np.where(df_f[2]=='aaaaaaaaaa', np.nan,df_f[2])
df_f[2] = np.where(df_f[2]=='Valores em R$ 1,00', np.nan,df_f[2])

df_f['acao'] = df_f[2]

df_f = df_f.drop(columns=[2])


mask = df_f[0].apply(lambda x: str(x)[:2].isdigit())
df_f['numero da acao'] = np.where(mask, df_f[0], np.nan)
df_f[0] = np.where(mask, np.nan, df_f[0])


mask = df_f[0]=='OBJETIVO'
objetivo = [i+1 for i in df_f[mask].index.tolist()]
df_f['objetivo'] = 'aaaaaaaaaa'

for i in objetivo:
    df_f = df_f.set_value(i,'objetivo' ,df_f.loc[i][0])
df_f['objetivo'] = np.where(df_f['objetivo']=='aaaaaaaaaa', np.nan,df_f['objetivo'])

    
mask = df_f[1]=='PÚBLICO ALVO'
publico = [i+1 for i in df_f[mask].index.tolist()]
df_f['publico alvo'] = 'aaaaaaaaaa'

for i in publico:
    df_f = df_f.set_value(i,'publico alvo' ,df_f.loc[i][1])
    df_f = df_f.set_value(i,1 ,np.nan)
    df_f = df_f.set_value(i-1,1 ,np.nan)
    
    
df_f['publico alvo'] = np.where(df_f['publico alvo']=='aaaaaaaaaa', np.nan,df_f['publico alvo'])

mask =  (df_f[1].notnull()) & (df_f['valor'].notnull())
df_f['fonte de financiamento'] = np.where(mask, df_f[1],np.nan)

# %%
df_f['orgao'].fillna(method='ffill', inplace=True)
df_f['empresa'].fillna(method='ffill', inplace=True)
df_f['programa'].fillna(method='ffill', inplace=True)
df_f['produto'].fillna(method='bfill', inplace=True)
df_f['indicador de produto'].fillna(method='bfill', inplace=True)
df_f['descricao'].fillna(method='bfill', inplace=True)
df_f['acao'].fillna(method='ffill', inplace=True)
df_f['numero da acao'].fillna(method='bfill', inplace=True)
df_f['objetivo'].fillna(method='bfill', inplace=True)
df_f['publico alvo'].fillna(method='bfill', inplace=True)


mask = df_f['fonte de financiamento'].notna()

df_f = df_f[mask].drop(columns = [0,1,3,4,5])

df_f['valor'] = df_f['valor'].astype(float)

# %%
df_f.columns
# Out:
# Index(['orgao', 'empresa', 'programa', 'produto', 'indicador de produto',
#        'descricao', 'valor', 'acao', 'numero da acao', 'objetivo',
#        'publico alvo', 'fonte de financiamento'],
#       dtype='object')

# %%
cols = [
    'orgao', 'empresa', 'programa', 
    'produto','indicador de produto', 'objetivo', 'descricao',  'publico alvo',
    'numero da acao','acao', 'fonte de financiamento', 'valor'
]

df_f = df_f[cols]


for col in df_f.columns:
    
    if col!='valor':
        df_f[col] = df_f[col].str.replace('\r',' ')

# %%
# df_f.to_excel('ldo_5.xlsx', index=False, encoding='utf-8')

# %%
df_f.groupby(by='programa').sum()
# Out:
#                                                            valor
# programa
# PROGRAMA:1606 MELHORIAS DA MALHA RODOVIÁRIA         1.000000e+01
# PROGRAMA:1608 TRAVESSIAS LITORÂNEAS                 1.000000e+01
# PROGRAMA:2005 FOMENTO AO DESENVOLVIMENTO SOCIOE...  2.571072e+08
# PROGRAMA:2027 GESTÃO DE SERVIÇOS PRESTADOS À AD...  1.000000e+01
# PROGRAMA:2028 GESTÃO INOVADORA E ORIENTADA PARA...  1.000000e+01
# PROGRAMA:2505 FOMENTO À HABITAÇÃO DE INTERESSE ...  7.275540e+06
# PROGRAMA:2507 REGULARIZAÇÃO FUNDIÁRIA DE INTERE...  6.043646e+07
# PROGRAMA:2508 PROVISÃO DE MORADIAS                  6.377098e+08
# PROGRAMA:2510 REQUALIFICAÇÃO HABITACIONAL E URBANA  4.846704e+08
# PROGRAMA:2624 ABASTECIMENTO DE ÁGUA E ESGOTAMEN...  3.623350e+09
# PROGRAMA:2626 FOMENTO AOS PROJETOS HIDROENERGÉT...  1.257381e+08
# PROGRAMA:3706 EXPANSÃO, MODERNIZAÇÃO E GESTÃO D...  2.257126e+08
# PROGRAMA:3708 EXPANSÃO, MODERNIZAÇÃO E OPERAÇÃO...  1.877967e+09
# PROGRAMA:5100 PLANEJAMENTO, COORDENAÇÃO E GESTÃ...  2.351010e+06
# PROGRAMA:5119 TECNOLOGIA E INOVAÇÃO NA GESTÃO G...  1.008923e+08

# %% [markdown]
# ### LOA 2019 EMENDAS SAUDE

# %%
dd = camelot.read_pdf('files/loa_2019.pdf', pages='22-52')

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i].df], axis=0)
    
df = df.reset_index(drop=True)

# %%
df2 = df.replace('\r',' ', regex=True).replace('\n',' ', regex=True)

# %%
mask = df[0]!='DEPUTADO (A)'
df2 = df2[mask].rename(columns={0:'DEPUTADO (A)'})

mask = df[1]!='ENTIDADE / PREFEITURA \nBENEFICIADA'
df2 = df2[mask].rename(columns={1:'ENTIDADE / PREFEITURA \nBENEFICIADA'})

mask = df[2]!='MUNICÍPIO'
df2 = df2[mask].rename(columns={2:'MUNICÍPIO'})

mask = df[3]!='CNPJ'
df2 = df2[mask].rename(columns={3:'CNPJ'})

mask = df[4]!='OBJETO'
df2 = df2[mask].rename(columns={4:'OBJETO'})

mask = df[5]!='VALOR'
df2 = df2[mask].rename(columns={5:'VALOR'})

df2['VALOR'] = df2['VALOR'].str.replace('.','')

df2['VALOR'] = pd.to_numeric(df2['VALOR'],errors='coerce')

# %%
# df2.to_excel('ldo_2019_emendas_saude.xlsx', index=False)

# %% [markdown]
# ### LOA 2019 EMENDAS EXCETO SAUDE

# %%
dd = camelot.read_pdf('files/loa_2019.pdf', pages='53-95')

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i].df], axis=0)
    
df = df.reset_index(drop=True)

# %%
df2 = df.replace('\r',' ', regex=True).replace('\n',' ', regex=True)

# %%
mask = df[0]!='DEPUTADO (A)'
df2 = df2[mask].rename(columns={0:'DEPUTADO (A)'})

mask = df[1]!='ENTIDADE / PREFEITURA \nBENEFICIADA'
df2 = df2[mask].rename(columns={1:'ENTIDADE / PREFEITURA \nBENEFICIADA'})

mask = df[2]!='MUNICÍPIO'
df2 = df2[mask].rename(columns={2:'MUNICÍPIO'})

mask = df[3]!='CNPJ'
df2 = df2[mask].rename(columns={3:'CNPJ'})

mask = df[4]!='OBJETO'
df2 = df2[mask].rename(columns={4:'OBJETO'})

mask = df[5]!='SECRETARIA / \nÓRGÃO'
df2 = df2[mask].rename(columns={5:'SECRETARIA / \nÓRGÃO'})

mask = df[6]!='VALOR'
df2 = df2[mask].rename(columns={6:'VALOR'})

df2['VALOR'] = df2['VALOR'].str.replace('.','')

df2['VALOR'] = pd.to_numeric(df2['VALOR'],errors='coerce')

# %%
df2.head()
# Out:
#          DEPUTADO (A)        ENTIDADE / PREFEITURA \nBENEFICIADA  \
# 1  ABELARDO CAMARINHA            PREFEITURA MUNICIPAL DE  BASTOS
# 2  ABELARDO CAMARINHA  PREFEITURA MUNICIPAL DE  FLÓRIDA PAULISTA
# 3  ABELARDO CAMARINHA              PREFEITURA MUNICIPAL DE GÁLIA
# 4  ABELARDO CAMARINHA              PREFEITURA MUNICIPAL DE GARÇA
# 5  ABELARDO CAMARINHA          PREFEITURA MUNICIPAL DE  GETULINA
#
#           MUNICÍPIO                CNPJ        OBJETO SECRETARIA / \nÓRGÃO  \
# 1            BASTOS  45.547.403/0001-93  PLANEJAMENTO       INFRAESTRUTURA
# 2  FLÓRIDA PAULISTA  44.925.691/0001-00  PLANEJAMENTO       INFRAESTRUTURA
# 3             GÁLIA  44.518.389/0001-37  PLANEJAMENTO       INFRAESTRUTURA
# 4             GARÇA  44.518.371/0001-35  PLANEJAMENTO       INFRAESTRUTURA
# 5          GETULINA  44.528.842/0001-96  PLANEJAMENTO       INFRAESTRUTURA
#
#       VALOR
# 1  250000.0
# 2  200000.0
# 3  250000.0
# 4  100000.0
# 5  100000.0

# %%
# df2.to_excel('ldo_2019_emendas_exceto_saude.xlsx', index=False)

# %%
df = pd.read_excel('2019/ldo_2019_emendas_exceto_saude.xlsx')

# %%
df.groupby(by=['DEPUTADO (A)']).sum().sort_values(by='VALOR', ascending=False)
# Out:
#                                        VALOR
# DEPUTADO (A)
# ABELARDO CAMARINHA                   2453970
# JOÃO PAULO RILLO                     2453970
# MARIA LÚCIA AMARY                    2453970
# MARCOS ZERBINI                       2453970
# MARCOS MARTINS                       2453970
# MARCOS DAMASIO                       2453970
# MARCO VINHOLI                        2453970
# MARCIO CAMARGO                       2453970
# LUIZ CARLOS GONDIM                   2453970
# LEO OLIVEIRA                         2453970
# JOÃO CARAMEZ                         2453970
# GERALDO CRUZ                         2453970
# JOSÉ ZICO PRADO                      2453970
# JORGE WILSON  XERIFE DO  CONSUMIDOR  2453970
# JORGE CARUSO                         2453970
# JOOJI HATO                           2453970
# ITAMAR BORGES                        2453970
# GILMAR GIMENES                       2453970
# GILMACI SANTOS                       2453970
# GILENO GOMES                         2453970
# MARTA COSTA                          2453970
# MILTON VIEIRA                        2453970
# ORLANDO BOLÇONE                      2453970
# PAULO CORRÊA JR.                     2453970
# WELLINGTON MOURA                     2453970
# VITOR SAPIENZA                       2453970
# VAZ DE LIMA                          2453970
# TEONILIO BARBA                       2453970
# SEBASTIÃO SANTOS                     2453970
# ROQUE BARBIERE                       2453970
# ROBERTO TRIPOLI                      2453970
# ROBERTO MORAIS                       2453970
# RITA PASSOS                          2453970
# RICARDO MADALENA                     2453970
# REINALDO ALGUZ                       2453970
# RAUL MARCELO                         2453970
# RAMALHO DA  CONSTRUÇÃO               2453970
# RAFAEL SILVA                         2453970
# PROF. AURIEL                         2453970
# PEDRO TOBIAS                         2453970
# PEDRO KAKÁ                           2453970
# GIL LANCASTER                        2453970
# HÉLIO NISHIMOTO                      2453970
# FERNANDO CURY                        2453970
# CARLOS BEZERRA JR                    2453970
# CELSO NASCIMENTO                     2453970
# CELINO CARDOSO                       2453970
# FERNANDO CAPEZ                       2453970
# CAUÊ MACRIS                          2453970
# CARLÃO PIGNATARI                     2453970
# CARLOS NEDER                         2453970
# CARLOS GIANNAZI                      2453970
# CARLOS CEZAR                         2453970
# CAMPOS MACHADO                       2453970
# CLELIA GOMES                         2453970
# BETH SAHÃO                           2453970
# BARROS MUNHOZ                        2453970
# ANDRÉ SOARES                         2453970
# ANDRÉ DO PRADO                       2453970
# ANALICE FERNANDES                    2453970
# ANA DO CARMO                         2453970
# ALENCAR SANTANA  BRAGA               2453970
# AFONSO LOBATO                        2453970
# CHICO SARDELLI                       2453970
# WELSON GASPARINI                     2453970
# CORONEL CAMILO                       2453970
# DAVI ZAIA                            2453970
# FELICIANO FILHO                      2453970
# ESTEVAM GALVÃO                       2453970
# ENIO TATTO                           2453970
# CÉLIA LEÃO                           2453970
# EDMIR CHEDID                         2453970
# ED THOMAS                            2453970
# CORONEL TELHADA                      2453970
# DOUTOR ULYSSES                       2453970
# DELEGADO OLIM                        2453970
# GUSTAVO PETTA                        2453000
# CAIO FRANÇA                          2453000
# CEZINHA DE  MADUREIRA                2453000
# LUIZ TURCO                           2453000
# MÁRCIA LIA                           2453000
# LUIZ FERNANDO  TEIXEIRA              2453000
# EDSON GIRIBONI                       2450000
# RODRIGO MORAES                       2450000
# ALDO DEMARCHI                        2450000
# ADILSON ROSSI                        2450000
# ROGÉRIO NOGUEIRA                     2450000
# MILTON LEITE FILHO                   2450000
# ROBERTO MASSAFERA                    2450000
# ROBERTO ENGLER                       2450000
# JOSÉ AMÉRICO                         2450000
# ANTONIO SALIM  CURIATI               2445000
# LECI BRANDÃO                         2160000
# CÁSSIO NAVARRO                       1453970
# CASSIONAVARRO                         500000
# CASSIO NAVARRO                        500000
# LECI BRANDAO                          293970

# %%
df.groupby(by=['OBJETO']).sum().sort_values(by='VALOR', ascending=False).head(10)
# Out:
#                                            VALOR
# OBJETO
# PLANEJAMENTO                            76020220
# DESENVOLVIMENTO  SOCIAL                 34544610
# PLANEJAMENTO E  GESTÃO                  29509260
# SAÚDE                                   12108880
# SECRETARIA DE  PLANEJAMENTO E  GESTÃO    9484940
# *                                        9361880
# CULTURA                                  6125910
# SECRETARIA DE  DESENVOLVIMENTO  SOCIAL   5962970
# EDUCAÇÃO                                 4220000
# ESPORTE                                  3253970

# %%
df.sort_values(by='VALOR', ascending=False).head(10)
# Out:
#            DEPUTADO (A) ENTIDADE / PREFEITURA \nBENEFICIADA  MUNICÍPIO  \
# 87    ANALICE FERNANDES                                   *          *
# 654      GILMACI SANTOS                                   *          *
# 99         ANDRÉ SOARES             PREFEITURA DE SÃO PAULO  SÃO PAULO
# 1058      MILTON VIEIRA                                   *          *
# 553     FELICIANO FILHO                PREFEITURA MUNICIPAL  GUARULHOS
# 179    CARLÃO PIGNATARI                                   *          *
# 774          JOOJI HATO                                   *          *
# 259         CAUÊ MACRIS                                   *          *
# 401       DELEGADO OLIM                                   *          *
# 1185     REINALDO ALGUZ                                   *          *
#
#                     CNPJ        OBJETO        SECRETARIA / \nÓRGÃO    VALOR
# 87                     *  PLANEJAMENTO                           *  2453970
# 654                    *             *                           *  2453970
# 99    46.395.000/0001-39         SAÚDE  AQUISIÇÃO DE  EQUIPAMENTOS  2453970
# 1058                   *             *                           *  2453970
# 553   46.319.000/0001-50         SAÚDE        DESPESAS DE  CUSTEIO  2453970
# 179                    *  PLANEJAMENTO                           *  2453970
# 774                    *             *                           *  2453970
# 259                    *  PLANEJAMENTO                           *  2453970
# 401                    *           NaN                           *  2453970
# 1185                   *  PLANEJAMENTO                           *  2378970

# %%
df.columns
# Out:
# Index(['DEPUTADO (A)', 'ENTIDADE / PREFEITURA \nBENEFICIADA', 'MUNICÍPIO',
#        'CNPJ', 'OBJETO', 'SECRETARIA / \nÓRGÃO', 'VALOR'],
#       dtype='object')
