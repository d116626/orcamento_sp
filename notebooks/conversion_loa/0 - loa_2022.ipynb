# %%
import pandas as pd
import numpy as np


pd.options.display.max_columns = 999
pd.options.display.max_rows = 1999
pd.options.display.max_colwidth = 100

import warnings
warnings.filterwarnings('ignore')

from tabula import read_pdf
# import camelot

# %% [markdown]
# ### COMPARACAO

# %%
def normalize_cols(df):
    return (
        df.str.normalize("NFKD")
        .str.encode("ascii", errors="ignore")
        .str.decode("utf-8")
        .str.replace("$", "")
        .str.replace("(", "")
        .str.replace(")", "")
        .str.replace("-", "")
        .str.replace(" ", "_")
        .str.replace("/", "_")
        .str.replace("__", "_")
        .str.replace("___", "_")
        .str.lower()
        .str.replace(".", "")
    )

# %%
df_2022 = pd.read_excel('../../data/loa/loa_2022/loa_2022.xlsx')
df_2022.columns = normalize_cols(df_2022.columns)
df_2022 = df_2022.rename(columns = {'valor':'dotacao_2022'})
df_2022['codigo_da_acao'] = df_2022['codigo_da_acao'].str.replace('.','')
dd = df_2022[['codigo_da_acao','dotacao_2022']]

# %%
df_2021 = pd.read_csv('../../data/orcamento_consolidado/despesas/orcamento_2021.csv', encoding='latin1')
df_2021['codigo da acao'] = df_2021['Funcional Programática'].apply(lambda x: str(x).split(' -')[0][:-4])
df_2021.columns = normalize_cols(df_2021.columns)


cols = ['orgao', 'uo', 'unidade_gestora', 'fonte_de_recursos', 'funcao',
       'sub_funcao', 'programa', 'acao', 'funcional_programatica', 'elemento',
       'dotacao_inicial', 'codigo_da_acao']
df_2021 = df_2021[cols]

df_2021 = df_2021.rename(columns = {'dotacao_inicial':'dotacao_2021'})

# %%
df.head()
# Out:
#                             orgao                              uo  \
# 0  01000 - ASSEMBLEIA LEGISLATIVA  01001 - ASSEMBLEIA LEGISLATIVA
# 1  01000 - ASSEMBLEIA LEGISLATIVA  01001 - ASSEMBLEIA LEGISLATIVA
# 2  01000 - ASSEMBLEIA LEGISLATIVA  01001 - ASSEMBLEIA LEGISLATIVA
# 3  01000 - ASSEMBLEIA LEGISLATIVA  01001 - ASSEMBLEIA LEGISLATIVA
# 4  01000 - ASSEMBLEIA LEGISLATIVA  01001 - ASSEMBLEIA LEGISLATIVA
#
#                    unidade_gestora  \
# 0  010010 - ASSEMBLEIA LEGISLATIVA
# 1  010101 - ASSEMBLEIA LEGISLATIVA
# 2  010010 - ASSEMBLEIA LEGISLATIVA
# 3  010010 - ASSEMBLEIA LEGISLATIVA
# 4  010101 - ASSEMBLEIA LEGISLATIVA
#
#                               fonte_de_recursos            funcao  \
# 0  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR  01 - LEGISLATIVA
# 1  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR  01 - LEGISLATIVA
# 2  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR  01 - LEGISLATIVA
# 3  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR  01 - LEGISLATIVA
# 4  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR  01 - LEGISLATIVA
#
#                sub_funcao                     programa  \
# 0  031 - ACAO LEGISLATIVA  0150 - PROCESSO LEGISLATIVO
# 1  031 - ACAO LEGISLATIVA  0150 - PROCESSO LEGISLATIVO
# 2  031 - ACAO LEGISLATIVA  0150 - PROCESSO LEGISLATIVO
# 3  031 - ACAO LEGISLATIVA  0150 - PROCESSO LEGISLATIVO
# 4  031 - ACAO LEGISLATIVA  0150 - PROCESSO LEGISLATIVO
#
#                                                        acao  \
# 0  12150000 - EXPANSAO E ADEQUACAO INSTALACOES PAL. 9 JULHO
# 1  12150000 - EXPANSAO E ADEQUACAO INSTALACOES PAL. 9 JULHO
# 2          45080000 - DIVULGACAO DOS TRABALHOS LEGISLATIVOS
# 3          45080000 - DIVULGACAO DOS TRABALHOS LEGISLATIVOS
# 4          45080000 - DIVULGACAO DOS TRABALHOS LEGISLATIVOS
#
#                                               funcional_programatica  \
# 0  01031015012150000 - EXPANSAO E ADEQUACAO INSTALACOES PAL. 9 JULHO
# 1  01031015012150000 - EXPANSAO E ADEQUACAO INSTALACOES PAL. 9 JULHO
# 2          01031015045080000 - DIVULGACAO DOS TRABALHOS LEGISLATIVOS
# 3          01031015045080000 - DIVULGACAO DOS TRABALHOS LEGISLATIVOS
# 4          01031015045080000 - DIVULGACAO DOS TRABALHOS LEGISLATIVOS
#
#                                                 elemento  \
# 0  339039 - OUTROS SERVICOS DE TERCEIROS-PESSOA JURIDICA
# 1  339039 - OUTROS SERVICOS DE TERCEIROS-PESSOA JURIDICA
# 2  339039 - OUTROS SERVICOS DE TERCEIROS-PESSOA JURIDICA
# 3             339040 - SERVICOS DE TI E COMUNICACAO - PJ
# 4                           339030 - MATERIAL DE CONSUMO
#
#               dotacao_2021 codigo_da_acao  dotacao_2022 _merge
# 0                    10,00  0103101501215          10.0   both
# 1                     0,00  0103101501215          10.0   both
# 2            13.860.042,00  0103101504508    20143228.0   both
# 3             6.881.328,00  0103101504508    20143228.0   both
# 4                     0,00  0103101504508    20143228.0   both

# %%
df.groupby('orgaos').sum()
# Out:
#                                                                numero de acoes  \
# orgaos
# ÓRGÃO:   01000 - ASSEMBLEIA LEGISLATIVA                                    126
# ÓRGÃO:   02000 - TRIBUNAL DE CONTAS DO ESTADO                               32
# ÓRGÃO:   03000 - TRIBUNAL DE JUSTIÇA                                       216
# ÓRGÃO:   06000 - TRIBUNAL DE JUSTIÇA MILITAR                                21
# ÓRGÃO:   08000 - SECRETARIA DA EDUCAÇÃO                                   1242
# ÓRGÃO:   09000 - SECRETARIA DA SAÚDE                                       987
# ÓRGÃO:   10000 - SECRETARIA DE DESENVOLVIMENTO ECONÔMICO                  1691
# ÓRGÃO:   12000 - SECRETARIA DA CULTURA E ECONOMIA CRIATIVA                 211
# ÓRGÃO:   13000 - SECRETARIA DE AGRICULTURA E ABASTECIMENTO                 908
# ÓRGÃO:   16000 - SECRETARIA DE LOGÍSTICA E TRANSPORTES                     431
# ÓRGÃO:   17000 - SECRETARIA DA JUSTIÇA E CIDADANIA                         620
# ÓRGÃO:   18000 - SECRETARIA DA SEGURANÇA PÚBLICA                           939
# ÓRGÃO:   20000 - SECRETARIA  DA  FAZENDA  E PLANEJAMENTO                   395
# ÓRGÃO:   21000 - ADMINISTRAÇÃO GERAL DO ESTADO                              61
# ÓRGÃO:   25000 - SECRETARIA DA HABITAÇÃO                                    96
# ÓRGÃO:   26000 - SECRETARIA DE INFRAESTRUTURA E MEIO AMBIENTE             2193
# ÓRGÃO:   27000 - MINISTÉRIO PÚBLICO                                        136
# ÓRGÃO:   28000 - CASA CIVIL                                                 10
# ÓRGÃO:   29000 - SECRETARIA DE DESENVOLVIMENTO REGIONAL                    260
# ÓRGÃO:   35000 - SECRETARIA DE DESENVOLVIMENTO SOCIAL                      261
# ÓRGÃO:   37000 - SECRETARIA DOS TRANSPORTES METROPOLITANOS                 537
# ÓRGÃO:   38000 - SECRETARIA DA ADMINISTRAÇÃO PENITENCIÁRIA                 655
# ÓRGÃO:   39000 - SECRETARIA DE  PROJETOS E AÇÕES ESTRATÉGICAS               26
# ÓRGÃO:   40000 - PROCURADORIA GERAL DO ESTADO                              119
# ÓRGÃO:   41000 - SECRETARIA DE ESPORTES                                    110
# ÓRGÃO:   42000 - DEFENSORIA PÚBLICA DO ESTADO                              120
# ÓRGÃO:   47000 - SEC. DOS DIREITOS DA PESSOA COM DEFICIÊNCIA                72
# ÓRGÃO:   50000 - SECRETARIA DE TURISMO E VIAGENS                            58
# ÓRGÃO:   51000 - SECRETARIA DE GOVERNO                                     348
# ÓRGÃO:   52000 - SECRETARIA ESP. DE  RELAÇÕES INTERNACIONAIS                 3
# ÓRGÃO:   53000 - SECRETARIA DE ORÇAMENTO E GESTÃO                          304
# ÓRGÃO:   99000 - RESERVA DE CONTINGÊNCIA                                     1
#
#                                                                        meta  \
# orgaos
# ÓRGÃO:   01000 - ASSEMBLEIA LEGISLATIVA                        5.626200e+04
# ÓRGÃO:   02000 - TRIBUNAL DE CONTAS DO ESTADO                  9.218000e+03
# ÓRGÃO:   03000 - TRIBUNAL DE JUSTIÇA                           5.629333e+06
# ÓRGÃO:   06000 - TRIBUNAL DE JUSTIÇA MILITAR                   1.090500e+04
# ÓRGÃO:   08000 - SECRETARIA DA EDUCAÇÃO                        4.308475e+07
# ÓRGÃO:   09000 - SECRETARIA DA SAÚDE                           3.496194e+08
# ÓRGÃO:   10000 - SECRETARIA DE DESENVOLVIMENTO ECONÔMICO       3.697714e+07
# ÓRGÃO:   12000 - SECRETARIA DA CULTURA E ECONOMIA CRIATIVA     1.758816e+07
# ÓRGÃO:   13000 - SECRETARIA DE AGRICULTURA E ABASTECIMENTO     2.021257e+07
# ÓRGÃO:   16000 - SECRETARIA DE LOGÍSTICA E TRANSPORTES         9.694140e+06
# ÓRGÃO:   17000 - SECRETARIA DA JUSTIÇA E CIDADANIA             3.065998e+06
# ÓRGÃO:   18000 - SECRETARIA DA SEGURANÇA PÚBLICA               9.019795e+07
# ÓRGÃO:   20000 - SECRETARIA  DA  FAZENDA  E PLANEJAMENTO       6.441100e+04
# ÓRGÃO:   21000 - ADMINISTRAÇÃO GERAL DO ESTADO                 0.000000e+00
# ÓRGÃO:   25000 - SECRETARIA DA HABITAÇÃO                       2.411680e+05
# ÓRGÃO:   26000 - SECRETARIA DE INFRAESTRUTURA E MEIO AMBIENTE  9.751519e+07
# ÓRGÃO:   27000 - MINISTÉRIO PÚBLICO                            1.080000e+02
# ÓRGÃO:   28000 - CASA CIVIL                                    0.000000e+00
# ÓRGÃO:   29000 - SECRETARIA DE DESENVOLVIMENTO REGIONAL        1.439000e+03
# ÓRGÃO:   35000 - SECRETARIA DE DESENVOLVIMENTO SOCIAL          4.787587e+06
# ÓRGÃO:   37000 - SECRETARIA DOS TRANSPORTES METROPOLITANOS     1.525778e+08
# ÓRGÃO:   38000 - SECRETARIA DA ADMINISTRAÇÃO PENITENCIÁRIA     1.868295e+05
# ÓRGÃO:   39000 - SECRETARIA DE  PROJETOS E AÇÕES ESTRATÉGICAS  5.000000e+02
# ÓRGÃO:   40000 - PROCURADORIA GERAL DO ESTADO                  1.143200e+04
# ÓRGÃO:   41000 - SECRETARIA DE ESPORTES                        2.647650e+05
# ÓRGÃO:   42000 - DEFENSORIA PÚBLICA DO ESTADO                  1.446146e+06
# ÓRGÃO:   47000 - SEC. DOS DIREITOS DA PESSOA COM DEFICIÊNCIA   1.602400e+04
# ÓRGÃO:   50000 - SECRETARIA DE TURISMO E VIAGENS               8.270000e+02
# ÓRGÃO:   51000 - SECRETARIA DE GOVERNO                         1.899546e+08
# ÓRGÃO:   52000 - SECRETARIA ESP. DE  RELAÇÕES INTERNACIONAIS   9.000000e+00
# ÓRGÃO:   53000 - SECRETARIA DE ORÇAMENTO E GESTÃO              2.425950e+07
# ÓRGÃO:   99000 - RESERVA DE CONTINGÊNCIA                       0.000000e+00
#
#                                                                       valor  \
# orgaos
# ÓRGÃO:   01000 - ASSEMBLEIA LEGISLATIVA                        1.287450e+09
# ÓRGÃO:   02000 - TRIBUNAL DE CONTAS DO ESTADO                  1.082664e+09
# ÓRGÃO:   03000 - TRIBUNAL DE JUSTIÇA                           1.352414e+10
# ÓRGÃO:   06000 - TRIBUNAL DE JUSTIÇA MILITAR                   7.315575e+07
# ÓRGÃO:   08000 - SECRETARIA DA EDUCAÇÃO                        4.219810e+10
# ÓRGÃO:   09000 - SECRETARIA DA SAÚDE                           2.639025e+10
# ÓRGÃO:   10000 - SECRETARIA DE DESENVOLVIMENTO ECONÔMIC
- SECRETARIA DE INFRAESTRUTURA E MEIO AMBIENTE       240
# ÓRGÃO:   27000 - MINISTÉRIO PÚBLICO                                  17
# ÓRGÃO:   28000 - CASA CIVIL                                           6
# ÓRGÃO:   29000 - SECRETARIA DE DESENVOLVIMENTO REGIONAL              66
# ÓRGÃO:   35000 - SECRETARIA DE DESENVOLVIMENTO SOCIAL                62
# ÓRGÃO:   37000 - SECRETARIA DOS TRANSPORTES METROPOLITANOS           67
# ÓRGÃO:   38000 - SECRETARIA DA ADMINISTRAÇÃO PENITENCIÁRIA          121
# ÓRGÃO:   39000 - SECRETARIA DE  PROJETOS E AÇÕES ESTRATÉGICAS        11
# ÓRGÃO:   40000 - PROCURADORIA GERAL DO ESTADO                        23
# ÓRGÃO:   41000 - SECRETARIA DE ESPORTES                              21
# ÓRGÃO:   42000 - DEFENSORIA PÚBLICA DO ESTADO                        15
# ÓRGÃO:   47000 - SEC. DOS DIREITOS DA PESSOA COM DEFICIÊNCIA         12
# ÓRGÃO:   50000 - SECRETARIA DE TURISMO E VIAGENS                     20
# ÓRGÃO:   51000 - SECRETARIA DE GOVERNO                               83
# ÓRGÃO:   52000 - SECRETARIA ESP. DE  RELAÇÕES INTERNACIONAIS          3
# ÓRGÃO:   53000 - SECRETARIA DE ORÇAMENTO E GESTÃO                    76
# ÓRGÃO:   99000 - RESERVA DE CONTINGÊNCIA                              1

# %% [markdown]
# ### LDO 2018-2022

# %%
dd = read_pdf('../../files/loa_2022.pdf', pages='130-130' ,multiple_tables=True, encoding='utf-8', lattice=True)

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i]], axis=0)
    
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                                        QUADRO XII  \
# 0   EVOLUÇÃO DA DESPESA DO ESTADO POR PODER E ÓRGÃO - 2018 A 2022
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# 5                                                             NaN
# 6                                                             NaN
# 7                                                             NaN
# 8                                                             NaN
# 9                                                             NaN
# 10                                                            NaN
# 11                                                            NaN
# 12                                                            NaN
# 13                                                            NaN
# 14                                                            NaN
# 15                                                            NaN
# 16                                                            NaN
# 17                                                            NaN
# 18                                                            NaN
# 19                                                            NaN
# 20                                                            NaN
# 21                                                            NaN
# 22                                                            NaN
# 23                                                            NaN
# 24                                                            NaN
# 25                                                            NaN
# 26                                                            NaN
# 27                                                            NaN
# 28                                                            NaN
# 29                                                            NaN
# 30                                                            NaN
# 31                                                            NaN
# 32                                                            NaN
# 33                                                            NaN
# 34                                                            NaN
# 35                                                            NaN
# 36                                                            NaN
# 37                                                            NaN
# 38                                                            NaN
# 39                                                            NaN
# 40                                                            NaN
# 41                                                            NaN
# 42                                                            NaN
# 43                                                            NaN
# 44                                                            NaN
#
#                                       Unnamed: 0        Unnamed: 1  \
# 0                                            NaN               NaN
# 1                                            NaN         REALIZADA
# 2                                  PODER / ÓRGÃO              2018
# 3                                    LEGISLATIVO     2.091.598.251
# 4                         ASSEMBLEIA LEGISLATIVA     1.160.359.153
# 5                   TRIBUNAL DE CONTAS DO ESTADO       931.239.098
# 6                                     JUDICIÁRIO    12.518.567.844
# 7                            TRIBUNAL DE JUSTIÇA    12.451.318.956
# 8                    TRIBUNAL DE JUSTIÇA MILITAR        67.248.888
# 9                             MINISTÉRIO PÚBLICO     2.566.115.242
# 10                            MINISTÉRIO PÚBLICO     2.566.115.242
# 11                            DEFENSORIA PÚBLICA       838.023.627
# 12                  DEFENSORIA PÚBLICA DO ESTADO       838.023.627
# 13                                     EXECUTIVO   223.171.295.687
# 14    34.290.764.396    33.952.208.167    35.102.900.752     42.198.106.261
# 15    23.557.207.095    26.961.790.596    23.642.716.764     26.342.921.375
# 16    15.883.823.291    16.154.079.373    17.443.806.730     21.279.860.117
# 17       785.068.237     1.014.564.423       810.104.960      1.118.014.916
# 18       736.307.968       928.399.583       734.786.507      1.174.210.410
# 19     3.744.036.660     3.416.125.117     5.806.555.194      9.007.557.673
# 20     2.098.261.083     2.103.385.440     1.980.679.640      2.049.828.956
# 21    22.077.753.659    25.316.377.214    21.316.512.871     23.570.073.192
# 22    41.378.884.654    46.595.288.595     3.416.091.822      4.397.060.648
# 23    73.473.993.548    60.890.808.794    82.045.698.886     93.268.508.702
# 24        30.406.135               NaN               NaN                NaN
# 25       709.760.040       796.961.404       972.990.751      1.366.228.501
# 26     1.930.141.228     2.185.855.605     2.503.384.723      3.742.736.748
# 27        54.967.391        32.239.123        36.517.484        364.147.513
# 28       524.447.810       447.635.874       649.781.066      1.996.585.118
# 29       780.878.988     1.040.800.762       914.705.154      1.303.906.544
# 30     6.446.499.832     7.231.024.872     7.203.095.840     10.129.402.310
# 31     4.131.028.179     4.240.307.133     4.444.456.963      4.810.074.548
# 32       282.074.130               NaN               NaN         31.753.091
# 33     1.663.684.410     2.073.770.524     1.536.623.774      2.044.152.391
# 34       127.412.009       154.503.764       194.751.125        282.841.986
# 35        42.903.542        37.895.513        43.311.945         49.964.980
# 36           707.565               NaN               NaN                NaN
# 37       335.564.427       168.044.779       582.898.813        650.458.701
# 38     3.594.518.751     3.737.464.125     2.363.394.243      2.571.706.410
# 39            52.958            88.792         2.369.894          2.340.293
# 40               NaN               NaN    42.347.725.401     43.114.919.311
# 41               NaN               NaN        51.000.000         61.995.886
# 42   257.506.997.157   257.852.468.254   274.306.209.242    316.810.590.135
# 43  (31.362.731.894)  (36.085.939.843)  (30.253.613.134)   (30.333.202.401)
# 44   226.144.265.264   221.766.528.411   244.052.596.108    286.477.387.734
#
#     Excluídos da Administração Direta os valores referentes às subvenções e receitas próprias das empresas dependentes.
# 0                                                                                                   NaN
# 1                                                                                                   NaN
# 2                                                                                                   NaN
# 3                                                                                                   NaN
# 4                                                                                                   NaN
# 5                                                                                                   NaN
# 6                                                                                                   NaN
# 7                                                                                                   NaN
# 8                                                                                                   NaN
# 9                                                                                                   NaN
# 10                                                                                                  NaN
# 11                                                                                                  NaN
# 12                                                                                                  NaN
# 13                                                                                                  NaN
# 14                                                                                                  NaN
# 15                                                                                                  NaN
# 16                                                                                                  NaN
# 17                                                                                                  NaN
# 18                                                                                                  NaN
# 19                                                                                                  NaN
# 20                                                                                                  NaN
# 21                                                                                                  NaN
# 22                                                                                                  NaN
# 23                                                                                                  NaN
# 24                                                                                                  NaN
# 25                                                                                                  NaN
# 26                                                                                                  NaN
# 27                                                                                                  NaN
# 28                                                                                                  NaN
# 29                                                                                                  NaN
# 30                                                                                                  NaN
# 31                                                                                                  NaN
# 32                                                                                                  NaN
# 33                                                                                                  NaN
# 34                                                                                                  NaN
# 35                                                                                                  NaN
# 36                                                                                                  NaN
# 37                                                                                                  NaN
# 38                                                                                                  NaN
# 39                                                                                                  NaN
# 40                                                                                                  NaN
# 41                                                                                                  NaN
# 42                                                                                                  NaN
# 43                                                                                                  NaN
# 44                                                                                                  NaN

# %%
# df_ff.to_excel('ldo_2.xlsx', index=False, encoding='utf-8')

# %% [markdown]
# ### LDO PRINCIPAL

# %%
### test - '457-461'
### full - '457-1024'

dd = read_pdf('../../files/loa_2022.pdf', pages='457-1024' ,multiple_tables=True, lattice=True)

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    ddf = dd[i]
    first_row = pd.DataFrame(ddf.columns.tolist()).T
    first_row.columns = [i for i in range(len(first_row.columns))]
    ddf.columns = [i for i in range(len(ddf.columns))]
    ddf = pd.concat([first_row,ddf],0)
    
    df = pd.concat([df,ddf], axis=0)
df = df.reset_index(drop=True)
df['aux']=np.nan

# %%
mask = df[0].str.contains('ÓRGÃO:').replace(np.nan,False)

df_orgao = df[mask]
df_orgao['aux'] = "org"

mask = df[0].str.contains('UNIDADE:').replace(np.nan,False)

df_unidade = df[mask]
df_unidade['aux']='uni'

mask = df[0].str.contains('PROGRAMAÇÃO DA UNIDADE ORÇAMENTÁRIA').replace(np.nan,False)

df_programacao = df[mask]
df_programacao['aux']='prog'

# indexes = list(df_programas.index)

# %%
df_include = pd.concat([df_orgao, df_unidade,df_programacao], axis=0).sort_index()

includes = df_include['aux'].tolist()

l3=[]
for i in range(len(includes)-2):
    if (includes[i]=='org') & (includes[i+1]=='uni') & (includes[i+2]=='prog'):
        l3.append(1)
    else:
        l3.append(0)
l3.append(1)
l3.append(1)

l4=[]        
for i in range(len(includes)-2):       
    if (includes[i-1]=='org') & (includes[i]=='uni') & (includes[i+1]=='prog'):
        l4.append(1)
    else:
        l4.append(0)
l4.append(1)
l4.append(1)

l5=[]
for i in range(len(includes)-2):       
    if (includes[i-2]=='org') & (includes[i-1]=='uni') & (includes[i]=='prog'):
        l5.append(1)
    else:
        l5.append(0)    
l5.append(1)
l5.append(1) 

df_include[3]=l3
df_include[4]=l4
df_include[5]=l5

df_include[6] = df_include[[3,4,5]].any(axis=1)
df_include[1]=df_include[2]
df_include[2]=df_include[6]
df_include = df_include.drop(columns=[3,4,5,6,7])

# %%
indexes = df_include.index.tolist()
ranges = df_include[2].tolist()

exclude_ranges=[]
for i in range(len(ranges)-1):
    if (ranges[i]==False) & (ranges[i+1]==True):
        exclude_ranges.append([indexes[i],indexes[i+1]])
    elif (ranges[i]==False) & (ranges[i+1]==False):
        exclude_ranges.append([indexes[i],indexes[i+1]])

# %%
df2 = df.copy()

for exclude in exclude_ranges:
    print(exclude[0],exclude[1])
    df2.drop(df.index[exclude[0]:exclude[1]], inplace=True)
# Out:
# 3 104
# 218 282
# 355 448
# 574 622
# 688 774
# 892 973
# 1087 1347
# 1347 1612
# 2840 3306
# 3306 3697
# 5078 5563
# 5563 5776
# 7255 7465
# 7465 7631
# 7983 8203
# 8203 8404
# 8709 8988
# 8988 9086
# 9617 9919
# 9919 10033
# 10663 11010
# 11010 11381
# 12120 12336
# 12336 12577
# 13131 13244
# 13244 13364
# 13598 13775
# 13775 13939
# 14167 14807
# 14807 15300
# 16609 16661
# 16661 16712
# 16773 16959
# 16959 17108
# 17555 17792
# 17792 18000
# 18548 18898
# 18898 19135
# 19664 19845
# 19845 20023
# 20804 20894
# 20894 20973
# 21076 21208
# 21208 21307
# 21444 21567
# 21567 21674
# 21831 21906
# 21906 21971
# 22059 22169
# 22169 22269
# 22432 22791
# 22791 22991
# 23712 23750
# 23750 23784
# 23821 24147
# 24147 24373
# 24908 24937
# 24937 24967
# 25006 25078
# 25078 25128
# 25128 25179
# 25179 25231
# 25231 25403
# 25403 25480
# 25480 25536
# 25536 25692

# %%
mask = df2[0].str.contains('ÓRGÃO:').replace(np.nan,False)
df_orgao = df2[mask]
df_orgao=df_orgao[[0]]
# df_orgao[1] = "org"

mask = df2[0].str.contains('UNIDADE:').replace(np.nan,False)
df_unidade = df2[mask]
df_unidade=df_unidade[[0]]
df_unidade[1]='uni'

mask = df2[0].str.contains('PROGRAMAÇÃO DA UNIDADE ORÇAMENTÁRIA').replace(np.nan,False)
df_programacao = df2[mask]
df_programacao=df_programacao[[0]]
df_programacao[1]='prog'

# indexes = list(df_programas.index)

# %%
indexes = df_orgao.index.tolist()
orgs = df_orgao[0].tolist()
unidades = df_unidade[0].tolist()

df_aux = pd.DataFrame([1])
df_final = pd.DataFrame()

for i in range(len(unidades)):   
    
#     print(unidades[i])

    if i == len(indexes)-1:
        df_f = df2.loc[indexes[i]:]
        mask = df_f[0].str.contains('PROGRAMA:').replace(np.nan,False)
        programas = df_f[mask][0].tolist()
        prog_index = df_f[mask][0].index.tolist()
        
        
        for j in range(len(programas)):
#             print(programas[j])
            
            if j == len(programas)-1:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:]    
                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))
                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                
            else:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:prog_index[j+1]-1]
                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                mask = df_ff[0]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))
                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)
                        
                        
                        
                        
                        
    else:
        
        df_f = df2.loc[indexes[i]:indexes[i+1]]
        mask = df_f[0].str.contains('PROGRAMA:').replace(np.nan,False)
        programas = df_f[mask][0].tolist()
        prog_index = df_f[mask][0].index.tolist()

        for j in range(len(programas)):
#             print(programas[j])
            if j == len(programas)-1:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:]   
#                 display(df_ff)
#                 display(df_ff)

                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))
                
                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                
            else:
                #separa projetos
                df_ff = df_f.loc[prog_index[j]:prog_index[j+1]-1]
                mask = df_ff[0].str.contains('AÇÃO', regex=True).replace(np.nan,False)
                acoes = df_ff[mask]
                mask = df_ff[0]
                acoes['leng'] = acoes[0].apply(lambda x: len(x))
                mask = acoes['leng']==4
                acoes = acoes[mask]
                acoes_index = acoes[mask][0].index.tolist()
#                 print(len(acoes_index))

                for k in range(len(acoes_index)):
                    #separa as açoes
                    
                    if k == len(acoes)-1:
                        df_acao = df_ff.loc[acoes_index[k]:]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j] 
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)

                    else:
                        
                        df_acao = df_ff.loc[acoes_index[k]:acoes_index[k+1]-1]
                        df_acao['orgaos'] = orgs[i]
                        df_acao['unidade'] = unidades[i]
                        df_acao['programas'] = programas[j]
                        df_acao['numero de acoes'] = len(acoes_index)
                        df_final = pd.concat([df_final,df_acao], axis=0)
            
#             df_final = pd.concat([df_final,df_aux],axis=0)
            
        
#         print(indexes[i], orgs[i], unidades[i])

# %%
df_final.to_excel('pre_ldo_4.xlsx', index=False, encoding='utf-8')

# %% [markdown]
# ### LDO_4 Revival

# %%
df = pd.read_excel('pre_ldo_4.xlsx')

# %%
df[3] = np.where(df[2]=='FONTE DE RECURSO', 'FONTE DE RECURSO',df[3])
df[2] = np.where(df[1]=='GRUPO DESPESA','GRUPO DESPESA',df[2])
df[1] = np.where(df[0]=='AÇÃO', 'AÇÃO',df[1])
df[0] = np.where(df[0]=='AÇÃO', 'NUMERO DA AÇÃO',df[0])

df[5] = np.where(df[0]=='PRODUTO:', df[1],np.nan)
df[6] = np.where(df[0]=='INDICADOR DE\rPRODUTO:', df[1], np.nan)
df[7] = np.where(df[0]=='META:', df[1], np.nan)


df[1] = np.where((df[0]=='PRODUTO:') | (df[0]=='INDICADOR DE\rPRODUTO:') | (df[0]=='META:'), np.nan,df[1])
df[0] = np.where((df[0]=='PRODUTO:') | (df[0]=='INDICADOR DE\rPRODUTO:') | (df[0]=='META:'), np.nan,df[0])


df[5] = np.where(df[0]=='NUMERO DA AÇÃO', 'PRODUTO',df[5])
df[6] = np.where(df[0]=='NUMERO DA AÇÃO', 'INDICADOR DE PRODUTO',df[6])
df[7] = np.where(df[0]=='NUMERO DA AÇÃO', 'META',df[7])

# %%
df[0].fillna(method='ffill', inplace=True)
df[1].fillna(method='ffill', inplace=True)
df[2].fillna(method='ffill', inplace=True)
df[5].fillna(method='bfill', inplace=True)
df[6].fillna(method='bfill', inplace=True)
df[7].fillna(method='bfill', inplace=True)

#remove os nulls das fontes de recurso
mask = df[3].notnull()
df = df[mask]

#remove os nulls dos valores
mask = df[4].notnull()
df = df[mask]

# coloca nan nas linhas que nao possuem meta
df[7] = np.where(df[7]=='META', np.nan, df[7])

# df = df.drop(columns=[8])

# %%
rename = {
    0:'codigo da acao',
    1:'acao',
    2:'grupo despesa',
    3:'fonte de recurso',
    4:'valor',
    5:'produto',
    6:'indicador de produto',
    7:'meta'
}

df = df.rename(columns=rename)

# %%
df.columns
# Out:
# Index([      'codigo da acao',                 'acao',        'grupo despesa',
#            'fonte de recurso',                'valor',              'produto',
#        'indicador de produto',                 'meta',                      8,
#                         'aux',               'orgaos',              'unidade',
#                   'programas',      'numero de acoes'],
#       dtype='object')

# %%
cols = [
    'orgaos', 'unidade',
    'programas', 
    'codigo da acao', 'acao','numero de acoes',
    'produto','indicador de produto', 
    'grupo despesa', 'fonte de recurso', 
    'meta','valor'
]

df = df[cols]

# %%
mask = (df['acao']=='AÇÃO') | (df['valor'].str.contains('Unnamed'))
df = df[np.logical_not(mask)]

# %%
for col in df.columns:
    if (col!='numero de acoes'):
        df[col] = df[col].str.replace('\r',' ')
    
    
df['valor'] =  df['valor'].str.replace('.','').str.replace(',','.').astype(float)
df['meta']  =  df['meta'].str.replace('.','').str.replace(',','.').astype(float)

# %%
df['contador'] = 1

# %%
replace_values = {
    'UTRAS DESPESAS ORRENTES':'OUTRAS DESPESAS CORRENTES',
    'NVESTIMENTOS':'INVESTIMENTOS ',
    'ESSOAL E ENCARGOS OCIAI':'PESSOAL E ENCARGOS SOCIAIS',
    'NVERSÕES FINANCEIRAS':'INVERSÕES FINANCEIRAS',
    'ESERVA DE ONTINGÊNCIA':'RESERVA DE CONTINGÊNCIA',
    'UROS E ENCARGOS DA ÍVIDA':'JUROS E ENCARGOS DA DÍVIDA',
    'MORTIZAÇÃO DA DÍVIDA':'AMORTIZAÇÃO DA DÍVIDA'
}


df = df.replace({"grupo despesa": replace_values})

# %%
replace_values = {
    'ESOURO DO ESTADO':'TESOURO DO ESTADO',
    'INCULADOS FEDERAIS':'VINCULADOS FEDERAIS',
    'UNDO ESPECIAL DE ESPESA':'FUNDO ESPECIAL DE DESPESA',
    'RÓPRIOS':'PRÓPRIOS',
    'INCULADOS ESTADUAIS':'VINCULADOS ESTADUAIS',
    'UTRAS FONTES - UNDOS':'OUTRAS FONTES - FUNDOS',
    'ESOURO-DOT.INICIAL E RED.SUPLEMENTAR- NTRA':'TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR- INTRA',
    'PERAÇÕES DE RÉDITO':'OPERAÇÕES DE CRÉDITO',
    'UTRAS FONTES - DREM':'OUTRAS FONTES - DREM',
    'ECURSOS INCULADOS-FUNDO SP. DESPESA-INTRA':'RECURSOS VINCULADOS-FUNDO ESP. DESPESA-INTRA',
    'ECURSOS VINCULADOS EDERAIS-INTRA':'RECURSOS VINCULADOS FEDERAIS-INTRA',
    'EC.PROPRIO-ADM.IND.- OT.INIC.CR.SUPL.- NTRA':'REC.PROPRIO-ADM.IND.- DOT.INIC.CR.SUPL.- INTRA',
    'P.CRED.CONTR.EXTERI R-DOT.INIC.CR.SUP- NTRA':'OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-INTRA',
    'UTRAS FONTES DE ECURSOS-INTRA':'OUTRAS FONTES DE RECURSOS-INTRA '
    
}


df = df.replace({"fonte de recurso": replace_values})

# %%
# df['indicador de produto'] = df['indicador de produto'].str.replace('ERCENTUAL','PERCENTUAL').str.replace('ÚMERO','NÚMERO').str.replace('XTENSÃO','EXTENSÃO').str.replace('ENEFICIÁRIOS','BENEFICIÁRIOS')

# df['indicador de produto'] = df['indicador de produto'].str.replace('ERCENTUAL','PERCENTUAL').str.replace('ÚMERO','NÚMERO')

# %%
# mask = (df['valor']==32265100)&(df['codigo da acao']=='roposta Orçamentária 2020')

# df = df.set_value(df[mask].index,'codigo da acao' ,'10.844.0000.9019')
# df = df.set_value(df[mask].index,'acao' ,'PAGAMENTO DA DÍVIDA PÚBLICA EXTERNA')

# mask = (df['valor']==51720442)&(df['codigo da acao']=='roposta Orçamentária 2020')

# df = df.set_value(df[mask].index,'codigo da acao' ,'10.844.0000.9019')
# df = df.set_value(df[mask].index,'acao' ,'PAGAMENTO DA DÍVIDA PÚBLICA EXTERNA')



# mask = (df['valor']==28623000)&(df['codigo da acao']=='roposta Orçamentária 2020')

# df = df.set_value(df[mask].index,'codigo da acao' ,'10.303.0935.4192')
# df = df.set_value(df[mask].index,'acao' ,'ATENDIMENTO HEMOTERÁPICO')




# mask = (df['programas']=='PROGRAMA:     0930    ATENDIMENTO INTEGRAL E DESCENTRALIZADO NO SUS NO ESTADO DE SÃO PAULO') & (df['codigo da acao']=='roposta Orçamentária 2020')

# df = df.set_value(df[mask].index,'codigo da acao' ,'10.302.0930.5274')
# df = df.set_value(df[mask].index,'acao' ,'ASSISTÊNCIA MÉDICA, HOSPITALAR E AMBULATORIAL')



# mask = (df['valor']==2202907)&(df['codigo da acao']=='roposta Orçamentária 2020')

# df = df.set_value(df[mask].index,'codigo da acao' ,'18.542.2604.2622')
# df = df.set_value(df[mask].index,'acao' ,'CONTRAPARTIDAS AMBIENTAIS E CONVÊNIOS')

# %%
# df.groupby(by='acao').sum().sort_values(by='valor',ascending=False)

# %%
# df.head()

# %%
df.groupby(by='unidade').sum()
# Out:
#                                                                   numero de acoes  \
# unidade
# UNIDADE:   01001 - ASSEMBLEIA LEGISLATIVA                                     126
# UNIDADE:   02001 - TRIBUNAL DE CONTAS DO ESTADO                                32
# UNIDADE:   03001 - TRIBUNAL DE JUSTIÇA                                        216
# UNIDADE:   06001 - TRIBUNAL DE JUSTIÇA MILITAR                                 21
# UNIDADE:   08001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE                527
# UNIDADE:   08002 - CONSELHO ESTADUAL DE EDUCAÇÃO-CEE                            5
# UNIDADE:   08009 - COORDENADORIA GESTÃO DE RECURSOS HUMANOS                    39
# UNIDADE:   08010 - ESCOLA FORMAÇÃO PROF.ED.EST.PAULO R.C.SOUZA                 41
# UNIDADE:   08011 - COORDENADORIA PEDAGÓGICA                                   183
# UNIDADE:   08012 - COORD.INFORMAÇÃO,TECNOLOGIA  EVID.E MATRÍCULA               98
# UNIDADE:   08013 - COORD.INFRAESTRUTURA E SERVIÇOS ESCOLARES                  178
# UNIDADE:   08014 - COORDENADORIA DE ORÇAMENTO E FINANÇAS                       32
# UNIDADE:   08046 - FUNDAÇÃO PARA DESENVOLVIMENTO DA EDUCAÇÃO-FDE              139
# UNIDADE:   09012 - FUNDO ESTADUAL DE SAÚDE - FUNDES                           834
# UNIDADE:   09014 - COORDENADORIA DE DEFESA  E SAÚDE ANIMAL                      3
# UNIDADE:   09045 - FUNDAÇÃO REMÉDIO POPULAR CHOPIN LIMA-FURP                   13
# UNIDADE:   09046 - FUNDAÇÃO ONCOCENTRO DE SÃO PAULO                            10
# UNIDADE:   09047 - FUNDAÇÃO PRÓ-SANGUE HEMOCENTRO DE S.PAULO                   14
# UNIDADE:   09055 - SUPERINT. DE CONTROLE DE ENDEMIAS - SUCEN                   13
# UNIDADE:   09056 - HOSP.CLÍNICAS FAC.MEDICINA RIB. PRETO-USP                   31
# UNIDADE:   09057 - HOSP.DAS CLÍNICAS FAC. DE MEDICINA DA USP                   37
# UNIDADE:   09059 - HOSP.CLÍNICAS FAC.MEDICINA BOTUCATU-HCFMB                   19
# UNIDADE:   09060 - HOSP.CLÍNICAS MEDICINA MARÍLIA - HCFAMEMA                   13
# UNIDADE:   10001 - SECRETARIA DE DESENVOLVIMENTO ECONÔMIC
# UNIDADE:   38045 - FUND.PROF.DR.MANOEL PEDRO PIMENTEL-FUNAP             14
# UNIDADE:   39001 - SECRETARIA DE  PROJETOS E AÇÕES ESTRATÉGICAS         11
# UNIDADE:   40001 - PROCURADORIA GERAL DO ESTADO                         23
# UNIDADE:   41001 - SECRETARIA DE ESPORTES                               21
# UNIDADE:   42001 - DEFENSORIA PÚBLICA DO ESTADO                         15
# UNIDADE:   47001 - SEC.DOS DIREITOS DA PESSOA COM DEFICIÊNCIA           12
# UNIDADE:   50001 - ADMINISTRAÇÃO SUPERIOR DA SECRETARIA E SEDE          13
# UNIDADE:   50002 - COORDENADORIA DE TURISMO                              7
# UNIDADE:   51001 - SECRETARIA DE GOVERNO                                19
# UNIDADE:   51003 - CASA MILITAR                                          7
# UNIDADE:   51004 - FUNDO SOCIAL DE SÃO PAULO - FUSSP                    10
# UNIDADE:   51005 - UNIDADE DE COMUNICAÇÃO                                2
# UNIDADE:   51045 - FUNDAÇÃO SIST.ESTADUAL  ANÁLISE  DADOS-SEADE          7
# UNIDADE:   51055 - AGÊNCIA REG.SERV.PÚB.DELEG.TRANSPORTES-ARTESP        13
# UNIDADE:   51056 - AGÊNCIA REG.DE SERVIÇOS PÚBLICOS DE SP-ARSESP        12
# UNIDADE:   51057 - DEPARTAMENTO ESTADUAL DE TRÂNSITO-DETRAN-SP          13
# UNIDADE:   52001 - SECRETARIA  ESP. DE  RELAÇÕES  INTERNACIONAIS         3
# UNIDADE:   53001 - SECRETARIA DE ORÇAMENTO E GESTÃO                     48
# UNIDADE:   53055 - INSTITUTO ASSIST.MÉDICA SERVIDOR PÚB.-IAMSPE         12
# UNIDADE:   53057 - SÃO PAULO PREVIDÊNCIA - SPPREV                       14
# UNIDADE:   53090 - DERSA - DESENVOLVIMENTO RODOVIÁRIO S.A                2
# UNIDADE:   99099 - RESERVA DE CONTINGÊNCIA                               1

# %%
df.to_excel('../../data/loa/loa_2022/loa_2022.xlsx', index=False)

# %% [markdown]
# ### LDO 5

# %%
### test - '339-396'
### full - '846-869'

dd = read_pdf('files/ldo_full.pdf', pages='846-869' ,multiple_tables=True, encoding='utf-8', lattice=True)

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i]], axis=0)
    
df = df.reset_index(drop=True)

# %%
mask = df[0].str.contains('ÓRGÃO:').replace(np.nan,False)

df_orgao = df[mask]
df_orgao[2] = "org"

mask = df[0].str.contains('EMPRESA:').replace(np.nan,False)

df_empresa = df[mask]
df_empresa[2]='uni'

mask = df[0].str.contains('DEMONSTRATIVO DOS INVESTIMENTOS').replace(np.nan,False)

df_demonstrativo = df[mask]
df_demonstrativo[2]='dem'

# indexes = list(df_programas.index)

# %%
df_exclude = pd.concat([df_empresa,df_demonstrativo],axis=0).sort_index()
exclude_list=[df_exclude.index.tolist()[i:i+2] for i in range(0,len(df_exclude.index.tolist()),2)]

# %%
df2 = df.copy()

for exclude in exclude_list:
    print(exclude[0],exclude[1])
    df2.drop(df.index[exclude[0]+1:exclude[1]+1], inplace=True)
# Out:
# 6 38
# 75 107
# 148 178
# 198 229
# 249 280
# 301 338
# 449 483
# 527 560
# 583 617
# 731 762
# 877 910
# 942 974
# 1006 1037

# %%
df_f = df2.copy()

df_f['orgao'] = np.where(df_f[0]=='ÓRGÃO:',df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where(df_f[0]=='ÓRGÃO:',np.nan,df_f[1])
df_f[0] = np.where(df_f[0]=='ÓRGÃO:',np.nan,df_f[0])

df_f['empresa'] = np.where(df_f[0]=='EMPRESA:',df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where(df_f[0]=='EMPRESA:',np.nan,df_f[1])
df_f[0] = np.where(df_f[0]=='EMPRESA:',np.nan,df_f[0])

df_f['programa'] = np.where(df_f[0].str.contains('PROGRAMA:'),df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where((df_f[0].str.contains('PROGRAMA:') & df_f[0].notnull()),np.nan,df_f[1])
df_f[0] = np.where((df_f[0].str.contains('PROGRAMA:') & df_f[0].notnull()),np.nan,df_f[0])

df_f['produto'] = np.where(df_f[0]=='PRODUTO:',df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where(df_f[0]=='PRODUTO:',np.nan,df_f[1])
df_f[0] = np.where(df_f[0]=='PRODUTO:',np.nan,df_f[0])


df_f['indicador de produto'] = np.where(df_f[0]=='INDICADOR\rDE PRODUTO:',df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where(df_f[0]=='INDICADOR\rDE PRODUTO:',np.nan,df_f[1])
df_f[0] = np.where(df_f[0]=='INDICADOR\rDE PRODUTO:',np.nan,df_f[0])


df_f['descricao'] = np.where(df_f[0]=='DESCRIÇÃO:',df_f[0]+" "+df_f[1], np.nan)
df_f[1] = np.where(df_f[0]=='DESCRIÇÃO:',np.nan,df_f[1])
df_f[0] = np.where(df_f[0]=='DESCRIÇÃO:',np.nan,df_f[0])


df_f[2] = df_f[2].str.replace('.','')
df_f[2] = df_f[2].fillna('aaaaaaaaaa')

mask = df_f[2].str.isdigit()
df_f['valor'] = np.where(mask, df_f[2],np.nan)
df_f[2] = np.where(mask, np.nan, df_f[2])

df_f[2] = np.where(df_f[2]=='aaaaaaaaaa', np.nan,df_f[2])
df_f[2] = np.where(df_f[2]=='Valores em R$ 1,00', np.nan,df_f[2])

df_f['acao'] = df_f[2]

df_f = df_f.drop(columns=[2])


mask = df_f[0].apply(lambda x: str(x)[:2].isdigit())
df_f['numero da acao'] = np.where(mask, df_f[0], np.nan)
df_f[0] = np.where(mask, np.nan, df_f[0])


mask = df_f[0]=='OBJETIVO'
objetivo = [i+1 for i in df_f[mask].index.tolist()]
df_f['objetivo'] = 'aaaaaaaaaa'

for i in objetivo:
    df_f = df_f.set_value(i,'objetivo' ,df_f.loc[i][0])
df_f['objetivo'] = np.where(df_f['objetivo']=='aaaaaaaaaa', np.nan,df_f['objetivo'])

    
mask = df_f[1]=='PÚBLICO ALVO'
publico = [i+1 for i in df_f[mask].index.tolist()]
df_f['publico alvo'] = 'aaaaaaaaaa'

for i in publico:
    df_f = df_f.set_value(i,'publico alvo' ,df_f.loc[i][1])
    df_f = df_f.set_value(i,1 ,np.nan)
    df_f = df_f.set_value(i-1,1 ,np.nan)
    
    
df_f['publico alvo'] = np.where(df_f['publico alvo']=='aaaaaaaaaa', np.nan,df_f['publico alvo'])

mask =  (df_f[1].notnull()) & (df_f['valor'].notnull())
df_f['fonte de financiamento'] = np.where(mask, df_f[1],np.nan)

# %%
df_f['orgao'].fillna(method='ffill', inplace=True)
df_f['empresa'].fillna(method='ffill', inplace=True)
df_f['programa'].fillna(method='ffill', inplace=True)
df_f['produto'].fillna(method='bfill', inplace=True)
df_f['indicador de produto'].fillna(method='bfill', inplace=True)
df_f['descricao'].fillna(method='bfill', inplace=True)
df_f['acao'].fillna(method='ffill', inplace=True)
df_f['numero da acao'].fillna(method='bfill', inplace=True)
df_f['objetivo'].fillna(method='bfill', inplace=True)
df_f['publico alvo'].fillna(method='bfill', inplace=True)


mask = df_f['fonte de financiamento'].notna()

df_f = df_f[mask].drop(columns = [0,1,3,4,5])

df_f['valor'] = df_f['valor'].astype(float)

# %%
df_f.columns
# Out:
# Index(['orgao', 'empresa', 'programa', 'produto', 'indicador de produto',
#        'descricao', 'valor', 'acao', 'numero da acao', 'objetivo',
#        'publico alvo', 'fonte de financiamento'],
#       dtype='object')

# %%
cols = [
    'orgao', 'empresa', 'programa', 
    'produto','indicador de produto', 'objetivo', 'descricao',  'publico alvo',
    'numero da acao','acao', 'fonte de financiamento', 'valor'
]

df_f = df_f[cols]


for col in df_f.columns:
    
    if col!='valor':
        df_f[col] = df_f[col].str.replace('\r',' ')

# %%
# df_f.to_excel('ldo_5.xlsx', index=False, encoding='utf-8')

# %%
df_f.groupby(by='programa').sum()
# Out:
#                                                            valor
# programa
# PROGRAMA:1606 MELHORIAS DA MALHA RODOVIÁRIA         1.000000e+01
# PROGRAMA:1608 TRAVESSIAS LITORÂNEAS                 1.000000e+01
# PROGRAMA:2005 FOMENTO AO DESENVOLVIMENTO SOCIOE...  2.571072e+08
# PROGRAMA:2027 GESTÃO DE SERVIÇOS PRESTADOS À AD...  1.000000e+01
# PROGRAMA:2028 GESTÃO INOVADORA E ORIENTADA PARA...  1.000000e+01
# PROGRAMA:2505 FOMENTO À HABITAÇÃO DE INTERESSE ...  7.275540e+06
# PROGRAMA:2507 REGULARIZAÇÃO FUNDIÁRIA DE INTERE...  6.043646e+07
# PROGRAMA:2508 PROVISÃO DE MORADIAS                  6.377098e+08
# PROGRAMA:2510 REQUALIFICAÇÃO HABITACIONAL E URBANA  4.846704e+08
# PROGRAMA:2624 ABASTECIMENTO DE ÁGUA E ESGOTAMEN...  3.623350e+09
# PROGRAMA:2626 FOMENTO AOS PROJETOS HIDROENERGÉT...  1.257381e+08
# PROGRAMA:3706 EXPANSÃO, MODERNIZAÇÃO E GESTÃO D...  2.257126e+08
# PROGRAMA:3708 EXPANSÃO, MODERNIZAÇÃO E OPERAÇÃO...  1.877967e+09
# PROGRAMA:5100 PLANEJAMENTO, COORDENAÇÃO E GESTÃ...  2.351010e+06
# PROGRAMA:5119 TECNOLOGIA E INOVAÇÃO NA GESTÃO G...  1.008923e+08

# %% [markdown]
# ### LOA 2019 EMENDAS SAUDE

# %%
dd = camelot.read_pdf('files/loa_2019.pdf', pages='22-52')

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i].df], axis=0)
    
df = df.reset_index(drop=True)

# %%
df2 = df.replace('\r',' ', regex=True).replace('\n',' ', regex=True)

# %%
mask = df[0]!='DEPUTADO (A)'
df2 = df2[mask].rename(columns={0:'DEPUTADO (A)'})

mask = df[1]!='ENTIDADE / PREFEITURA \nBENEFICIADA'
df2 = df2[mask].rename(columns={1:'ENTIDADE / PREFEITURA \nBENEFICIADA'})

mask = df[2]!='MUNICÍPIO'
df2 = df2[mask].rename(columns={2:'MUNICÍPIO'})

mask = df[3]!='CNPJ'
df2 = df2[mask].rename(columns={3:'CNPJ'})

mask = df[4]!='OBJETO'
df2 = df2[mask].rename(columns={4:'OBJETO'})

mask = df[5]!='VALOR'
df2 = df2[mask].rename(columns={5:'VALOR'})

df2['VALOR'] = df2['VALOR'].str.replace('.','')

df2['VALOR'] = pd.to_numeric(df2['VALOR'],errors='coerce')

# %%
# df2.to_excel('ldo_2019_emendas_saude.xlsx', index=False)

# %% [markdown]
# ### LOA 2019 EMENDAS EXCETO SAUDE

# %%
dd = camelot.read_pdf('files/loa_2019.pdf', pages='53-95')

# %%
df = pd.DataFrame()

for i in range(len(dd)):
    df = pd.concat([df,dd[i].df], axis=0)
    
df = df.reset_index(drop=True)

# %%
df2 = df.replace('\r',' ', regex=True).replace('\n',' ', regex=True)

# %%
mask = df[0]!='DEPUTADO (A)'
df2 = df2[mask].rename(columns={0:'DEPUTADO (A)'})

mask = df[1]!='ENTIDADE / PREFEITURA \nBENEFICIADA'
df2 = df2[mask].rename(columns={1:'ENTIDADE / PREFEITURA \nBENEFICIADA'})

mask = df[2]!='MUNICÍPIO'
df2 = df2[mask].rename(columns={2:'MUNICÍPIO'})

mask = df[3]!='CNPJ'
df2 = df2[mask].rename(columns={3:'CNPJ'})

mask = df[4]!='OBJETO'
df2 = df2[mask].rename(columns={4:'OBJETO'})

mask = df[5]!='SECRETARIA / \nÓRGÃO'
df2 = df2[mask].rename(columns={5:'SECRETARIA / \nÓRGÃO'})

mask = df[6]!='VALOR'
df2 = df2[mask].rename(columns={6:'VALOR'})

df2['VALOR'] = df2['VALOR'].str.replace('.','')

df2['VALOR'] = pd.to_numeric(df2['VALOR'],errors='coerce')

# %%
df2.head()
# Out:
#          DEPUTADO (A)        ENTIDADE / PREFEITURA \nBENEFICIADA  \
# 1  ABELARDO CAMARINHA            PREFEITURA MUNICIPAL DE  BASTOS
# 2  ABELARDO CAMARINHA  PREFEITURA MUNICIPAL DE  FLÓRIDA PAULISTA
# 3  ABELARDO CAMARINHA              PREFEITURA MUNICIPAL DE GÁLIA
# 4  ABELARDO CAMARINHA              PREFEITURA MUNICIPAL DE GARÇA
# 5  ABELARDO CAMARINHA          PREFEITURA MUNICIPAL DE  GETULINA
#
#           MUNICÍPIO                CNPJ        OBJETO SECRETARIA / \nÓRGÃO  \
# 1            BASTOS  45.547.403/0001-93  PLANEJAMENTO       INFRAESTRUTURA
# 2  FLÓRIDA PAULISTA  44.925.691/0001-00  PLANEJAMENTO       INFRAESTRUTURA
# 3             GÁLIA  44.518.389/0001-37  PLANEJAMENTO       INFRAESTRUTURA
# 4             GARÇA  44.518.371/0001-35  PLANEJAMENTO       INFRAESTRUTURA
# 5          GETULINA  44.528.842/0001-96  PLANEJAMENTO       INFRAESTRUTURA
#
#       VALOR
# 1  250000.0
# 2  200000.0
# 3  250000.0
# 4  100000.0
# 5  100000.0

# %%
# df2.to_excel('ldo_2019_emendas_exceto_saude.xlsx', index=False)

# %%
df = pd.read_excel('2019/ldo_2019_emendas_exceto_saude.xlsx')

# %%
df.groupby(by=['DEPUTADO (A)']).sum().sort_values(by='VALOR', ascending=False)
# Out:
#                                        VALOR
# DEPUTADO (A)
# ABELARDO CAMARINHA                   2453970
# JOÃO PAULO RILLO                     2453970
# MARIA LÚCIA AMARY                    2453970
# MARCOS ZERBINI                       2453970
# MARCOS MARTINS                       2453970
# MARCOS DAMASIO                       2453970
# MARCO VINHOLI                        2453970
# MARCIO CAMARGO                       2453970
# LUIZ CARLOS GONDIM                   2453970
# LEO OLIVEIRA                         2453970
# JOÃO CARAMEZ                         2453970
# GERALDO CRUZ                         2453970
# JOSÉ ZICO PRADO                      2453970
# JORGE WILSON  XERIFE DO  CONSUMIDOR  2453970
# JORGE CARUSO                         2453970
# JOOJI HATO                           2453970
# ITAMAR BORGES                        2453970
# GILMAR GIMENES                       2453970
# GILMACI SANTOS                       2453970
# GILENO GOMES                         2453970
# MARTA COSTA                          2453970
# MILTON VIEIRA                        2453970
# ORLANDO BOLÇONE                      2453970
# PAULO CORRÊA JR.                     2453970
# WELLINGTON MOURA                     2453970
# VITOR SAPIENZA                       2453970
# VAZ DE LIMA                          2453970
# TEONILIO BARBA                       2453970
# SEBASTIÃO SANTOS                     2453970
# ROQUE BARBIERE                       2453970
# ROBERTO TRIPOLI                      2453970
# ROBERTO MORAIS                       2453970
# RITA PASSOS                          2453970
# RICARDO MADALENA                     2453970
# REINALDO ALGUZ                       2453970
# RAUL MARCELO                         2453970
# RAMALHO DA  CONSTRUÇÃO               2453970
# RAFAEL SILVA                         2453970
# PROF. AURIEL                         2453970
# PEDRO TOBIAS                         2453970
# PEDRO KAKÁ                           2453970
# GIL LANCASTER                        2453970
# HÉLIO NISHIMOTO                      2453970
# FERNANDO CURY                        2453970
# CARLOS BEZERRA JR                    2453970
# CELSO NASCIMENTO                     2453970
# CELINO CARDOSO                       2453970
# FERNANDO CAPEZ                       2453970
# CAUÊ MACRIS                          2453970
# CARLÃO PIGNATARI                     2453970
# CARLOS NEDER                         2453970
# CARLOS GIANNAZI                      2453970
# CARLOS CEZAR                         2453970
# CAMPOS MACHADO                       2453970
# CLELIA GOMES                         2453970
# BETH SAHÃO                           2453970
# BARROS MUNHOZ                        2453970
# ANDRÉ SOARES                         2453970
# ANDRÉ DO PRADO                       2453970
# ANALICE FERNANDES                    2453970
# ANA DO CARMO                         2453970
# ALENCAR SANTANA  BRAGA               2453970
# AFONSO LOBATO                        2453970
# CHICO SARDELLI                       2453970
# WELSON GASPARINI                     2453970
# CORONEL CAMILO                       2453970
# DAVI ZAIA                            2453970
# FELICIANO FILHO                      2453970
# ESTEVAM GALVÃO                       2453970
# ENIO TATTO                           2453970
# CÉLIA LEÃO                           2453970
# EDMIR CHEDID                         2453970
# ED THOMAS                            2453970
# CORONEL TELHADA                      2453970
# DOUTOR ULYSSES                       2453970
# DELEGADO OLIM                        2453970
# GUSTAVO PETTA                        2453000
# CAIO FRANÇA                          2453000
# CEZINHA DE  MADUREIRA                2453000
# LUIZ TURCO                           2453000
# MÁRCIA LIA                           2453000
# LUIZ FERNANDO  TEIXEIRA              2453000
# EDSON GIRIBONI                       2450000
# RODRIGO MORAES                       2450000
# ALDO DEMARCHI                        2450000
# ADILSON ROSSI                        2450000
# ROGÉRIO NOGUEIRA                     2450000
# MILTON LEITE FILHO                   2450000
# ROBERTO MASSAFERA                    2450000
# ROBERTO ENGLER                       2450000
# JOSÉ AMÉRICO                         2450000
# ANTONIO SALIM  CURIATI               2445000
# LECI BRANDÃO                         2160000
# CÁSSIO NAVARRO                       1453970
# CASSIONAVARRO                         500000
# CASSIO NAVARRO                        500000
# LECI BRANDAO                          293970

# %%
df.groupby(by=['OBJETO']).sum().sort_values(by='VALOR', ascending=False).head(10)
# Out:
#                                            VALOR
# OBJETO
# PLANEJAMENTO                            76020220
# DESENVOLVIMENTO  SOCIAL                 34544610
# PLANEJAMENTO E  GESTÃO                  29509260
# SAÚDE                                   12108880
# SECRETARIA DE  PLANEJAMENTO E  GESTÃO    9484940
# *                                        9361880
# CULTURA                                  6125910
# SECRETARIA DE  DESENVOLVIMENTO  SOCIAL   5962970
# EDUCAÇÃO                                 4220000
# ESPORTE                                  3253970

# %%
df.sort_values(by='VALOR', ascending=False).head(10)
# Out:
#            DEPUTADO (A) ENTIDADE / PREFEITURA \nBENEFICIADA  MUNICÍPIO  \
# 87    ANALICE FERNANDES                                   *          *
# 654      GILMACI SANTOS                                   *          *
# 99         ANDRÉ SOARES             PREFEITURA DE SÃO PAULO  SÃO PAULO
# 1058      MILTON VIEIRA                                   *          *
# 553     FELICIANO FILHO                PREFEITURA MUNICIPAL  GUARULHOS
# 179    CARLÃO PIGNATARI                                   *          *
# 774          JOOJI HATO                                   *          *
# 259         CAUÊ MACRIS                                   *          *
# 401       DELEGADO OLIM                                   *          *
# 1185     REINALDO ALGUZ                                   *          *
#
#                     CNPJ        OBJETO        SECRETARIA / \nÓRGÃO    VALOR
# 87                     *  PLANEJAMENTO                           *  2453970
# 654                    *             *                           *  2453970
# 99    46.395.000/0001-39         SAÚDE  AQUISIÇÃO DE  EQUIPAMENTOS  2453970
# 1058                   *             *                           *  2453970
# 553   46.319.000/0001-50         SAÚDE        DESPESAS DE  CUSTEIO  2453970
# 179                    *  PLANEJAMENTO                           *  2453970
# 774                    *             *                           *  2453970
# 259                    *  PLANEJAMENTO                           *  2453970
# 401                    *           NaN                           *  2453970
# 1185                   *  PLANEJAMENTO                           *  2378970

# %%
df.columns
# Out:
# Index(['DEPUTADO (A)', 'ENTIDADE / PREFEITURA \nBENEFICIADA', 'MUNICÍPIO',
#        'CNPJ', 'OBJETO', 'SECRETARIA / \nÓRGÃO', 'VALOR'],
#       dtype='object')
