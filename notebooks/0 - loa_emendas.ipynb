# %% [markdown]
# IBRA - INSTITUTO BRASILEIRO DE RASTREAMENTO DE ATIVOS

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 200)
import warnings
warnings.filterwarnings('ignore')

from tabula import read_pdf
import camelot

import sys
sys.path.insert(0, "../")
from scripts import emendas

# %%
def check_total(df):
    return df.groupby(by=['parlamentar'], as_index=False).sum().sort_values(by='valor')

# %% [markdown]
# ### LOA 2021 EMENDAS

# %%
# dd_saude_2021 = camelot.read_pdf('../files/loa_2021_final.pdf', pages='22-98',kind='grid')

# %%
# dd_outros_2021 = camelot.read_pdf('../files/loa_2021_final.pdf', pages='99-188',kind='grid')

# %%
### saude
df = emendas.tables_to_df(dd_saude_2021)

columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','objeto','valor']

df_saude = emendas.manipulate_padronize_df(df, columns_df)
df_saude['parlamentar'] = df_saude['parlamentar'].str.replace(
    'MARINA HELOU MARINA HELOU',
    'MARINA HELOU'
)

### outros
df = emendas.tables_to_df(dd_outros_2021)
columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','orgao','objeto','valor']

df_outras = emendas.manipulate_padronize_df(df, columns_df)

# %%
# display(check_total(df_saude))
# display(check_total(df_outras))

# %%
### merge saude and outras
df_saude['orgao'] = 'SAÚDE'

df_saude = df_saude[df_outras.columns]
df_final = pd.concat([df_saude,df_outras], axis=0)

df_final.to_csv('../data/emendas/emendas_parlamentares_2021.csv',index=False)

display(check_total(df_final))
# Out:
#                           parlamentar    valor
# 52                       LECI BRANDAO  4907940
# 36                        EDNA MACEDO  5208000
# 57                         MARCIA LIA  5360000
# 32                 DR. JORGE DO CARMO  5400000
# 82                   ROGERIO NOGUEIRA  5404000
# 0                   ADALBERTO FREITAS  5416000
# 66                      MAURO BRAGATO  5416000
# 65                            MAURICI  5416000
# 64                        MARTA COSTA  5416000
# 63                       MARINA HELOU  5416000
# 62                  MARIA LUCIA AMARY  5416000
# 61                     MARCOS ZERBINI  5416000
# 60                     MARCOS DAMASIO  5416000
# 58                 MARCIO DA FARMACIA  5416000
# 67                 MILTON LEITE FILHO  5416000
# 56                        MAJOR MECCA  5416000
# 55             LUIZ FERNANDO TEIXEIRA  5416000
# 54                     LETICIA AGUIAR  5416000
# 53                       LEO OLIVEIRA  5416000
# 51                       JOSE AMERICO  5416000
# 50  JORGE WILSON XERIFE DO CONSUMIDOR  5416000
# 59                   MARCIO NAKASHIMA  5416000
# 68         MONICA DA BANCADA ATIVISTA  5416000
# 69                    PAULO CORREA JR  5416000
# 70                      PAULO FIORILO  5416000
# 91                  VALERIA BOLSONARO  5416000
# 90                   THIAGO AURICCHIO  5416000
# 89                     TEONILIO BARBA  5416000
# 88                 TENENTE NASCIMENTO  5416000
# 87                    TENENTE COIMBRA  5416000
# 86                      SERGIO VICTOR  5416000
# 85                   SEBASTIAO SANTOS  5416000
# 84                      SARGENTO NERI  5416000
# 83                     ROQUE BARBIERE  5416000
# 49                       JORGE CARUSO  5416000
# 81                     RODRIGO MORAES  5416000
# 79                     ROBERTO MORAIS  5416000
# 78                     ROBERTO ENGLER  5416000
# 77                     RICARDO MELLAO  5416000
# 76                   RICARDO MADALENA  5416000
# 75                     REINALDO ALGUZ  5416000
# 74                       RAFAEL SILVA  5416000
# 73                      RAFA ZIMBALDI  5416000
# 72                   PROFESSORA BEBEL  5416000
# 71                    PROFESSOR KENNY  5416000
# 80                    RODRIGO GAMBALE  5416000
# 48                   JANAINA PASCHOAL  5416000
# 46                          ISA PENNA  5416000
# 92                 VINICIUS CAMARINHA  5416000
# 19                    CASTELLO BRANCO  5416000
# 18                    CARLOS GIANNAZI  5416000
# 17                       CARLOS CEZAR  5416000
# 16                   CARLAO PIGNATARI  5416000
# 15                      CARLA MORANDO  5416000
# 14                     CAMPOS MACHADO  5416000
# 13                        CAIO FRANCA  5416000
# 12                        BRUNO GANEM  5416000
# 11                      BARROS MUNHOZ  5416000
# 10                      ATAIDE TERUEL  5416000
# 9                  ARTHUR MAMAE FALEI  5416000
# 8                             APRIGIO  5416000
# 7                      ANDRE DO PRADO  5416000
# 6                   ANALICE FERNANDES  5416000
# 5                       ALTAIR MORAES  5416000
# 4                   ALEXANDRE PEREIRA  5416000
# 3                   ALEX DE MADUREIRA  5416000
# 2         AGENTE FEDERAL DANILO BALAS  5416000
# 1                       ADRIANA BORGO  5416000
# 20                        CAUE MACRIS  5416000
# 21                              CEZAR  5416000
# 22                        CONTE LOPES  5416000
# 23                  CORONEL NISHIKAWA  5416000
# 45                    HENI OZI CUKIER  5416000
# 44                     GILMACI SANTOS  5416000
# 43                          GIL DINIZ  5416000
# 42                   FREDERICO DAVILA  5416000
# 41                      FERNANDO CURY  5416000
# 40                     ESTEVAM GALVAO  5416000
# 39                  ERICA MALUNGUINHO  5416000
# 38                         ENIO TATTO  5416000
# 37                    EMIDIO DE SOUZA  5416000
# 47                      ITAMAR BORGES  5416000
# 35                       EDMIR CHEDID  5416000
# 33                 DRA. DAMARIS MOURA  5416000
# 31                     DOUGLAS GARCIA  5416000
# 30                      DIRCEU DALBEN  5416000
# 29                      DELEGADO OLIM  5416000
# 28                DELEGADO BRUNO LIMA  5416000
# 27                  DELEGADA GRACIELA  5416000
# 26                      DANIEL SOARES  5416000
# 25                        DANIEL JOSE  5416000
# 24                    CORONEL TELHADA  5416000
# 34                          ED THOMAS  5416000
# 93                   WELLINGTON MOURA  5416000

# %% [markdown]
# ### LOA 2020 EMENDAS

# %%
# dd_saude_2020 = camelot.read_pdf('../files/loa_2020_final.pdf', pages='22-63',kind='grid')

# %%
# dd_outros_2020 = camelot.read_pdf('../files/loa_2020_final.pdf', pages='65-118',kind='grid')

# %%
### saude
df = emendas.tables_to_df(dd_saude_2020)

columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','objeto','valor']

df_saude = emendas.manipulate_padronize_df(df, columns_df)
df_saude['parlamentar'] = df_saude['parlamentar'].str.replace(
    'MARINA HELOU MARINA HELOU',
    'MARINA HELOU'
)

### outros
df = emendas.tables_to_df(dd_outros_2020)
columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','orgao','objeto','valor']

df_outras = emendas.manipulate_padronize_df(df, columns_df)

# %%
# display(check_total(df_saude))
# display(check_total(df_outras))

# %%
### merge saude and outras
df_saude['orgao'] = 'SAÚDE'

df_saude = df_saude[df_outras.columns]
df_final = pd.concat([df_saude,df_outras], axis=0)

df_final.to_csv('../data/emendas/emendas_parlamentares_2020.csv',index=False)

display(check_total(df_final))
# Out:
#                           parlamentar    valor
# 3                   ALEX DE MADUREIRA  5154852
# 77                     RICARDO MELLAO  5159520
# 0                   ADALBERTO FREITAS  5160000
# 67                 MILTON LEITE FILHO  5160000
# 66                      MAURO BRAGATO  5160000
# 65                        MARTA COSTA  5160000
# 64                       MARINA HELOU  5160000
# 63                  MARIA LUCIA AMARY  5160000
# 62                     MARCOS ZERBINI  5160000
# 61                     MARCOS DAMASIO  5160000
# 60                   MARCIO NAKASHIMA  5160000
# 59                 MARCIO DA FARMACIA  5160000
# 58                         MARCIA LIA  5160000
# 57                        MAJOR MECCA  5160000
# 56             LUIZ FERNANDO TEIXEIRA  5160000
# 55                     LETICIA AGUIAR  5160000
# 54                       LEO OLIVEIRA  5160000
# 53                       LECI BRANDAO  5160000
# 52                       JOSE AMERICO  5160000
# 51  JORGE WILSON XERIFE DO CONSUMIDOR  5160000
# 50                       JORGE CARUSO  5160000
# 49                   JANAINA PASCHOAL  5160000
# 68         MONICA DA BANCADA ATIVISTA  5160000
# 69                    PAULO CORREA JR  5160000
# 70                      PAULO FIORILO  5160000
# 71                    PROFESSOR KENNY  5160000
# 91                  VALERIA BOLSONARO  5160000
# 90                   THIAGO AURICCHIO  5160000
# 89                     TEONILIO BARBA  5160000
# 88                 TENENTE NASCIMENTO  5160000
# 87                    TENENTE COIMBRA  5160000
# 86                      SERGIO VICTOR  5160000
# 85                   SEBASTIAO SANTOS  5160000
# 84                      SARGENTO NERI  5160000
# 83                     ROQUE BARBIERE  5160000
# 82                   ROGERIO NOGUEIRA  5160000
# 81                     RODRIGO MORAES  5160000
# 80                    RODRIGO GAMBALE  5160000
# 79                     ROBERTO MORAIS  5160000
# 78                     ROBERTO ENGLER  5160000
# 76                   RICARDO MADALENA  5160000
# 75                     REINALDO ALGUZ  5160000
# 74                       RAFAEL SILVA  5160000
# 73                      RAFA ZIMBALDI  5160000
# 72                   PROFESSORA BEBEL  5160000
# 48                      ITAMAR BORGES  5160000
# 47                          ISA PENNA  5160000
# 46                    HENI OZI CUKIER  5160000
# 45                     GILMACI SANTOS  5160000
# 20                    CASTELLO BRANCO  5160000
# 19                    CARLOS GIANNAZI  5160000
# 18                       CARLOS CEZAR  5160000
# 17                   CARLAO PIGNATARI  5160000
# 16                      CARLA MORANDO  5160000
# 15                     CAMPOS MACHADO  5160000
# 14                        CAIO FRANCA  5160000
# 13                        BRUNO GANEM  5160000
# 12                         BETH SAHAO  5160000
# 11                      BARROS MUNHOZ  5160000
# 10                      ATAIDE TERUEL  5160000
# 9                  ARTHUR MAMAE FALEI  5160000
# 8                             APRIGIO  5160000
# 7                      ANDRE DO PRADO  5160000
# 6                   ANALICE FERNANDES  5160000
# 5                       ALTAIR MORAES  5160000
# 4                   ALEXANDRE PEREIRA  5160000
# 2         AGENTE FEDERAL DANILO BALAS  5160000
# 1                       ADRIANA BORGO  5160000
# 21                        CAUE MACRIS  5160000
# 22                              CEZAR  5160000
# 23                        CONTE LOPES  5160000
# 24                  CORONEL NISHIKAWA  5160000
# 44                          GIL DINIZ  5160000
# 43                   FREDERICO DAVILA  5160000
# 42                      FERNANDO CURY  5160000
# 41                     ESTEVAM GALVAO  5160000
# 40                  ERICA MALUNGUINHO  5160000
# 39                         ENIO TATTO  5160000
# 38                    EMIDIO DE SOUZA  5160000
# 37                        EDNA MACEDO  5160000
# 36                       EDMIR CHEDID  5160000
# 92                 VINICIUS CAMARINHA  5160000
# 35                          ED THOMAS  5160000
# 33                 DR. JORGE DO CARMO  5160000
# 32                     DOUGLAS GARCIA  5160000
# 31                      DIRCEU DALBEN  5160000
# 30                      DELEGADO OLIM  5160000
# 29                DELEGADO BRUNO LIMA  5160000
# 28                  DELEGADA GRACIELA  5160000
# 27                      DANIEL SOARES  5160000
# 26                        DANIEL JOSE  5160000
# 25                    CORONEL TELHADA  5160000
# 34                 DRA. DAMARIS MOURA  5160000
# 93                   WELLINGTON MOURA  5160000

# %% [markdown]
# ### LOA 2019 EMENDAS

# %%
# dd_saude_2019 = camelot.read_pdf('../files/loa_2019_final.pdf', pages='22-52',kind='grid')

# %%
# dd_outros_2019 = camelot.read_pdf('../files/loa_2019_final.pdf', pages='53-95',kind='grid')

# %%
## saude
df = emendas.tables_to_df(dd_saude_2019)

columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','objeto','valor']

df_saude = emendas.manipulate_padronize_df(df, columns_df)
df_saude['parlamentar'] = df_saude['parlamentar'].str.replace(
    'LUIZ FERNANDO TEIXEIRA LUIZ FERNANDO TEIXEIRA',
    'LUIZ FERNANDO TEIXEIRA'
)

## outros

df = emendas.tables_to_df(dd_outros_2019)
columns_df = ['parlamentar','entidade_beneficiada',
              'municipio','cnpj','orgao','objeto','valor']

df_outras = emendas.manipulate_padronize_df(df, columns_df)
df_outras['parlamentar'] = df_outras['parlamentar'].str.replace('CASSIONAVARRO','CASSIO NAVARRO')

# %%
### merge saude and outras
df_saude['orgao'] = 'SAÚDE'

df_saude = df_saude[df_outras.columns]
df_final = pd.concat([df_saude,df_outras], axis=0)

df_final.to_csv('../data/emendas/emendas_parlamentares_2019.csv',index=False)

display(check_total(df_final))
# Out:
#                           parlamentar    valor
# 3                       ALDO DEMARCHI  4800000
# 9               ANTONIO SALIM CURIATI  4890000
# 68                 MILTON LEITE FILHO  4900000
# 1                       ADILSON ROSSI  4900000
# 34                     EDSON GIRIBONI  4900000
# 53                       JOSE AMERICO  4900000
# 86                   ROGERIO NOGUEIRA  4900000
# 85                     RODRIGO MORAES  4900000
# 81                     ROBERTO ENGLER  4900000
# 82                  ROBERTO MASSAFERA  4900000
# 60                         MARCIA LIA  4906000
# 59                         LUIZ TURCO  4906000
# 58             LUIZ FERNANDO TEIXEIRA  4906000
# 24               CEZINHA DE MADUREIRA  4906000
# 12                        CAIO FRANCA  4906000
# 45                      GUSTAVO PETTA  4906970
# 56                       LEO OLIVEIRA  4907940
# 55                       LECI BRANDAO  4907940
# 54                    JOSE ZICO PRADO  4907940
# 61                     MARCIO CAMARGO  4907940
# 62                      MARCO VINHOLI  4907940
# 63                     MARCOS DAMASIO  4907940
# 52  JORGE WILSON XERIFE DO CONSUMIDOR  4907940
# 64                     MARCOS MARTINS  4907940
# 65                     MARCOS ZERBINI  4907940
# 66                  MARIA LUCIA AMARY  4907940
# 67                        MARTA COSTA  4907940
# 57                 LUIZ CARLOS GONDIM  4907940
# 0                  ABELARDO CAMARINHA  4907940
# 70                    ORLANDO BOLCONE  4907940
# 91                     VITOR SAPIENZA  4907940
# 90                        VAZ DE LIMA  4907940
# 89                     TEONILIO BARBA  4907940
# 88                   SEBASTIAO SANTOS  4907940
# 87                     ROQUE BARBIERE  4907940
# 84                    ROBERTO TRIPOLI  4907940
# 83                     ROBERTO MORAIS  4907940
# 80                        RITA PASSOS  4907940
# 69                      MILTON VIEIRA  4907940
# 79                   RICARDO MADALENA  4907940
# 77                       RAUL MARCELO  4907940
# 76              RAMALHO DA CONSTRUCAO  4907940
# 75                       RAFAEL SILVA  4907940
# 74                       PROF. AURIEL  4907940
# 73                       PEDRO TOBIAS  4907940
# 51                       JORGE CARUSO  4907940
# 72                         PEDRO KAKA  4907940
# 71                   PAULO CORREA JR.  4907940
# 78                     REINALDO ALGUZ  4907940
# 50                         JOOJI HATO  4907940
# 46                    HELIO NISHIMOTO  4907940
# 48                       JOAO CARAMEZ  4907940
# 22                     CELINO CARDOSO  4907940
# 21                         CELIA LEAO  4907940
# 20                        CAUE MACRIS  4907940
# 19                     CASSIO NAVARRO  4907940
# 18                       CARLOS NEDER  4907940
# 17                    CARLOS GIANNAZI  4907940
# 16                       CARLOS CEZAR  4907940
# 15                  CARLOS BEZERRA JR  4907940
# 23                   CELSO NASCIMENTO  4907940
# 14                   CARLAO PIGNATARI  4907940
# 11                         BETH SAHAO  4907940
# 10                      BARROS MUNHOZ  4907940
# 8                        ANDRE SOARES  4907940
# 7                      ANDRE DO PRADO  4907940
# 6                   ANALICE FERNANDES  4907940
# 5                        ANA DO CARMO  4907940
# 4               ALENCAR SANTANA BRAGA  4907940
# 2                       AFONSO LOBATO  4907940
# 13                     CAMPOS MACHADO  4907940
# 49                   JOAO PAULO RILLO  4907940
# 25                     CHICO SARDELLI  4907940
# 27                     CORONEL CAMILO  4907940
# 47                      ITAMAR BORGES  4907940
# 92                   WELLINGTON MOURA  4907940
# 44                     GILMAR GIMENES  4907940
# 43                     GILMACI SANTOS  4907940
# 42                       GILENO GOMES  4907940
# 41                      GIL LANCASTER  4907940
# 40                       GERALDO CRUZ  4907940
# 39                      FERNANDO CURY  4907940
# 26                       CLELIA GOMES  4907940
# 38                     FERNANDO CAPEZ  4907940
# 36                     ESTEVAM GALVAO  4907940
# 35                         ENIO TATTO  4907940
# 33                       EDMIR CHEDID  4907940
# 32                          ED THOMAS  4907940
# 31                     DOUTOR ULYSSES  4907940
# 30                      DELEGADO OLIM  4907940
# 29                          DAVI ZAIA  4907940
# 28                    CORONEL TELHADA  4907940
# 37                    FELICIANO FILHO  4907940
# 93                   WELSON GASPARINI  4907940

# %% [markdown]
# ### LOA 2018 EMENDAS

# %%
# dd_saude_2018 = camelot.read_pdf('../files/loa_2018_final.pdf', pages='22-76',kind='grid')

# %%
# dd_outros_2018 = camelot.read_pdf('../files/loa_2018_final.pdf', pages='77-135',kind='grid')

# %%
## saude
df = emendas.tables_to_df(dd_saude_2018)

columns_df = ['parlamentar','entidade_beneficiada',
              'cnpj','municipio','objeto','valor']

df_saude = emendas.manipulate_padronize_df(df, columns_df)


## outros

df = emendas.tables_to_df(dd_outros_2018)
columns_df = ['parlamentar','entidade_beneficiada',
              'cnpj','municipio','orgao','objeto','valor']

df_outras = emendas.manipulate_padronize_df(df, columns_df)
df_outras['parlamentar'] = df_outras['parlamentar'].str.replace(
    'MARIA LUCIAAMARY',
    'MARIA LUCIA AMARY'
)

# %%
### merge saude and outras
df_saude['orgao'] = 'SAÚDE'

df_saude = df_saude[df_outras.columns]
df_final = pd.concat([df_saude,df_outras], axis=0)

df_final.to_csv('../data/emendas/emendas_parlamentares_2018.csv',index=False)

display(check_total(df_final))
# Out:
#                              parlamentar      valor
# 38                            ENIO TATTO  2145000.0
# 54   JORGE WILSON - XERIFE DO CONSUMIDOR  2445000.0
# 18                       CARLOS GIANNAZI  2445000.0
# 17                       CARLOS GIANAZZI  2445000.0
# 35                          EDMIR CHEDID  2445000.0
# 34                         EDIMIR CHEDID  2445000.0
# 65                         LUIZ FERNANDO  2445000.0
# 64                    LUIZ CARLOS GONDIM  2445000.0
# 62                    LUIS CARLOS GONDIM  2445000.0
# 63                         LUIS FERNANDO  2445000.0
# 78                   PAULO CORREA JUNIOR  2445000.0
# 95                        ROQUE BARBIERE  2445000.0
# 96                        ROQUE BARBIERI  2445000.0
# 59                     JUNIOR APRILLANTI  2445000.0
# 58                     JUNIOR APRILANTTI  2445000.0
# 55     JORGE WILSON XERIFE DO CONSUMIDOR  2445000.0
# 79                      PAULO CORREIA JR  2445000.0
# 37                             ENIO TATO  2745000.0
# 69                         MARCO VINHOLI  4310000.0
# 32                        DOUTOR ULYSSES  4835000.0
# 71                        MARCOS MARTINS  4890000.0
# 67                            MARCIA LIA  4890000.0
# 68                        MARCIO CAMARGO  4890000.0
# 66                            LUIZ TURCO  4890000.0
# 61                          LEO OLIVEIRA  4890000.0
# 60                          LECI BRANDAO  4890000.0
# 57                       JOSE ZICO PRADO  4890000.0
# 56                          JOSE AMERICO  4890000.0
# 70                        MARCOS DAMASIO  4890000.0
# 72                        MARCOS ZERBINI  4890000.0
# 0                     ABELARDO CAMARINHA  4890000.0
# 74                           MARTA COSTA  4890000.0
# 100                       VITOR SAPIENZA  4890000.0
# 99                           VAZ DE LIMA  4890000.0
# 98                        TEONILIO BARBA  4890000.0
# 97                      SEBASTIAO SANTOS  4890000.0
# 94                      ROGERIO NOGUEIRA  4890000.0
# 93                        RODRIGO MORAES  4890000.0
# 92                       ROBERTO TRIPOLI  4890000.0
# 91                        ROBERTO MORAIS  4890000.0
# 90                     ROBERTO MASSAFERA  4890000.0
# 89                        ROBERTO ENGLER  4890000.0
# 88                           RITA PASSOS  4890000.0
# 87                      RICARDO MADALENA  4890000.0
# 86                        REINALDO ALGUZ  4890000.0
# 85                          RAUL MARCELO  4890000.0
# 84                 RAMALHO DA CONSTRUCAO  4890000.0
# 83                          RAFAEL SILVA  4890000.0
# 82                          PROF. AURIEL  4890000.0
# 81                          PEDRO TOBIAS  4890000.0
# 80                            PEDRO KAKA  4890000.0
# 77                       ORLANDO BOLCONE  4890000.0
# 75                    MILTON LEITE FILHO  4890000.0
# 73                     MARIA LUCIA AMARY  4890000.0
# 76                         MILTON VIEIRA  4890000.0
# 51                      JOAO PAULO RILLO  4890000.0
# 52                            JOOJI HATO  4890000.0
# 22                           CEL. CAMILO  4890000.0
# 21                           CAUE MACRIS  4890000.0
# 20                        CASSIO NAVARRO  4890000.0
# 19                          CARLOS NEDER  4890000.0
# 16                          CARLOS CEZAR  4890000.0
# 15                     CARLOS BEZERRA JR  4890000.0
# 14                      CARLAO PIGNATARI  4890000.0
# 13                        CAMPOS MACHADO  4890000.0
# 12                           CAIO FRANCA  4890000.0
# 23                          CEL. TELHADA  4890000.0
# 11                            BETH SAHAO  4890000.0
# 9                  ANTONIO SALIM CURIATI  4890000.0
# 8                           ANDRE SOARES  4890000.0
# 7                         ANDRE DO PRADO  4890000.0
# 6                      ANALICE FERNANDES  4890000.0
# 5                           ANA DO CARMO  4890000.0
# 4                  ALENCAR SANTANA BRAGA  4890000.0
# 3                          ALDO DEMARCHI  4890000.0
# 2                          AFONSO LOBATO  4890000.0
# 1                          ADILSON ROSSI  4890000.0
# 10                         BARROS MUNHOZ  4890000.0
# 53                          JORGE CARUSO  4890000.0
# 24                            CELIA LEAO  4890000.0
# 26                      CELSO NASCIMENTO  4890000.0
# 101                     WELLINGTON MOURA  4890000.0
# 50                          JOAO CARAMEZ  4890000.0
# 49                         ITAMAR BORGES  4890000.0
# 48                       HELIO NISHIMOTO  4890000.0
# 47                        GILMAR GIMENES  4890000.0
# 46                        GILMACI SANTOS  4890000.0
# 45                          GILENO GOMES  4890000.0
# 44                         GIL LANCASTER  4890000.0
# 43                          GERALDO CRUZ  4890000.0
# 25                        CELINO CARDOSO  4890000.0
# 42                         FERNANDO CURY  4890000.0
# 40                       FELICIANO FILHO  4890000.0
# 39                        ESTEVAM GALVAO  4890000.0
# 36                        EDSON GIRIBONI  4890000.0
# 33                             ED THOMAS  4890000.0
# 31                         DELEGADO OLIM  4890000.0
# 30                             DAVI ZAIA  4890000.0
# 29                          CLELIA GOMES  4890000.0
# 28                        CHICO SARDELLI  4890000.0
# 27                  CEZINHA DE MADUREIRA  4890000.0
# 41                        FERNANDO CAPEZ  4890000.0
# 102                     WELSON GASPARINI  4890000.0

# %% [markdown]
# ### UPLOAD TO BQ

# %%
import basedosdados as bd

# %%
tb = bd.Table('emendas_parlamentares','br_sp_alesp')

# %%
tb.create(
    '../data/emendas/',
    if_table_exists='replace',
    if_storage_data_exists='replace',
    if_table_config_exists='pass',)
# Out:
# Uploading files: 100%|██████████| 4/4 [00:03<00:00,  1.20it/s]

# %%
tb.publish(if_exists='replace')
